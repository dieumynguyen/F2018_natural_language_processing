# %%
import numpy as np
from collections import defaultdict
import itertools
from itertools import product

# %% [markdown]
# <b> Step 1. Calculate transition and emission probabilities </b>

# %%
def build_words_tags_sets(data):
    # Create a set of tags and set of words to process unseen words & get counts

    set_of_tags = set()
    set_of_tags.add("<s>"); set_of_tags.add("</s>")
    set_of_words = set()
    total_list_of_words = []
    
    # Add in UNK word class 
    set_of_words.add("UNK")

    for line in data:
        if line != '\n':
            word_tag = line.strip().split('\t')
            set_of_tags.add(word_tag[2])
            set_of_words.add(word_tag[1])
            total_list_of_words.append(word_tag[1])
            
    return set_of_tags, set_of_words, total_list_of_words

# %%
def build_lists_and_probabilities(train_data, set_of_tags, set_of_words, unk_count):

    # Get counts of tag, words, word-tags
    word_tag_count = defaultdict(int) # C(t, w)
    word_count = defaultdict(int) # C(w)
    tag_count = defaultdict(int) # C(t)

    tag_sequence = ["<s>"]  # Sequence of tags, a sentence ends with .
    tag_sequence_count = 0 
    tag_tag_count = defaultdict(int) # C(t_{i-1}, t_i)

    # print('{}'.format(train_data[0][2:]))

    for line in train_data:
         if line != '\n':
            word_tag = line.strip().split('\t')

            word_tag_count[(word_tag[1], word_tag[2])] += 1
            word_count[word_tag[1]] += 1
            tag_count[word_tag[2]] += 2

            # Get all tags from all lines
            tag_sequence.append(word_tag[2])
            if word_tag[1] == ".":
                tag_sequence.append("</s>")
                for i in range(0, len(tag_sequence)-1):
                    tag_tag_count[(tag_sequence[i], tag_sequence[i+1])] += 1
                tag_sequence = ["<s>"]
                tag_sequence_count += 1

    tag_count["<s>"] = tag_sequence_count
    tag_count["</s>"] = tag_sequence_count
    
    # For UNK words, count from corpus
    word_count["UNK"] = UNK_count

    # Combine tag set and word set 
    all_word_tag_combos = list(product(set_of_words, set_of_tags))
    for word_tag_combo in all_word_tag_combos:
        if word_tag_combo not in word_tag_count.keys():
            word_tag_count[word_tag_combo] = 0

    # Same thing for tag_tag_count
    all_tag_tag_combos = list(product(set_of_tags, set_of_tags))
    for tag_tag_combo in all_tag_tag_combos:
        if tag_tag_combo not in tag_tag_count.keys():
            tag_tag_count[tag_tag_combo] = 0

    # Get lists and probs
    # To smooth or to not smooth - that is the question...
    transition_probs = laplace_smooth_transition(tag_tag_count, tag_count, word_count)
    emission_probs = laplace_smooth_emission(word_tag_count, tag_count, word_count) 
#     transition_probs = calculate_transition(tag_tag_count, tag_count)
#     emission_probs = calculate_emission(word_tag_count, tag_count)
    list_of_tags = list(sorted(set_of_tags))
    list_of_words = list(sorted(set_of_words))
    
    return list_of_tags, list_of_words, word_count, transition_probs, emission_probs

# %%
def calculate_transition(tag_tag_count, tag_count):
    # Calculate transition probabilities
    # P(t_i | t_{i-1}) = C(t_{i-1, t_i}) / C(t_{i-1})
    transition_probs = {}
    for tag_tag in tag_tag_count:
        count_tag1tag2 = tag_tag_count[tag_tag]
        count_tag1 = tag_count[tag_tag[0]]
        transition_probs[tag_tag] = count_tag1tag2 / count_tag1        
    return transition_probs

# %%
def calculate_emission(word_tag_count, tag_count):
    # Calculate emission probabilities
    # P(w | t) = C(t, w) / C(t)
    # word-tag pairings with 0 prob not included, will be 0 by default if not in dict
    # No smoothing yet
    emission_probs = {}
    for word_tag in word_tag_count:
        count_word_tag = word_tag_count[word_tag]
        count_tag = tag_count[word_tag[1]]
        emission_probs[word_tag] = count_word_tag / count_tag
    return emission_probs

# %%
def laplace_smooth_transition(tag_tag_count, tag_count, word_count):
    vocab_size = len(word_count)
    
    transition_probs = {}
    for tag_tag in tag_tag_count:
        count_tag1tag2 = tag_tag_count[tag_tag]
        count_tag1 = tag_count[tag_tag[0]]
        transition_probs[tag_tag] = (count_tag1tag2 + 1) / (count_tag1 + vocab_size)        
    return transition_probs

# %%
def laplace_smooth_emission(word_tag_count, tag_count, word_count):
    vocab_size = len(word_count)
    
    emission_probs = {}
    for word_tag in word_tag_count:
        count_word_tag = word_tag_count[word_tag]
        count_tag = tag_count[word_tag[1]]
        emission_probs[word_tag] = (count_word_tag + 1) / (count_tag + vocab_size)
    return emission_probs

# %% [markdown]
# <b> Step 2. Viterbi algorithm </b>

# %%
def viterbi_pos_tagger(list_of_tags, input_sentence, transition_probs, emission_probs):
    # Initializing matrices & vector
    # Matrix with tags vs words
    p = np.zeros(shape=(len(list_of_tags), len(input_sentence)))
    # Matrix for backtrace
    back = np.zeros(shape=(len(list_of_tags), len(input_sentence)), dtype=np.int)

    # Initializing step: P(tag|start) * P(word1|tag)
    for tag_i, tag in enumerate(list_of_tags):
        # Fill first col of matrix p & back matrices
        tag_given_start = ('<s>', tag)
        word_given_tag = (input_sentence[0], tag)
        p[tag_i, 0] = transition_probs[tag_given_start] * emission_probs[word_given_tag]
        back[tag_i, 0] = 0  # RECHECK this - not sure how to initialize back pointer

    # Recursion step - go through every tag for each token:
    for word_i in range(1, len(input_sentence)):
        for tagi1, tag1 in enumerate(list_of_tags):
            # For each tag, get its prob given all other tags:
            # Prev column * P(tag|all tags) * P(word|tag)
            # Fill in viterbi matrix
            p[tagi1, word_i] = np.max([p[tagi2, word_i - 1] * transition_probs[tag2, tag1] * emission_probs[input_sentence[word_i], tag1] for tagi2,tag2 in enumerate(list_of_tags)])
            # Fill in backpointer
            back[tagi1, word_i] = np.argmax([p[tagi2, word_i - 1] * transition_probs[tag2, tag1] * emission_probs[input_sentence[word_i], tag1] for tagi2,tag2 in enumerate(list_of_tags)])

    # Termination steps
    best_path_prob = np.max([p[tag_i, len(input_sentence)-1] for tag_i, tag in enumerate(list_of_tags)])        
    best_path_pointer = np.argmax([p[tag_i, len(input_sentence)-1] for tag_i, tag in enumerate(list_of_tags)])        

    return p, back, best_path_pointer, best_path_prob

# %%
def backtrace(back, best_path_pointer, input_sentence):
    path_idx = [best_path_pointer]
    for column_i, column in enumerate(back.T[::-1]): # Starts at end 
        max_tag_idx = max(column)
        path_idx.append(max_tag_idx)
    # print(path_idx)

    tag_seq = []
    for i in range(0,len(path_idx)-1):
        tag_seq.append(list_of_tags[path_idx[i]])
        
    tag_seq = tag_seq[::-1]

    # print('Input sentence: {}'.format(input_sentence))
    # print('Part of speech: {}'.format(tag_seq))
    
    return tag_seq

# %% [markdown]
# # MIKE

# %%
with open('berp-POS-training.txt', 'r') as train_file:
    train_data = train_file.readlines()

# %%
XXX = np.array([ele.strip().split("\t") for ele in train_data if ele.strip() != ""])
XXX[:12]
# Out:
# array([['1', 'i', 'PRP'],
#        ['2', "'d", 'MD'],
#        ['3', 'like', 'VB'],
#        ['4', 'to', 'TO'],
#        ['5', 'go', 'VB'],
#        ['6', 'to', 'IN'],
#        ['7', 'a', 'DT'],
#        ['8', 'fancy', 'JJ'],
#        ['9', 'restaurant', 'NN'],
#        ['10', '.', '.'],
#        ['1', 'i', 'PRP'],
#        ['2', "'d", 'MD']], dtype='<U17')

# %%
XXX.shape
# Out:
# (152119, 3)

# %%
token_sentence_idxs = XXX[:,0]
tokens = XXX[:,1]
tags = XXX[:,2]

# %%
len(train_data)
# Out:
# 167984

# %%
sentences = []
sentence = []
for token, tag in zip(tokens, tags):
    if token == '.':
        sentence.append(np.array([token, tag]))
        sentences.append(np.array(sentence))
        sentence = []
    else:
        sentence.append(np.array([token, tag]))

# %%
sentences = np.array(sentences)

# %%
sentences.shape[0]
# Out:
# 15866

# %%
num_total_sentences = sentences.shape[0]
num_total_sentences
# Out:
# 15866

# %%
np.random.shuffle(sentences)

# %%
train_test_split = 0.8

# %%
num_train_sentences = int(num_total_sentences * train_test_split)
num_train_sentences
# Out:
# 12692

# %%
num_test_sentences = num_total_sentences - num_train_sentences
num_test_sentences
# Out:
# 3174

# %%
(num_test_sentences + num_train_sentences) == num_total_sentences
# Out:
# True

# %%
train_sentences = sentences[:num_train_sentences]
test_sentences = sentences[num_train_sentences:]

# %%
train_sentences.shape[0] == num_train_sentences
# Out:
# True

# %%
test_sentences.shape[0] == num_test_sentences
# Out:
# True

# %%
train_sentences.shape
# Out:
# (12692,)

# %%
test_sentences.shape
# Out:
# (3174,)

# %% [markdown]
# ## Unique Sets

# %%
def get_unique_stuff(sentence, get="token"):
    idx = 0 if get == "token" else 1
    unique_raw = np.array([np.unique(ele[:,idx]) for ele in sentence])

    flat_X = []
    for ele in unique_raw:
        flat_X += list(ele)
    unique_set = set(np.unique(flat_X))
    
    if get == "token":
        unique_set.add()
    else:
        unique_set.add()
    
    return unique_set

# %%
# comb_sentences = np.concatenate([train_sentences, test_sentences], axis=0)
# unique_total_tokens = get_unique_stuff(comb_sentences, get="token")
# unique_total_tags = get_unique_stuff(comb_sentences, get="tags")
# unique_total_tokens.shape, unique_total_tags.shape

# %%
# unique_train_tokens = get_unique_stuff(train_sentences, get="token")
# unique_train_tags = get_unique_stuff(train_sentences, get="tags")
# unique_train_tokens.shape, unique_train_tags.shape

# %%
# unique_test_tokens = get_unique_stuff(test_sentences, get="token")
# unique_test_tags = get_unique_stuff(test_sentences, get="tags")
# unique_test_tokens.shape, unique_test_tags.shape

# %% [markdown]
# ### Make Train/Test Files

# %%
def write_new_stuff(sentences, dataset_key):
    with open("{}_sentences_shuffled.txt".format(dataset_key), "w") as outfile:
        for sentence in sentences:
            for i, (token, tag) in enumerate(sentence, 1):
                out_write = "{}\t{}\t{}\n".format(i, token, tag)
                outfile.write(out_write)
            out_write = "\n"
            outfile.write(out_write)

# %%
write_new_stuff(train_sentences, "training")
write_new_stuff(test_sentences, "test")

# %% [markdown]
# # -----------//Mike---------

# %% [markdown]
# After splitting data into training & test set:
#     1. Build word & tag sets for entire data & training data
#     2. Words in entire data but not training data are turned into UNK & counted
#     3. Use training data and the UNK counts to build transition and emission matrices
#     4. Load test set & turn tokens into a list, preserve "/n"
#     5. Run viterbi function on test set, get list of tags
#     6. Write output file with idx-token-tag
#     7. Compare output file and test set & calculate accuracy

# %%
### 1. 
# Entire data
with open('berp-POS-training.txt', 'r') as entire_file:
    entire_set = entire_file.readlines()

# Train set
with open('training_sentences_shuffled.txt', 'r') as train_file:
    train_set = train_file.readlines()
    
# Test set
with open('test_sentences_shuffled.txt', 'r') as test_file:
    test_set = test_file.readlines()
    
# Build word & tag sets
entire_tags, entire_words, entire_total_word_list = build_words_tags_sets(entire_set)
train_tags, train_words, train_total = build_words_tags_sets(train_set)
test_tags, test_words, test_total = build_words_tags_sets(test_set)

# %%
### 2. 
# Get UNK count
unk_count = 0
unk_words = []
for word in entire_words:
    if word != '/n':
        if word not in train_words:
            unk_words.append(word)
            unk_count += entire_total_word_list.count(word)
            
### 4. 
# Get sequence of words + Replace unseen words in test set with UNK
sequence_tokens = []
for line in test_set:
    if line != '\n':
        word_tag = line.strip().split('\t')
        if word_tag[1] not in train_words:
            sequence_tokens.append('UNK')
        else:
            sequence_tokens.append(word_tag[1])

# %%
XXX = np.array([ele.strip().split("\t") for ele in test_set if ele.strip() != ""])
tokens = XXX[:,1]
tags = XXX[:,2]

sentences_labels = []
sentence_labels = []

sentences = []
sentence = []
for token, tag in zip(tokens, tags):
    if token not in train_words:
        token = "UNK"
    if token == '.':
        sentence.append(token)
        sentences.append(sentence)
        sentence = []
        
    else:
        sentence.append(token)
        
    if tag == '.':
        sentence_labels.append(tag)
        sentences_labels.append(sentence_labels)
        sentence_labels = []
    else:
        sentence_labels.append(tag)

# %%
sentences_labels
# Out:
# [['VB', 'PRP', 'IN', 'NN', 'HYPH', 'NN', '.'],
#  ['UH', 'VB', 'PRP', 'JJ', 'NN', 'IN', 'DT', 'JJ', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'IN', 'NNP', '.'],
#  ['UH', 'VB', 'IN', 'CD', 'NNS', 'VB', 'CC', 'VB', '.'],
#  ['IN', 'NN', '.'],
#  ['JJ', 'JJ', 'UH', 'CD', 'TO', 'CD', 'NNS', '.'],
#  ['PRP', 'MD', 'VB', 'RB', 'JJ', 'IN', 'NN', '.'],
#  ['NN', 'NN', '.'],
#  ['WRB', 'MD', 'PRP', 'VB', 'NN', 'IN', 'DT', 'CD', 'NNS', '.'],
#  ['NN', 'IN', 'NN', '.'],
#  ['VB',
#   'PRP',
#   'RBR',
#   'IN',
#   'JJ',
#   'NN',
#   'CC',
#   'NNS',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBZ',
#   '.'],
#  ['NN',
#   'NN',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'CC',
#   'NNS',
#   'NN',
#   '.'],
#  ['UH', 'RB', 'CD', 'NNS', '.'],
#  ['VB', 'PRP', 'DT', 'NN', 'NNS', 'IN', 'NN', '.'],
#  ['VBP', 'VBN', 'NN', '.'],
#  ['RB',
#   'HYPH',
#   'FW',
#   'FW',
#   'FW',
#   'NN',
#   'NN',
#   'POS',
#   'NN',
#   'NN',
#   'NN',
#   'POS',
#   'NN',
#   'JJ',
#   'NN',
#   '.'],
#  ['JJR', 'IN', 'RB', 'NNS', 'VBP', '.'],
#  ['PRP', 'MD', 'VB', 'DT', 'NN', 'IN', 'NN', '.'],
#  ['UH', 'NN', 'VBP', 'EX', 'DT', 'JJ', 'JJ', 'NNS', 'IN', 'NN', '.'],
#  ['IN', 'VBG', 'NN', 'IN', 'NN', '.'],
#  ['VB', 'PRP', 'VB', 'RB', '.'],
#  ['WP', 'VBP', 'PRP', 'VB', 'IN', 'NN', 'NN', '.'],
#  ['PRP', 'VBP', 'RB', 'RB', 'VB', 'WP', 'NN', 'IN', 'NN', '.'],
#  ['UH',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'RB',
#   'JJR',
#   'IN',
#   'CD',
#   'NNS',
#   'IN',
#   'NNS',
#   '.'],
#  ['PRP$',
#   'NN',
#   'VBZ',
#   'VBG',
#   'TO',
#   'VB',
#   'CC',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'PRP',
#   'IN',
#   'NN',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'JJ', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'NN', 'JJR', 'IN', 'NN', 'UH', '.'],
#  ['IN', 'PDT', 'DT', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'IN', 'JJR', 'IN', 'DT', 'CD', 'NNS', '.'],
#  ['PRP', 'VBP', 'JJ', 'NNS', 'IN', 'NN', '.'],
#  ['VB',
#   'DT',
#   'UH',
#   'PRP',
#   'UH',
#   'VB',
#   'PRP',
#   'DT',
#   'NN',
#   'IN',
#   'UH',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   'NN',
#   'PRP',
#   'VBD',
#   'DT',
#   'NN',
#   'IN',
#   'PRP',
#   'RB',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'NN', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'CC',
#   'RB',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN',
#   'UH',
#   '.'],
#  ['UH', 'RB', 'RB', 'IN', 'PRP', 'VBZ', 'VBG', 'NN', 'PRP', 'VBZ', 'JJ', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['PRP', 'VBP', 'DT', 'JJS', 'NN', 'IN', 'NN', 'CC', 'DT', 'RBR', 'JJ', '.'],
#  ['PRP',
#   'VBP',
#   'DT',
#   'JJ',
#   'NN',
#   'JJ',
#   'IN',
#   'PRP',
#   'TO',
#   'VB',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'UH', 'JJ', 'NN', '.'],
#  ['UH', 'TO', 'VB', 'CD', 'WDT', 'VBZ', 'JJ', 'RB', 'IN', 'NN', '.'],
#  ['VB', 'RP', '.'],
#  ['VBP', 'EX', 'DT', 'NNS', 'JJ', 'IN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'UH', 'JJ', 'JJ', 'NN', 'IN', 'NN', '.'],
#  ['PRP',
#   'MD',
#   'RB',
#   'UH',
#   'IN',
#   'NN',
#   'IN',
#   'NN',
#   'PRP',
#   'MD',
#   'RB',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'VB',
#   'IN',
#   'PRP',
#   'MD',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['MD', 'PRP', 'VB', 'PRP', 'JJR', 'NN', 'IN', 'DT', 'JJ', 'NN', '.'],
#  ['WRB', 'IN', 'JJ', 'NN', 'IN', 'NNP', 'NN', '.'],
#  ['TO', 'VB', 'IN', 'DT', 'NN', 'NN', 'IN', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'RP', 'IN', 'NN', 'IN', 'NN', 'NN', '.'],
#  ['UH',
#   'WP',
#   'PRP',
#   'RB',
#   'VBD',
#   'VBZ',
#   'IN',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'RB',
#   'JJ',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'DT', 'NN', '.'],
#  ['UH', 'DT', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'IN', 'NN', '.'],
#  ['WRB', 'IN', 'NN', 'HYPH', 'NN', '.'],
#  ['WRB', 'IN', 'DT', 'JJ', 'NN', 'IN', 'NN', '.'],
#  ['JJ', 'NN', '.'],
#  ['DT', 'NN', 'MD', 'VB', 'JJR', 'IN', 'CD', 'NN', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'DT',
#   'RB',
#   'JJ',
#   'NN',
#   'TO',
#   'VB',
#   'NN',
#   'JJ',
#   'NN',
#   '.'],
#  ['VBP', 'PRP', 'VB', 'IN', 'DT', 'JJ', 'NNS', '.'],
#  ['PRP', 'VBZ', 'RB', 'VB', 'WRB', 'RB', 'PRP', 'VBZ', 'RB', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'IN', 'NN', '.'],
#  ['VBP', 'PRP', 'VB', 'NNS', 'IN', 'DT', 'NN', 'NN', '.'],
#  ['MD', 'PRP', 'VB', 'PRP', 'DT', 'NNS', '.'],
#  ['VBZ', 'DT', 'POS', 'NN', 'NN', 'RB', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'NN',
#   'CC',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'JJ',
#   'NN',
#   '.'],
#  ['WRB', 'IN', 'JJ', 'NN', '.'],
#  ['VBZ', 'EX', 'DT', 'NN', 'NN', 'RB', '.'],
#  ['WRB', 'IN', 'NN', 'CC', 'VBZ', 'PRP', 'NN', '.'],
#  ['DT', 'NN', '.'],
#  ['PRP', 'VBP', 'NN', '.'],
#  ['VBP', 'PRP', 'VB', 'NN', 'IN', 'DT', 'NNS', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'IN', 'NNP', '.'],
#  ['RB', 'CD', 'NNS', 'POS', 'NN', '.'],
#  ['WP', 'IN', 'PRP', 'VBD', 'DT', 'NN', 'RB', '.'],
#  ['IN', 'NN', 'NN', 'CC', 'PRP', 'VBP', 'UH', 'DT', 'JJ', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'IN', 'CD', 'NNS', '.'],
#  ['UH',
#   'VB',
#   'PRP',
#   'VB',
#   'RB',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'CC',
#   'PRP',
#   'MD',
#   'VB',
#   'RB',
#   'CD',
#   'NNS',
#   '.'],
#  ['WRB', 'VBZ', 'DT', 'NN', 'WDT', 'NN', 'JJ', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'WDT',
#   'VBZ',
#   'IN',
#   'VBG',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['PRP', 'VBP', 'VBG', 'IN', 'DT', 'RB', 'JJ', 'JJ', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'NN', 'IN', 'NN', 'HYPH', 'NN', '.'],
#  ['NN', 'NN', 'NN', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'VBP',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['MD', 'PRP', 'VB', 'JJR', 'NN', 'IN', 'JJ', 'NN', 'NN', 'NN', '.'],
#  ['PRP', 'VBP', 'VBG', 'IN', 'DT', 'NN', 'IN', 'NN', 'NN', '.'],
#  ['IN', 'NN', 'PRP', 'VBP', 'TO', 'VB', 'JJ', 'NN', '.'],
#  ['JJ', 'NN', '.'],
#  ['VB', 'PRP', 'IN', 'NN', 'NN', '.'],
#  ['VBP', 'PRP', 'VB', 'NN', 'IN', 'DT', 'NN', 'VBN', 'NN', 'NN', '.'],
#  ['PRP', 'VBP', 'RB', 'VB', 'WP', 'NN', '.'],
#  ['WP', 'NN', 'IN', 'JJ', 'NNS', 'VBP', 'RB', 'IN', 'NN', '.'],
#  ['VB', 'PRP', 'IN', 'DT', 'NN', 'NN', '.'],
#  ['PRP', 'VBP', 'DT', 'NN', 'CC', 'PRP', 'MD', 'VB', 'NN', 'IN', 'NNS', '.'],
#  ['UH', 'WRB', 'PRP', 'VBP', 'PRP', 'MD', 'VB', 'TO', 'VB', 'UH', 'NN', '.'],
#  ['PRP', 'VBP', 'JJ', 'IN', 'NN', 'NN', 'NN', 'IN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'JJ', 'NN', '.'],
#  ['NNS', 'DT', 'HYPH', 'NN', 'HYPH', 'NN', '.'],
#  ['MD', 'PRP', 'VB', 'PRP', 'DT', 'NN', 'IN', 'DT', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'IN', 'UH', 'NN', 'NN', '.'],
#  ['VBP', 'PRP', 'VB', 'NN', 'IN', 'VBG', 'IN', 'NN', '.'],
#  ['LS',
#   'HYPH',
#   'NNP',
#   'POS',
#   'VBZ',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   'MD',
#   'PRP',
#   'VB',
#   'PRP',
#   'NN',
#   'IN',
#   'PRP',
#   '.'],
#  ['NN', 'CD', 'NNS', 'CC', 'JJR', 'MD', 'VB', 'JJ', '.'],
#  ['VB', 'RP', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'NN', '.'],
#  ['JJR', 'IN', 'CD', 'NN', '.'],
#  ['VB', 'PRP', 'RBR', 'IN', 'NNP', 'POS', 'NN', '.'],
#  ['DT', 'NN', 'MD', 'VB', 'JJR', 'IN', 'CD', 'NN', 'IN', 'NN', '.'],
#  ['VB', 'PRP', 'IN', 'NN', 'NNS', '.'],
#  ['UH',
#   'UH',
#   'MD',
#   'PRP',
#   'VB',
#   'PRP',
#   'PDT',
#   'DT',
#   'JJ',
#   'NNS',
#   'IN',
#   'UH',
#   'NNS',
#   '.'],
#  ['MD', 'PRP', 'VB', 'DT', 'NN', 'IN', 'NNS', '.'],
#  ['IN', 'CD', 'NNS', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'UH',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'IN',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'MD',
#   'VB',
#   'CD',
#   'NN',
#   'IN',
#   'CD',
#   'NN',
#   '.'],
#  ['WRB', 'IN', 'PRP$', 'NN', 'DT', 'NN', '.'],
#  ['UH', 'PRP', 'VBP', 'DT', 'JJ', 'NN', '.'],
#  ['WRB', 'MD', 'PRP', 'VB', 'DT', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'PRP', 'IN', 'NN', '.'],
#  ['WP', 'NN', 'IN', 'NN', 'VBP', 'PRP', 'VB', 'IN', 'NN', '.'],
#  ['CC', 'RB', 'DT', 'NN', 'NN', '.'],
#  ['UH', 'RB', 'DT', 'JJS', '.'],
#  ['UH',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'JJ',
#   'NNS',
#   'PRP',
#   'VBD',
#   'PRP',
#   'RB',
#   '.'],
#  ['VB',
#   'PRP',
#   'VB',
#   'NNS',
#   'IN',
#   'DT',
#   'CD',
#   'NN',
#   'TO',
#   'CD',
#   'NN',
#   'NN',
#   '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'VBP',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['VBP', 'PRP', 'VB', 'IN', 'DT', 'JJ', 'NN', 'NNS', '.'],
#  ['WP', 'IN', 'DT', 'NN', 'IN', 'DT', 'NN', '.'],
#  ['PRP', 'VBP', 'RB', 'VB', 'TO', 'VB', 'IN', 'JJ', 'NN', '.'],
#  ['MD',
#   'PRP',
#   'VB',
#   'PRP',
#   'RBR',
#   'IN',
#   'JJ',
#   'NN',
#   'TO',
#   'VB',
#   'TO',
#   'VB',
#   'CC',
#   'UH',
#   'NN',
#   'NN',
#   '.'],
#  ['VBG', 'IN', 'DT', 'JJ', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'IN', 'DT', 'JJ', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'RP', 'IN', 'JJ', 'NN', '.'],
#  ['NN', 'HYPH', 'NN', '.'],
#  ['PRP', 'VBP', 'PRP', 'IN', 'DT', 'NN', '.'],
#  ['NNS', '.'],
#  ['JJ',
#   'NN',
#   'FW',
#   'NN',
#   'FW',
#   'FW',
#   'POS',
#   'FW',
#   'POS',
#   'FW',
#   'FW',
#   'NN',
#   'NN',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'DT', 'NNS', '.'],
#  ['RB', 'CD', 'NNS', '.'],
#  ['PRP', 'VBP', 'JJ', 'TO', 'VB', 'IN', 'IN', 'CD', 'NN', '.'],
#  ['DT', 'NN', 'VBZ', 'CD', 'NNS', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'NN',
#   'IN',
#   'NNP',
#   'UH',
#   'DT',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   'UH',
#   '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'CC',
#   'PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'WRB',
#   'PRP',
#   'MD',
#   'VB',
#   'MD',
#   'PRP',
#   'VB',
#   'PRP',
#   'UH',
#   '.'],
#  ['WP', 'IN', 'VBP', 'NN', '.'],
#  ['MD', 'PRP', 'VB', 'PRP', 'RBR', 'IN', 'NNP', 'POS', 'NN', 'NN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'VBP',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['VB', 'PRP', 'IN', 'NN', 'NNS', '.'],
#  ['WRB', 'VBP', 'PRP', 'VB', 'TO', 'VB', 'PRP', '.'],
#  ['VB', 'PRP', 'IN', 'NNS', 'CD', 'NNS', 'RB', 'IN', 'NN', '.'],
#  ['VBP',
#   'PRP',
#   'VB',
#   'DT',
#   'JJ',
#   'NNS',
#   'WDT',
#   'VBP',
#   'VBN',
#   'IN',
#   'NNS',
#   '.'],
#  ['MD', 'PRP', 'VB', 'PRP', 'RBR', 'IN', 'DT', 'NN', '.'],
#  ['UH',
#   'UH',
#   'PRP',
#   'VBP',
#   'DT',
#   'JJ',
#   'CC',
#   'PRP$',
#   'NN',
#   'VBZ',
#   'UH',
#   'DT',
#   'NN',
#   'NN',
#   'RB',
#   'UH',
#   'PRP',
#   'VBZ',
#   'VBG',
#   'JJ',
#   'NN',
#   'IN',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN',
#   'WDT',
#   'VBZ',
#   'DT',
#   'IN',
#   'PRP',
#   'VBP',
#   'DT',
#   'MD',
#   'VB',
#   'VBN',
#   '.'],
#  ['PRP', 'VBP', 'JJ', 'TO', 'VB', 'CD', 'NNS', 'RB', '.'],
#  ['VB', 'RP', 'RB', '.'],
#  ['WRB', 'MD', 'PRP', 'VB', 'IN', 'NN', '.'],
#  ['RB',
#   'PRP',
#   'RB',
#   'VBP',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'JJ',
#   'IN',
#   'NN',
#   'VBP',
#   'DT',
#   'NN',
#   'VB',
#   'PRP',
#   'RB',
#   'IN',
#   'PRP$',
#   'NN',
#   '.'],
#  ['UH', 'VB', 'PRP', 'RBR', 'IN', 'JJ', 'NN', 'NN', '.'],
#  ['IN', 'PDT', 'DT', 'NN', '.'],
#  ['UH', 'UH', 'WP', 'VBP', 'DT', 'NNS', 'IN', 'DT', 'NN', 'NN', '.'],
#  ['PRP', 'VBP', 'DT', 'NN', 'IN', 'NN', 'RB', 'DT', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'IN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'DT', 'JJ', 'NN', 'UH', '.'],
#  ['PRP', 'VBP', 'DT', 'JJR', 'NN', 'IN', 'NN', 'CC', 'IN', 'NN', 'NN', '.'],
#  ['MD', 'PRP', 'VB', 'PRP', 'DT', 'DT', 'NN', 'IN', 'NNS', 'RB', '.'],
#  ['RB', 'JJR', 'IN', 'CD', 'NNS', '.'],
#  ['MD', 'PRP', 'VB', 'PRP', 'IN', 'NN', 'HYPH', 'NN', '.'],
#  ['RB', 'VB', 'PRP', 'IN', 'NN', 'POS', 'UH', '.'],
#  ['PRP', 'MD', 'VB', 'DT', 'JJ', 'JJ', 'JJ', 'JJ', 'NN', 'NN', '.'],
#  ['DT',
#   'NN',
#   'MD',
#   'VB',
#   'RB',
#   'IN',
#   'DT',
#   'JJR',
#   'IN',
#   'DT',
#   'CD',
#   'NNS',
#   'POS',
#   'NN',
#   '.'],
#  ['VBZ',
#   'VB',
#   'HYPH',
#   'RP',
#   'NN',
#   'VBP',
#   'JJ',
#   'HYPH',
#   'NN',
#   'IN',
#   'NN',
#   'NNS',
#   '.'],
#  ['PRP', 'MD', 'VB', 'CD', 'NNS', 'IN', 'DT', 'NN', '.'],
#  ['PRP', 'VBP', 'NN', 'NN', '.'],
#  ['UH', 'VB', 'PRP', 'JJR', 'IN', 'NN', 'NN', '.'],
#  ['UH', 'NN', 'JJR', 'UH', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'IN', 'DT', 'NN', '.'],
#  ['WDT', 'IN', 'DT', 'VBP', 'JJ', 'RB', 'IN', 'NN', '.'],
#  ['WRB', 'IN', 'RBR', 'JJ', '.'],
#  ['WP', 'VBP', 'PRP', 'VB', 'IN', 'JJ', 'NNS', '.'],
#  ['UH', 'WRB', 'VBZ', 'DT', 'NN', 'HYPH', 'VBG', 'NN', 'NN', 'NN', 'VBN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'IN', 'DT', 'NN', 'NN', '.'],
#  ['VBP', 'PRP', 'VB', 'NN', 'HYPH', 'NN', 'IN', 'PRP$', 'NN', '.'],
#  ['PRP', 'VBZ', 'RB', 'VB', 'DT', 'NN', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'IN',
#   'TO',
#   'CD',
#   'NNS',
#   'IN',
#   'NNS',
#   'CC',
#   'DT',
#   'NN',
#   'DT',
#   'JJR',
#   'IN',
#   'CD',
#   'NNS',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'IN', 'NN', '.'],
#  ['VBP',
#   'PRP',
#   'VB',
#   'DT',
#   'JJ',
#   'NNS',
#   'IN',
#   'PRP$',
#   'NN',
#   'UH',
#   'UH',
#   'UH',
#   'UH',
#   'UH',
#   'VB',
#   'DT',
#   'NN',
#   'NN',
#   'NN',
#   '.'],
#  ['JJR', 'IN', 'CD', 'NNS', '.'],
#  ['UH', 'VB', 'PRP', 'DT', 'JJR', 'NN', 'IN', 'DT', 'NN', 'NN', '.'],
#  ['NN', 'IN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'IN', 'NN', 'NNS', '.'],
#  ['UH', 'PRP', 'VBP', 'TO', 'VB', '.'],
#  ['MD', 'PRP', 'VB', 'PRP', 'RBR', 'IN', 'NNP', 'POS', 'NN', 'NN', 'NN', '.'],
#  ['JJ', 'UH', '.'],
#  ['RB',
#   'PRP',
#   'MD',
#   'VB',
#   'JJ',
#   'NN',
#   'CC',
#   'VBD',
#   'RP',
#   'TO',
#   'CD',
#   'CD',
#   'NNS',
#   '.'],
#  ['UH',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'RP',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'UH',
#   'RB',
#   'RB',
#   'JJ',
#   '.'],
#  ['PRP', 'VBP', 'DT', 'JJ', 'NN', '.'],
#  ['MD', 'VB', 'IN', 'JJS', 'CD', 'NN', 'NN', '.'],
#  ['PRP', 'VBP', 'JJ', 'TO', 'VB', 'IN', 'CD', 'NNS', '.'],
#  ['VB', 'RP', '.'],
#  ['VBZ', 'NN', 'IN', 'NN', 'NN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'CD', 'CD', 'NNS', 'NNS', 'JJ', '.'],
#  ['VBZ', 'VB', 'NN', 'NN', '.'],
#  ['VB', 'RP', '.'],
#  ['PRP', 'MD', 'VB', 'DT', 'JJ', 'JJ', 'NN', '.'],
#  ['UH',
#   'PRP',
#   'VBP',
#   'DT',
#   'VBG',
#   'NN',
#   'PRP',
#   'MD',
#   'VB',
#   'CD',
#   'NNS',
#   'IN',
#   'NN',
#   '.'],
#  ['VB', 'RP', '.'],
#  ['PRP', 'VBP', 'EX', 'VBZ', 'RB', 'DT', 'NN', 'VBN', 'NN', 'NN', '.'],
#  ['NN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'IN', 'CD', 'NNS', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'DT', 'JJ', 'NN', 'UH', '.'],
#  ['PRP',
#   'VBP',
#   'JJ',
#   'IN',
#   'VBG',
#   'JJ',
#   'NN',
#   'RB',
#   'PRP',
#   'VBP',
#   'JJ',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['RB',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'RB',
#   'CD',
#   'NNS',
#   'IN',
#   'NN',
#   'CC',
#   'PRP',
#   'MD',
#   'RB',
#   'VB',
#   'DT',
#   'JJR',
#   'IN',
#   'CD',
#   'NNS',
#   '.'],
#  ['RB', 'JJR', 'IN', 'PDT', 'DT', 'NN', '.'],
#  ['VB', 'PRP', 'DT', 'JJR', 'JJ', 'NNS', '.'],
#  ['WRB', 'VBZ', 'JJ', 'NN', '.'],
#  ['VBZ', 'NN', 'DT', 'NN', 'IN', 'NN', '.'],
#  ['VBZ', 'JJR', 'IN', 'PRP$', 'NN', 'NN', '.'],
#  ['VB', 'PRP', 'NN', 'IN', 'FW', 'FW', 'FW', '.'],
#  ['JJ', 'NN', 'NN', 'NN', 'NN', 'FW', 'FW', 'JJ', 'NN', '.'],
#  ['DT',
#   'NN',
#   'IN',
#   'NN',
#   'VBZ',
#   'VBN',
#   'IN',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   'CC',
#   'NNS',
#   'VBP',
#   'RB',
#   'VB',
#   '.'],
#  ['VB', 'PRP', 'DT', 'JJS', 'JJ', 'NN', 'RB', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'WDT',
#   'VBZ',
#   'JJR',
#   'IN',
#   'PDT',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'NN', 'JJR', 'IN', 'NN', 'UH', '.'],
#  ['PRP', 'VBP', 'NN', 'IN', 'NN', '.'],
#  ['PRP',
#   'VBP',
#   'JJ',
#   'NN',
#   'CC',
#   'PRP',
#   'VBP',
#   'NN',
#   'POS',
#   'NN',
#   'IN',
#   'PRP',
#   'MD',
#   'VB',
#   'RP',
#   'CC',
#   'PRP',
#   'RB',
#   'VBP',
#   'TO',
#   'VB',
#   'IN',
#   'CD',
#   'NNS',
#   'CC',
#   'PRP',
#   'RB',
#   'VBP',
#   'TO',
#   'VB',
#   'CD',
#   'NNS',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'CC', 'IN', 'NN', 'CC', 'IN', 'NN', '.'],
#  ['PRP', 'VBP', 'RB', 'JJ', 'NN', 'NN', 'NN', 'RB', 'JJ', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'UH',
#   'JJ',
#   'NN',
#   'CC',
#   'PRP',
#   'VBZ',
#   'DT',
#   'NN',
#   'CD',
#   '.'],
#  ['DT', 'NN', 'MD', 'VB', 'IN', 'CD', 'NNS', 'IN', 'NN', '.'],
#  ['VBP', 'EX', 'DT', 'DT', 'NN', 'IN', 'CD', 'NNS', 'IN', 'NN', '.'],
#  ['WRB',
#   'MD',
#   'PRP',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   'CC',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'NN', '.'],
#  ['CD', 'NNS', 'IN', 'NN', '.'],
#  ['JJ', 'NN', '.'],
#  ['UH', 'PRP', 'MD', 'VB', 'TO', 'VB', 'NN', 'IN', 'NN', '.'],
#  ['VB', 'PRP', 'IN', 'NN', 'NN', '.'],
#  ['VB', 'RP', '.'],
#  ['WRB', 'IN', 'JJ', 'NN', 'NN', 'NN', '.'],
#  ['WP', 'VBZ', 'DT', 'JJS', 'NN', 'IN', 'NN', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'RB',
#   'CD',
#   'NNS',
#   'IN',
#   'NN',
#   'CC',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   'MD',
#   'VB',
#   'RB',
#   'CD',
#   'NNS',
#   '.'],
#  ['PRP', 'VBZ', 'RB', 'VB', '.'],
#  ['RB', 'JJ', '.'],
#  ['VBP',
#   'PRP',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'FW',
#   'HYPH',
#   'FW',
#   'NN',
#   'CC',
#   'NN',
#   '.'],
#  ['NN', 'NN', 'RB', 'CC', 'RB', 'DT', 'NN', 'TO', 'VB', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'JJR', 'IN', 'CD', 'NNS', '.'],
#  ['NNS', 'VBP', 'NNS', 'VBP', 'NN', 'POS', 'JJ', 'NN', 'NN', 'NN', 'NN', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'NN',
#   'CC',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'UH',
#   'RB',
#   'VB',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['JJ', 'NN', 'VBZ', 'IN', 'NN', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'DT',
#   'JJR',
#   'IN',
#   'CD',
#   'CD',
#   'CC',
#   'CD',
#   'CD',
#   'NNS',
#   '.'],
#  ['VB', 'PRP', 'VB', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'NN', 'IN', 'JJ', 'NNS', '.'],
#  ['PRP', 'VBP', 'JJ', 'TO', 'VB', 'CD', 'NNS', '.'],
#  ['PRP', 'MD', 'VB', 'DT', 'JJ', 'JJ', 'NN', '.'],
#  ['VB', 'PRP', 'DT', 'JJR', 'NN', 'IN', 'JJ', 'NN', '.'],
#  ['PRP', 'VBP', 'JJ', 'IN', 'VBG', 'NN', '.'],
#  ['CD', 'NNS', '.'],
#  ['DT', 'VBZ', 'RB', 'VB', 'RB', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'IN', 'NNP', '.'],
#  ['UH',
#   'PRP',
#   'MD',
#   'VB',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'DT',
#   'CD',
#   'NNS',
#   'NN',
#   'NN',
#   'CC',
#   'NN',
#   'VBP',
#   'PRP',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'JJ', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'DT', 'NN', 'RB', 'IN', 'NN', '.'],
#  ['UH', 'WRB', 'IN', 'DT', 'NN', '.'],
#  ['MD', 'PRP', 'VB', 'PRP', 'RB', 'IN', 'DT', 'NN', '.'],
#  ['WRB', 'VBZ', 'NNS', '.'],
#  ['WRB', 'JJ', 'VBZ', 'VBN', '.'],
#  ['WDT', 'CD', 'VBZ', 'DT', 'JJS', 'IN', 'NN', '.'],
#  ['FW', 'NN', 'NN', 'NN', 'FW', 'FW', 'JJ', 'NN', '.'],
#  ['VBP',
#   'EX',
#   'DT',
#   'JJ',
#   'NNS',
#   'EX',
#   'VBZ',
#   'CD',
#   'PRP',
#   'VBD',
#   'RB',
#   'IN',
#   'NN',
#   'NN',
#   'IN',
#   'PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'WP',
#   'PRP',
#   'VBZ',
#   'VBN',
#   'UH',
#   '.'],
#  ['UH',
#   'PRP',
#   'MD',
#   'VB',
#   'VB',
#   'CD',
#   'CD',
#   'CC',
#   'CD',
#   'NNS',
#   'IN',
#   'NNS',
#   '.'],
#  ['VB',
#   'PRP',
#   'DT',
#   'NN',
#   'IN',
#   'NNS',
#   'IN',
#   'CD',
#   'NNS',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['UH',
#   'UH',
#   'PRP',
#   'VBP',
#   'DT',
#   'JJ',
#   'CC',
#   'PRP$',
#   'NN',
#   'VBZ',
#   'UH',
#   'DT',
#   'NN',
#   'NN',
#   'RB',
#   'UH',
#   'PRP',
#   'VBZ',
#   'VBG',
#   'JJ',
#   'NN',
#   'IN',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN',
#   'WDT',
#   'VBZ',
#   'DT',
#   'IN',
#   'PRP',
#   'VBP',
#   'DT',
#   'MD',
#   'VB',
#   'VBN',
#   '.'],
#  ['WDT',
#   'VBP',
#   'DT',
#   'UH',
#   'WDT',
#   'VBP',
#   'DT',
#   'JJS',
#   'NNS',
#   'IN',
#   'NN',
#   'WRB',
#   'PRP',
#   'VBP',
#   'MD',
#   'VB',
#   'IN',
#   'NN',
#   '.'],
#  ['VB', 'PRP', 'IN', 'DT', 'NNS', 'IN', 'NN', '.'],
#  ['WRB', 'IN', 'DT', 'NN', 'RB', '.'],
#  ['UH', 'PRP', 'VBD', 'IN', 'PRP', 'VBP', 'NN', 'WDT', 'VBZ', 'RB', 'JJ', '.'],
#  ['WRB', 'IN', 'JJ', 'NNS', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'DT', 'NN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'CD', 'NNS', '.'],
#  ['PRP', 'MD', 'VB', 'VBN', 'CD', 'NNS', 'IN', 'NN', 'CC', 'CD', 'UH', '.'],
#  ['NN',
#   'EX',
#   'VBD',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'RB',
#   'WDT',
#   'PRP',
#   'VBD',
#   'RB',
#   'MD',
#   'PRP',
#   'VB',
#   'PRP',
#   'IN',
#   'DT',
#   'NN',
#   'NNS',
#   'IN',
#   'NN',
#   '.'],
#  ['VB', 'RP', '.'],
#  ['UH', 'VB', 'PRP', 'DT', 'NNS', 'RB', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'JJ', 'NN', '.'],
#  ['PRP', 'VBP', 'JJ', 'TO', 'VB', 'RB', 'CD', 'NNS', '.'],
#  ['TO', 'VB', 'NN', 'IN', 'DT', 'NN', 'IN', 'NN', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'JJR',
#   'IN',
#   'CD',
#   'NNS',
#   'IN',
#   'DT',
#   'VBN',
#   'NN',
#   '.'],
#  ['JJ', 'NN', 'PRP', 'MD', 'VB', 'NN', '.'],
#  ['UH', 'UH', 'PRP', 'VBP', 'JJ', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'DT', 'JJ', 'JJ', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'JJ', 'NN', 'IN', 'NN', '.'],
#  ['WRB', 'MD', 'PRP', 'VB', 'DT', 'NN', 'IN', 'NN', '.'],
#  ['WP', 'IN', 'NN', 'NN', '.'],
#  ['VBP', 'EX', 'DT', 'JJ', 'NNS', '.'],
#  ['VB', 'DT', 'NN', 'JJR', 'IN', 'CD', 'NNS', 'IN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'DT', 'NN', 'IN', 'NN', 'NN', '.'],
#  ['JJ', 'NN', '.'],
#  ['UH', 'WRB', 'IN', 'JJ', 'NN', '.'],
#  ['UH',
#   'PRP',
#   'VBP',
#   'VBG',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'VBG',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'RB',
#   'CD',
#   'CC',
#   'CD',
#   'NNS',
#   'DT',
#   'NN',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'NN',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['JJR', 'IN', 'CD', 'NNS', '.'],
#  ['IN', 'WDT', 'NN', 'VBZ', 'NNS', 'JJ', '.'],
#  ['PRP', 'VBP', 'DT', 'DT', 'JJ', 'JJ', 'NN', '.'],
#  ['IN', 'NNP', 'UH', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'JJR', 'IN', 'CD', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'IN', 'JJ', 'NNS', '.'],
#  ['VBZ', 'PRP', 'UH', 'UH', 'CD', 'IN', 'DT', 'RBR', 'JJ', 'NNS', '.'],
#  ['UH', 'PRP', 'VBP', 'TO', 'VB', 'DT', 'JJ', 'NN', 'RB', '.'],
#  ['CD', 'NN', 'UH', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'RP', 'RB', 'RB', 'IN', 'NN', '.'],
#  ['WRB', 'JJ', 'VBZ', 'NN', 'VB', 'IN', 'NNS', '.'],
#  ['VBZ', 'EX', 'DT', 'JJ', 'NN', 'IN', 'DT', 'NN', '.'],
#  ['PRP', 'VBP', 'JJ', 'TO', 'VB', 'RP', 'IN', 'CD', 'NNS', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'RP',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'JJ', 'NN', '.'],
#  ['WDT', 'NN', 'VBZ', 'JJS', 'IN', 'NN', '.'],
#  ['MD',
#   'PRP',
#   'VB',
#   'PRP',
#   'DT',
#   'NN',
#   'IN',
#   'NNS',
#   'VBG',
#   'JJ',
#   'NN',
#   'IN',
#   'CD',
#   'NNS',
#   'CC',
#   'JJR',
#   '.'],
#  ['WRB', 'IN', 'DT', 'NN', 'HYPH', 'NN', 'POS', 'IN', 'NN', '.'],
#  ['VBP', 'IN', 'UH', 'CD', 'NN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'IN', 'NNP', '.'],
#  ['VB', 'PRP', 'IN', 'UH', 'DT', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'IN', 'NNP', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'DT', 'JJ', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'RB', 'RB', '.'],
#  ['WP', 'VBP', 'PRP', 'VB', 'IN', 'JJ', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'JJR', 'IN', 'CD', 'NNS', 'RB', 'IN', 'DT', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'IN', 'CD', 'NNS', 'VBG', 'NN', '.'],
#  ['VB', 'PRP', 'DT', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'DT', 'JJ', 'NN', '.'],
#  ['NNS', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'IN',
#   'JJ',
#   'NN',
#   'RB',
#   'JJ',
#   'CD',
#   'CD',
#   'CD',
#   'VBP',
#   'PRP',
#   '.'],
#  ['PRP', 'VBP', 'JJ', 'TO', 'VB', 'CD', 'NNS', 'CC', 'JJR', '.'],
#  ['NN', 'CD', 'NNS', 'CC', 'JJR', 'MD', 'VB', 'JJ', '.'],
#  ['DT', 'NN', 'CC', 'DT', 'NN', 'MD', 'VB', '.'],
#  ['PRP', 'MD', 'VB', 'IN', 'DT', 'NN', 'IN', 'CD', 'NNS', '.'],
#  ['VBZ', 'EX', 'NN', 'JJR', 'IN', 'DT', '.'],
#  ['RB', 'VBN', 'UH', '.'],
#  ['UH',
#   'WP',
#   'VBP',
#   'NNS',
#   'RB',
#   'UH',
#   'PRP',
#   'VBP',
#   'PRP',
#   'MD',
#   'VB',
#   'JJ',
#   'CC',
#   'JJ',
#   'CC',
#   'RB',
#   'JJ',
#   'JJ',
#   'NN',
#   '.'],
#  ['PRP', 'VBD', 'RB', 'VB', 'DT', 'NN', 'POS', 'PRP', 'VBP', 'DT', 'NN', '.'],
#  ['UH', 'VB', 'PRP', 'RBR', 'IN', 'NNS', '.'],
#  ['VBZ', 'VB', 'NN', 'NN', '.'],
#  ['VBP', 'PRP', 'JJ', 'UH', 'CC', 'VB', 'RP', '.'],
#  ['WRB', 'VB', 'PRP', 'VBP', 'RB', 'JJ', 'IN', 'JJ', 'NN', 'NN', '.'],
#  ['PRP',
#   'VBP',
#   'VBG',
#   'JJ',
#   'NNP',
#   'RB',
#   'RB',
#   'RB',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBP',
#   'VBN',
#   'DT',
#   'NN',
#   'CC',
#   'RB',
#   'PRP',
#   'VBP',
#   'JJ',
#   'TO',
#   'VB',
#   'RB',
#   'VB',
#   'PRP',
#   'RB',
#   'RB',
#   'IN',
#   'CD',
#   'NNS',
#   'RB',
#   'IN',
#   'NN',
#   '.'],
#  ['JJ', 'NN', 'VBZ', 'WP', 'PRP', 'VBP', '.'],
#  ['PRP', 'VBP', 'DT', 'NN', '.'],
#  ['VBZ', 'NN', 'NN', 'VB', 'NNS', '.'],
#  ['VB', 'PRP', 'VB', 'RP', '.'],
#  ['WRB', 'MD', 'PRP', 'VB', 'DT', 'JJ', 'NN', 'NN', 'NN', '.'],
#  ['NN', 'CC', 'NN', '.'],
#  ['UH',
#   'VB',
#   'PRP',
#   'VB',
#   'NN',
#   'JJR',
#   'VBP',
#   'EX',
#   'JJ',
#   'NNS',
#   'IN',
#   'NN',
#   '.'],
#  ['WP', 'VBZ', 'DT', 'JJ', 'JJ', 'NN', 'IN', 'NN', '.'],
#  ['DT',
#   'NN',
#   'IN',
#   'NN',
#   'VBZ',
#   'RB',
#   'VB',
#   'CC',
#   'DT',
#   'JJS',
#   'MD',
#   'VB',
#   'JJ',
#   '.'],
#  ['DT', 'NN', 'MD', 'VB', 'JJR', 'IN', 'CD', 'CD', 'NNS', 'RB', '.'],
#  ['VBP',
#   'RB',
#   'RB',
#   'RB',
#   'UH',
#   'PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'JJ',
#   'CC',
#   'JJ',
#   'CC',
#   'JJ',
#   'CC',
#   'JJ',
#   'CC',
#   'JJ',
#   'NN',
#   'IN',
#   'NNS',
#   'IN',
#   'JJ',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'IN',
#   'CD',
#   'NNS',
#   'NN',
#   'IN',
#   'DT',
#   '.'],
#  ['UH', 'JJ', 'NN', 'MD', 'VB', 'DT', 'JJR', 'IN', '.'],
#  ['MD', 'PRP', 'VB', 'DT', 'NN', 'IN', 'PRP', '.'],
#  ['RB', 'RB', 'IN', 'DT', 'NN', 'RB', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'VBP',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['MD', 'PRP', 'VB', 'JJR', 'NN', 'IN', 'DT', 'JJ', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'DT', 'JJ', 'NN', '.'],
#  ['WRB', 'VBZ', 'DT', 'NN', 'VBN', '.'],
#  ['VBP', 'PRP', 'VB', 'JJ', 'NNS', '.'],
#  ['UH', 'MD', 'PRP', 'VB', 'PRP', 'RBR', 'IN', 'VBD', 'DT', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'JJ', 'JJ', 'NNS', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'RB', 'JJ', '.'],
#  ['UH', 'PRP', 'MD', 'VB', 'TO', 'VB', 'IN', 'NN', 'IN', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'JJ', 'NN', 'NN', '.'],
#  ['UH',
#   'RB',
#   'JJR',
#   'IN',
#   'CD',
#   'NNS',
#   'CC',
#   'CD',
#   'UH',
#   'CD',
#   'CD',
#   'NNS',
#   '.'],
#  ['WRB',
#   'RB',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   '.'],
#  ['VB', 'PRP', 'IN', 'DT', 'NN', 'CC', 'RB', 'DT', 'NN', 'NN', '.'],
#  ['WRB', 'IN', 'PRP$', 'NN', 'DT', 'NN', '.'],
#  ['DT', 'NN', 'VBZ', 'CD', 'NN', '.'],
#  ['PRP', 'VBP', 'JJ', 'TO', 'VB', 'PDT', 'DT', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'NN', '.'],
#  ['PRP', 'VBD', 'IN', 'PRP', 'VBP', 'TO', 'VB', 'NN', 'IN', 'NN', '.'],
#  ['WRB', 'MD', 'PRP', 'VB', 'DT', 'JJ', 'NN', 'NN', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'DT', 'NN', 'IN', 'NNS', '.'],
#  ['NN', 'VBZ', 'RB', 'VB', '.'],
#  ['UH',
#   'PRP',
#   'RB',
#   'VBP',
#   'IN',
#   'JJ',
#   'NN',
#   'RB',
#   'WRB',
#   'VBP',
#   'RB',
#   'PRP',
#   'VB',
#   'PRP',
#   'IN',
#   'NN',
#   '.'],
#  ['VB', 'PRP', 'RBR', 'IN', 'NNP', 'POS', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'DT', 'JJ', 'NN', 'NN', 'IN', 'NNP', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'RP', 'IN', 'NN', '.'],
#  ['WRB', 'IN', 'CD', 'NNS', '.'],
#  ['TO', 'VB', 'NN', 'IN', 'DT', 'NN', 'IN', 'NN', '.'],
#  ['VB', 'PRP', 'VB', 'RP', '.'],
#  ['PRP', 'VBP', 'IN', 'NN', 'DT', 'JJ', 'NN', '.'],
#  ['WRB', 'JJ', 'VBZ', 'NN', 'VB', 'IN', 'NNS', '.'],
#  ['WRB', 'IN', 'IN', 'NN', '.'],
#  ['DT', 'NN', 'IN', 'NN', 'UH', '.'],
#  ['VB', 'PRP', 'IN', 'NNS', 'WDT', 'UH', 'VBP', 'JJ', 'NN', '.'],
#  ['WRB', 'JJ', 'JJ', 'NNS', 'VBP', 'PRP', 'VB', 'IN', 'RB', 'HYPH', 'NN', '.'],
#  ['IN', 'CD', 'NN', '.'],
#  ['PRP', 'VBP', 'JJ', 'TO', 'VB', 'DT', 'NN', 'CC', 'DT', 'NN', 'RB', '.'],
#  ['JJ', 'NN', 'NN', 'UH', '.'],
#  ['JJ', 'JJ', 'UH', 'CD', 'TO', 'CD', 'NNS', '.'],
#  ['VBZ', 'RB', 'EX', 'DT', 'NN', 'POS', '.'],
#  ['PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'PRP',
#   'VBP',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['MD', 'PRP', 'VB', 'NNS', 'IN', 'DT', 'NN', 'NN', '.'],
#  ['IN', 'NN', 'NN', 'CC', 'PRP', 'VBP', 'UH', 'DT', 'JJ', 'NN', '.'],
#  ['VB', 'RP', '.'],
#  ['VB', 'RP', '.'],
#  ['WP', 'IN', 'VBP', 'NN', '.'],
#  ['JJ', 'NN', 'PRP', 'VBD', 'IN', 'NN', 'RBR', 'PRP', 'VBD', 'RP', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'IN', 'DT', 'JJ', 'NN', 'NN', '.'],
#  ['JJ', 'NN', 'NN', 'VBZ', 'NN', 'NN', 'NN', 'NNS', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   'POS',
#   'IN',
#   'NN',
#   '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'WP',
#   'NN',
#   'IN',
#   'NNS',
#   'PRP',
#   'VBP',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'VBP',
#   'DT',
#   'NN',
#   '.'],
#  ['UH', 'NN', 'NN', 'IN', 'CD', 'NNS', 'IN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'IN', 'NN', 'CC', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'IN', 'DT', 'NN', 'NN', 'UH', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'NN',
#   'NN',
#   'CC',
#   'DT',
#   'NN',
#   'VBZ',
#   'RB',
#   'VB',
#   '.'],
#  ['VB', 'PRP', 'VB', 'RP', '.'],
#  ['MD', 'PRP', 'VB', 'PRP', 'RBR', 'IN', 'JJ', 'NN', '.'],
#  ['PRP', 'VBP', 'RB', 'VB', 'TO', 'VB', 'RB', 'IN', 'CD', 'NNS', '.'],
#  ['NN',
#   'HYPH',
#   'NN',
#   'NN',
#   'HYPH',
#   'NN',
#   'NN',
#   'HYPH',
#   'NN',
#   'NN',
#   'NN',
#   'POS',
#   'NN',
#   'NN',
#   'NN',
#   '.'],
#  ['MD', 'PRP', 'VB', 'VBN', 'IN', 'JJ', '.'],
#  ['NN', 'NN', '.'],
#  ['WRB', 'VBZ', 'DT', 'NN', '.'],
#  ['WRB', 'MD', 'PRP', 'VB', 'DT', 'JJ', 'NN', 'NN', 'IN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'NN', 'IN', 'NN', 'NN', '.'],
#  ['VB', 'RB', 'IN', 'DT', 'NN', '.'],
#  ['VB', 'PRP', 'RBR', 'IN', 'NN', 'POS', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'WRB', 'EX', 'VBZ', 'JJ', 'DT', 'NN', '.'],
#  ['WRB', 'IN', 'DT', 'JJ', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'DT', 'NN', 'CC', 'VB', 'DT', 'NN', '.'],
#  ['UH',
#   'VB',
#   'PRP',
#   'VB',
#   'RP',
#   'VB',
#   'PRP',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'RB',
#   'CD',
#   'CC',
#   'CD',
#   'NNS',
#   'DT',
#   'NN',
#   'JJ',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   '.'],
#  ['DT', 'VBZ', 'NN', 'NN', 'VBP', 'PRP', 'VB', 'PRP', 'PRP', 'VBP', 'NN', '.'],
#  ['RB', 'RB', 'JJ', 'RB', 'IN', 'JJ', 'NN', 'VBP', 'CD', 'NNS', '.'],
#  ['WRB', 'VBZ', 'DT', 'NN', 'RBR', 'JJ', '.'],
#  ['PRP', 'VBP', 'NN', 'NN', '.'],
#  ['VBZ', 'DT', 'JJ', 'NN', 'VB', 'NNS', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'JJ', 'NN', '.'],
#  ['WP', 'IN', 'NNP', 'NNP', 'NNP', '.'],
#  ['RB',
#   'HYPH',
#   'FW',
#   'FW',
#   'FW',
#   'NN',
#   'NN',
#   'POS',
#   'NN',
#   'NN',
#   'NN',
#   'POS',
#   'NN',
#   'JJ',
#   'NN',
#   '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'DT',
#   'JJ',
#   'NNS',
#   'WRB',
#   'DT',
#   'NN',
#   'VBZ',
#   'JJR',
#   'IN',
#   'CD',
#   'NN',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'RB', 'JJ', '.'],
#  ['VB', 'PRP', 'IN', 'FW', 'FW', 'FW', '.'],
#  ['CD', 'NNS', 'NN', 'NN', '.'],
#  ['UH', 'PRP', 'MD', 'VB', 'DT', 'NN', 'IN', 'DT', 'JJ', 'NN', 'UH', '.'],
#  ['DT', 'NN', 'IN', 'NN', 'VBZ', 'RB', 'VB', '.'],
#  ['WRB', 'MD', 'PRP', 'VB', 'VBZ', '.'],
#  ['VB', 'PRP', 'VB', 'RP', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'NN', 'CC', 'DT', 'VBZ', 'NNP', '.'],
#  ['WRB', 'IN', 'NN', '.'],
#  ['WRB', 'VBZ', 'NNP', 'HYPH', 'NNP', 'UH', '.'],
#  ['MD',
#   'PRP',
#   'VB',
#   'PRP',
#   'DT',
#   'NN',
#   'IN',
#   'PDT',
#   'DT',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['WP', 'VBZ', 'NNP', 'POS', 'NN', 'NN', 'NN', 'POS', 'NN', 'IN', '.'],
#  ['UH', 'PRP', 'VBD', 'IN', 'PRP', 'VBP', 'NN', 'WDT', 'VBZ', 'RB', 'JJ', '.'],
#  ['VBZ', 'RB', 'VB', '.'],
#  ['JJ',
#   'NN',
#   'POS',
#   'NN',
#   'POS',
#   'NN',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'POS',
#   'NN',
#   'POS',
#   'NN',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'CD', 'NNS', '.'],
#  ['VB',
#   'DT',
#   'PRP',
#   'UH',
#   'VB',
#   'PRP',
#   'DT',
#   'NN',
#   'IN',
#   'UH',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   'NN',
#   'PRP',
#   'VBD',
#   'DT',
#   'NN',
#   'IN',
#   'PRP',
#   'RB',
#   '.'],
#  ['WDT', 'CD', 'VBZ', 'DT', 'JJS', 'IN', 'NN', '.'],
#  ['CD', 'NNS', 'NN', 'NN', '.'],
#  ['UH', 'VBP', 'DT', 'NNS', 'RB', 'JJ', 'RB', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'RB', 'NN', '.'],
#  ['WDT', 'NNS', 'IN', 'DT', 'NN', 'VBP', 'NNS', '.'],
#  ['NN', 'VBD', 'NN', 'NN', 'POS', 'JJ', 'NN', 'NN', 'NN', 'NN', '.'],
#  ['RB', 'JJR', 'IN', 'CD', 'NNS', '.'],
#  ['PRP', 'MD', 'VB', 'JJ', 'JJ', 'NNS', '.'],
#  ['VBP',
#   'PRP',
#   'VB',
#   'RB',
#   'WRB',
#   'PRP',
#   'MD',
#   'VB',
#   'DT',
#   'JJ',
#   'VBN',
#   'NN',
#   '.'],
#  ['PRP', 'VBP', 'DT', 'JJ', 'NN', '.'],
#  ['NN', 'NN', 'RB', '.'],
#  ['PRP', 'MD', 'VB', 'IN', 'DT', 'NN', 'IN', 'CD', 'NNS', '.'],
#  ['PRP',
#   'VBD',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'VBZ',
#   'RB',
#   'JJ',
#   'IN',
#   'JJ',
#   'NN',
#   '.'],
#  ['JJ', 'NN', '.'],
#  ['VB', 'PRP', 'IN', 'DT', 'JJ', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'JJ', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'NN', '.'],
#  ['DT',
#   'NN',
#   'MD',
#   'VB',
#   'RB',
#   'IN',
#   'DT',
#   'JJR',
#   'IN',
#   'DT',
#   'CD',
#   'NNS',
#   'POS',
#   'NN',
#   '.'],
#  ['WRB', 'JJ', 'NNS', 'VBP', 'PRP', 'VB', 'RB', 'RB', '.'],
#  ['VB', 'PRP', 'VB', 'RP', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'DT',
#   'UH',
#   'NN',
#   'TO',
#   'VB',
#   'UH',
#   'IN',
#   'JJ',
#   'UH',
#   'NN',
#   '.'],
#  ['PRP', 'VBP', 'VBG', 'IN', 'DT', 'NN', 'IN', 'NN', 'IN', 'NN', '.'],
#  ['VB', 'PRP', 'RBR', 'IN', 'NNS', '.'],
#  ['WP', 'NN', 'IN', 'NN', 'VBP', 'PRP', 'VB', 'RB', '.'],
#  ['PRP', 'VBD', 'PRP', 'VBD', 'DT', 'NN', 'IN', 'IN', 'NN', '.'],
#  ['NN', 'IN', 'NN', 'VBZ', 'JJ', 'NN', '.'],
#  ['VB', 'DT', 'NNS', 'WDT', 'DT', 'VBZ', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'IN',
#   'NNP',
#   'CC',
#   'DT',
#   'NN',
#   'VBZ',
#   'TO',
#   'VB',
#   'JJ',
#   'IN',
#   'NN',
#   '.'],
#  ['UH',
#   'PRP',
#   'VBP',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'RB',
#   'IN',
#   'NN',
#   'RB',
#   'RB',
#   'JJ',
#   'RB',
#   'JJ',
#   'NN',
#   'CC',
#   'RB',
#   'JJ',
#   'CC',
#   'RB',
#   'JJ',
#   'NN',
#   'RB',
#   '.'],
#  ['VBZ', 'NNP', 'POS', 'VB', 'DT', 'NN', 'NN', '.'],
#  ['WRB', 'VBZ', 'UH', 'VBN', 'DT', 'NN', '.'],
#  ['UH',
#   'PRP',
#   'PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'VBG',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   'CC',
#   'PRP',
#   'PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'IN',
#   'PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'TO',
#   'VB',
#   'RB',
#   'JJ',
#   'PRP',
#   'VBP',
#   'JJ',
#   'NN',
#   'MD',
#   'VB',
#   'JJ',
#   '.'],
#  ['UH', 'VB', 'PRP', 'JJR', 'IN', 'DT', 'NN', 'NN', '.'],
#  ['NN', 'POS', 'NN', 'JJ', 'NN', 'NN', 'VBZ', 'NN', 'NN', 'NN', '.'],
#  ['PRP', 'VBP', 'DT', 'NN', 'WDT', 'VBZ', 'DT', 'NN', '.'],
#  ['VB', 'PRP', 'RBR', 'IN', 'NN', 'CC', 'IN', 'DT', 'JJ', 'NN', '.'],
#  ['NNP', '.'],
#  ['PRP', 'VBP', 'IN', 'DT', 'JJ', 'NN', '.'],
#  ['VB', 'PRP', 'IN', 'DT', 'JJ', 'NN', 'NN', 'NN', '.'],
#  ['RB', 'RB', 'RB', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'WP',
#   'NN',
#   'IN',
#   'NNS',
#   'PRP',
#   'VBP',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'VBP',
#   'DT',
#   'NN',
#   '.'],
#  ['WRB', 'VBZ', 'DT', 'JJ', 'NN', 'IN', 'NN', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'CC',
#   'PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'WRB',
#   'PRP',
#   'MD',
#   'VB',
#   'MD',
#   'PRP',
#   'VB',
#   'PRP',
#   'UH',
#   '.'],
#  ['NN', 'NN', 'CC', 'VB', 'RP', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'VBN',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'VBG',
#   'NN',
#   'IN',
#   'NNS',
#   '.'],
#  ['WRB', 'IN', 'JJ', 'NN', '.'],
#  ['RB', 'CD', 'NNS', '.'],
#  ['MD', 'PRP', 'VB', 'PRP', 'RB', 'IN', 'DT', 'NN', '.'],
#  ['TO', 'VB', 'DT', 'NN', 'IN', 'NN', '.'],
#  ['WRB', 'VBZ', 'NNP', 'POS', 'JJ', '.'],
#  ['WRB', 'VBZ', 'NN', 'POS', '.'],
#  ['RB', 'JJR', 'IN', 'CD', 'NNS', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'NN', 'IN', 'NN', '.'],
#  ['PRP', 'VBP', 'NN', 'RB', '.'],
#  ['PRP', 'VBD', 'PRP', 'VBD', 'DT', 'NN', 'IN', 'IN', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'NN', 'CC', 'PRP', 'VBP', 'TO', 'VB', 'NN', '.'],
#  ['PRP', 'VBP', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'NN', '.'],
#  ['WRB',
#   'VBZ',
#   'DT',
#   'JJS',
#   'NN',
#   'TO',
#   'VB',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'IN',
#   'CD',
#   'NNS',
#   'UH',
#   'IN',
#   'DT',
#   'CD',
#   'NN',
#   'NN',
#   '.'],
#  ['IN', 'CD', 'IN', 'RB', 'CD', 'TO', 'CD', 'NNS', '.'],
#  ['VBP', 'PRP', 'VB', 'NN', 'VBN', 'IN', 'NN', 'IN', 'NN', '.'],
#  ['WRB', 'IN', 'DT', 'NN', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'CC',
#   'RB',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN',
#   'UH',
#   '.'],
#  ['VB', 'PRP', 'IN', 'NN', 'HYPH', 'NN', '.'],
#  ['PRP',
#   'MD',
#   'RB',
#   'UH',
#   'IN',
#   'NN',
#   'IN',
#   'NN',
#   'PRP',
#   'MD',
#   'RB',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'VB',
#   'IN',
#   'PRP',
#   'MD',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['UH', 'TO', 'VB', 'NN', 'IN', 'NN', '.'],
#  ['IN', 'CD', 'NNS', '.'],
#  ['IN', 'NN', 'UH', '.'],
#  ['VBZ', 'NNP', 'FW', 'FW', 'VBP', 'NNS', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'JJR', 'IN', 'CD', 'NNS', 'IN', 'NN', '.'],
#  ['VBP',
#   'PRP',
#   'VB',
#   'DT',
#   'JJ',
#   'NNS',
#   'IN',
#   'PRP$',
#   'NN',
#   'UH',
#   'UH',
#   'UH',
#   'UH',
#   'UH',
#   'VB',
#   'DT',
#   'NN',
#   'NN',
#   'NN',
#   '.'],
#  ['DT', 'NN', 'MD', 'VB', 'IN', 'TO', 'CD', 'NNS', '.'],
#  ['RB', 'VB', 'JJR', 'IN', 'CD', 'NNS', '.'],
#  ['PRP', 'VBD', 'PRP$', 'NN', 'PRP', 'VBP', 'NN', '.'],
#  ['MD', 'PRP', 'VB', 'JJR', 'NN', 'IN', 'NN', 'POS', 'UH', '.'],
#  ['PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'TO',
#   'VB',
#   'JJR',
#   'IN',
#   'CD',
#   'NN',
#   'IN',
#   'PRP$',
#   'NN',
#   '.'],
#  ['WP', 'NNS', 'IN', 'NN', 'VBP', 'JJ', '.'],
#  ['VB', 'PRP', 'RBR', 'IN', 'NNS', 'NNS', '.'],
#  ['PRP', 'MD', 'VB', 'JJR', 'NN', 'IN', 'JJ', 'NNS', '.'],
#  ['NN', 'VBZ', 'JJ', '.'],
#  ['UH',
#   'PRP',
#   'MD',
#   'VB',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'DT',
#   'CD',
#   'NNS',
#   'NN',
#   'NN',
#   'CC',
#   'NN',
#   'VBP',
#   'PRP',
#   '.'],
#  ['VB', 'PRP', 'DT', 'JJS', 'JJ', 'NN', 'RB', '.'],
#  ['RB',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'UH',
#   'NN',
#   'NN',
#   'IN',
#   'VBG',
#   'NN',
#   'RB',
#   'VBZ',
#   'IN',
#   'CD',
#   'NNS',
#   '.'],
#  ['VBZ', 'RB', 'HYPH', 'NNS', 'VBP', 'VBN', '.'],
#  ['PRP', 'VBP', 'CD', 'NNS', 'IN', 'PRP', '.'],
#  ['VBZ',
#   'NNP',
#   'POS',
#   'NN',
#   'IN',
#   'CD',
#   'NNS',
#   'IN',
#   'NN',
#   'IN',
#   'NN',
#   'CC',
#   'NN',
#   '.'],
#  ['RB',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'UH',
#   'NN',
#   'NN',
#   'IN',
#   'VBG',
#   'NN',
#   'RB',
#   'VBZ',
#   'IN',
#   'CD',
#   'NNS',
#   '.'],
#  ['JJR', 'IN', 'CD', 'CD', 'NNS', 'POS', 'NN', '.'],
#  ['RB', 'JJR', 'IN', 'CD', 'NNS', 'IN', 'NN', '.'],
#  ['VB', 'RP', '.'],
#  ['DT', 'NN', 'NN', ':', 'NN', 'NN', '.'],
#  ['VBG',
#   'IN',
#   'PRP',
#   'VBP',
#   'RB',
#   'JJ',
#   'IN',
#   'PRP',
#   'VBP',
#   'PRP',
#   'MD',
#   'VB',
#   'IN',
#   'CD',
#   'NNS',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['PRP', 'VBP', 'RB', 'VB', 'IN', 'DT', 'NN', 'IN', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'IN', 'JJ', 'NNS', 'IN', 'NNS', '.'],
#  ['NN', 'NN', '.'],
#  ['PRP',
#   'VBP',
#   'RB',
#   'RB',
#   'JJ',
#   'IN',
#   'JJ',
#   'NN',
#   'RB',
#   'NN',
#   'WDT',
#   'VBZ',
#   'IN',
#   'DT',
#   'CD',
#   'NN',
#   'TO',
#   'CD',
#   'NN',
#   'NN',
#   '.'],
#  ['UH', 'VB', 'RP', '.'],
#  ['UH', 'PRP', 'MD', 'VB', 'TO', 'VB', 'IN', 'NN', 'IN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'DT', 'NN', 'CC', 'NN', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'VBN',
#   'NN',
#   'NN',
#   'IN',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'VBG',
#   'NN',
#   'IN',
#   'NNS',
#   '.'],
#  ['VBZ', 'VB', 'PRP', 'VB', 'NNS', '.'],
#  ['UH',
#   'VB',
#   'PRP',
#   'VB',
#   'IN',
#   'DT',
#   'UH',
#   'VBP',
#   'UH',
#   'IN',
#   'UH',
#   'NN',
#   '.'],
#  ['VB', 'RP', '.'],
#  ['PRP', 'MD', 'VB', 'PRP', 'WP', 'NN', 'IN', 'NN', '.'],
#  ['VBZ', 'JJ', 'NNS', 'JJ', 'TO', 'VB', '.'],
#  ['PRP', 'MD', 'VB', 'DT', 'NN', 'IN', 'CD', 'CD', 'NNS', 'CD', 'NNS', '.'],
#  ['UH',
#   'VB',
#   'PRP',
#   'VB',
#   'RB',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'CC',
#   'PRP',
#   'MD',
#   'VB',
#   'RB',
#   'CD',
#   'NNS',
#   '.'],
#  ['JJ',
#   'POS',
#   'JJ',
#   'NN',
#   'FW',
#   'NN',
#   'FW',
#   'FW',
#   'POS',
#   'FW',
#   'POS',
#   'FW',
#   'FW',
#   '.'],
#  ['RB', 'CD', 'CD', 'NNS', '.'],
#  ['VB', 'RP', '.'],
#  ['VBZ', 'VB', 'POS', 'VB', 'NN', 'IN', 'PRP$', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'VB', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'IN', 'JJ', 'NNS', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'NN', 'RB', 'JJ', '.'],
#  ['VBP', 'PRP', 'VB', 'DT', 'NN', 'WDT', 'VBZ', 'JJ', 'NN', '.'],
#  ['UH', 'VB', 'PRP', 'JJ', 'NN', 'IN', 'JJ', 'NN', '.'],
#  ['PRP',
#   'VBP',
#   'PRP$',
#   'NN',
#   'RB',
#   'UH',
#   'RB',
#   'PRP',
#   'VBP',
#   'PRP',
#   'MD',
#   'VB',
#   'JJS',
#   'UH',
#   'IN',
#   'RB',
#   'CD',
#   'NNS',
#   '.'],
#  ['UH',
#   'UH',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'PRP',
#   'VBP',
#   'VBG',
#   'IN',
#   'NNS',
#   'IN',
#   'NN',
#   '.'],
#  ['UH', 'MD', 'PRP', 'VB', 'PRP', 'JJR', 'IN', 'DT', 'UH', 'JJ', '.'],
#  ['MD', 'PRP', 'VB', 'PRP', 'DT', 'NN', 'NNS', 'PRP', 'VBP', '.'],
#  ['VB', 'PRP', 'JJ', 'JJ', 'NNS', 'IN', 'CD', 'NNS', 'IN', 'DT', 'NN', '.'],
#  ['WRB', 'JJ', 'NNS', 'VBP', 'JJ', 'IN', 'DT', 'NN', 'POS', '.'],
#  ['WRB', 'MD', 'PRP', 'VB', 'DT', 'JJ', 'NN', 'NN', '.'],
#  ['PRP', 'VBP', 'VBG', 'IN', 'DT', 'NN', 'IN', 'JJ', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'JJR', 'IN', 'JJ', 'NN', '.'],
#  ['RB', 'IN', 'DT', 'CD', 'NN', 'NN', '.'],
#  ['UH', 'PRP', 'MD', 'VB', 'VBG', 'IN', 'NN', '.'],
#  ['NN', 'NN', '.'],
#  ['VBD', 'IN', 'NNP', 'POS', 'JJ', 'HYPH', 'NN', 'NN', 'NN', 'DT', 'NN', '.'],
#  ['PRP', 'VBP', 'DT', 'NN', 'IN', 'JJR', 'IN', 'CD', 'NNS', 'UH', '.'],
#  ['MD', 'VB', 'TO', 'VB', 'IN', 'NN', 'IN', 'NN', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'IN',
#   'NNP',
#   'VBZ',
#   'UH',
#   'VB',
#   'PRP',
#   'VB',
#   'WP',
#   'VBP',
#   'PRP',
#   'VB',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'IN',
#   'PRP',
#   'VBP',
#   'UH',
#   'JJ',
#   'NN',
#   'NN',
#   'HYPH',
#   'NN',
#   '.'],
#  ['UH', 'VB', 'PRP', 'DT', 'NN', 'IN', 'NNS', 'JJ', 'IN', 'DT', 'NN', '.'],
#  ['VBP', 'PRP', 'VB', 'IN', 'JJ', 'NN', '.'],
#  ['NN', 'NNS', 'IN', 'NN', 'RB', 'JJ', '.'],
#  ['NN', 'IN', 'NN', 'WDT', 'NN', 'NN', 'RB', '.'],
#  ['VBP', 'PRP', 'VB', 'DT', 'NN', 'IN', 'JJ', 'NN', '.'],
#  ['VB', 'PRP', 'RBR', 'IN', 'PRP', 'UH', 'UH', '.'],
#  ['RB', 'RB', 'RB', '.'],
#  ['VBZ', 'RB', 'JJ', 'IN', 'NNS', '.'],
#  ['PRP', 'MD', 'VB', 'CD', 'NNS', 'IN', 'DT', 'JJ', 'NN', '.'],
#  ['VB', 'PRP', 'IN', 'NNS', '.'],
#  ['WP', 'IN', 'NN', 'HYPH', 'NN', '.'],
#  ['WRB',
#   'JJ',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'CD',
#   'IN',
#   'NN',
#   'NN',
#   'IN',
#   'JJ',
#   'NN',
#   '.'],
#  ['JJ', 'NN', 'UH', '.'],
#  ['PRP', 'MD', 'VB', 'DT', 'NN', 'IN', 'NN', 'NNS', '.'],
#  ['UH', 'UH', 'WP', 'VBP', 'DT', 'NNS', 'IN', 'DT', 'NN', 'NN', '.'],
#  ['VB', 'PRP', 'IN', 'DT', 'NNS', '.'],
#  ['JJ', 'CC', 'JJ', '.'],
#  ['UH',
#   'PRP',
#   'VBP',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'RB',
#   'IN',
#   'NN',
#   'RB',
#   'RB',
#   'JJ',
#   'RB',
#   'JJ',
#   'NN',
#   'CC',
#   'RB',
#   'JJ',
#   'CC',
#   'RB',
#   'JJ',
#   'NN',
#   'RB',
#   '.'],
#  ['VBZ', 'DT', 'NN', 'NN', 'RB', 'IN', 'NN', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'JJ',
#   'NN',
#   'WDT',
#   'VBZ',
#   'UH',
#   'JJ',
#   'IN',
#   'IN',
#   'DT',
#   'CD',
#   'NN',
#   'TO',
#   'CD',
#   'NN',
#   'NN',
#   '.'],
#  ['WRB',
#   'MD',
#   'PRP',
#   'VB',
#   'IN',
#   'NNS',
#   'VBZ',
#   'PRP',
#   'VBG',
#   'TO',
#   'VB',
#   'DT',
#   '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'RB',
#   'CD',
#   'NNS',
#   'IN',
#   'NN',
#   'CC',
#   'MD',
#   'RB',
#   'VB',
#   'JJR',
#   'IN',
#   'CD',
#   'NNS',
#   '.'],
#  ['PRP', 'VBP', 'JJ', 'IN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'IN', 'DT', 'NN', 'RB', 'RB', 'RB', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'NN', '.'],
#  ['CD', 'CD', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'CD', 'NNS', '.'],
#  ['PRP', 'VBP', 'DT', 'NN', 'RB', '.'],
#  ['MD', 'PRP', 'VB', 'PRP', 'RBR', 'IN', 'JJ', 'NN', '.'],
#  ['RB', 'JJR', 'IN', 'CD', 'NNS', 'IN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'RB', 'IN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'UH', 'JJ', 'NN', '.'],
#  ['MD', 'PRP', 'VB', 'PRP', 'UH', 'DT', 'NN', 'IN', 'UH', 'JJ', 'NN', '.'],
#  ['WDT', 'IN', 'DT', 'NNS', 'CC', 'NNS', 'VBZ', 'NN', '.'],
#  ['MD', 'PRP', 'VB', 'PRP', 'DT', 'NN', 'RB', 'RB', 'IN', 'JJ', 'NN', '.'],
#  ['UH', 'UH', 'UH', 'UH', 'UH', 'CC', 'DT', 'NN', 'IN', 'DT', 'JJ', 'NN', '.'],
#  ['DT', 'NN', 'MD', 'VB', 'IN', 'DT', 'NN', 'IN', 'NN', '.'],
#  ['MD', 'VB', 'RB', 'RB', '.'],
#  ['VB', 'PRP', 'JJR', 'IN', 'UH', 'NN', 'POS', '.'],
#  ['IN', 'CD', 'NNS', 'VBG', 'NN', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'JJR',
#   'NN',
#   'UH',
#   'IN',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   '.'],
#  ['WRB', 'IN', 'CD', 'NNS', 'DT', 'NN', '.'],
#  ['PRP', 'VBP', 'JJ', 'TO', 'VB', 'IN', 'TO', 'CD', 'NNS', 'IN', 'NN', '.'],
#  ['VBP', 'EX', 'JJ', 'JJ', 'NNS', '.'],
#  ['VBZ', 'CD', 'IN', 'DT', 'NNS', 'IN', 'CD', 'NNS', 'IN', 'NN', '.'],
#  ['VB', 'PRP', 'RBR', 'IN', 'NN', 'HYPH', 'VBG', 'NN', 'NN', 'UH', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'NN', 'IN', 'NN', '.'],
#  ['VB', 'PRP', 'IN', 'NNS', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'RB', 'RB', 'JJ', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'RB', 'CD', 'NNS', '.'],
#  ['VBP',
#   'EX',
#   'DT',
#   'UH',
#   'JJR',
#   'IN',
#   'CD',
#   'NNS',
#   'CC',
#   'JJR',
#   'IN',
#   'CD',
#   'NNS',
#   'PRP',
#   'VBD',
#   'TO',
#   'VB',
#   'RB',
#   '.'],
#  ['VB', 'RP', '.'],
#  ['WP', 'VBZ', 'JJ', 'NNS', 'IN', '.'],
#  ['NN', '.'],
#  ['IN', 'NNP', '.'],
#  ['VBP', 'EX', 'DT', 'NNS', 'JJ', 'IN', 'DT', 'JJ', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'RP', 'IN', 'NN', 'NN', '.'],
#  ['VB',
#   'PRP',
#   'VB',
#   'NNS',
#   'IN',
#   'DT',
#   'CD',
#   'NN',
#   'TO',
#   'CD',
#   'NN',
#   'NN',
#   '.'],
#  ['NN', 'NN', '.'],
#  ['VBP', 'RB', 'PRP', 'VB', 'JJ', 'NN', '.'],
#  ['WRB', 'MD', 'RB', 'PRP', 'VB', '.'],
#  ['VBZ', 'NNP', 'POS', 'NN', 'JJ', 'IN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'DT', 'JJ', 'NN', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'VBP',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'JJR', 'NN', 'IN', 'DT', 'NN', 'DT', 'NN', '.'],
#  ['WRB', 'VBZ', 'DT', 'NN', 'JJ', '.'],
#  ['PRP', 'VBP', 'IN', 'NN', 'IN', 'PRP', 'RB', 'VB', 'JJ', '.'],
#  ['EX', 'VBZ', 'DT', 'NN', 'IN', 'NN', 'NN', 'WP', 'IN', 'DT', 'NN', '.'],
#  ['RB',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   'MD',
#   'VB',
#   'JJ',
#   'NN',
#   'CC',
#   'PRP',
#   'MD',
#   'VB',
#   'IN',
#   'CD',
#   'TO',
#   'CD',
#   'NNS',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'JJ', 'NN', '.'],
#  ['UH', 'VB', 'PRP', 'JJR', 'IN', 'NNP', '.'],
#  ['DT', 'NN', 'CC', 'DT', 'NN', 'VBP', 'RB', 'VB', '.'],
#  ['PRP', 'MD', 'VB', 'DT', 'NN', 'IN', 'NN', 'NN', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'RB',
#   'CD',
#   'NNS',
#   'IN',
#   'NN',
#   'CC',
#   'MD',
#   'RB',
#   'VB',
#   'JJR',
#   'IN',
#   'CD',
#   'NNS',
#   '.'],
#  ['VB', 'DT', 'JJ', 'NN', 'NN', '.'],
#  ['MD', 'VB', 'RB', 'CD', 'CD', 'NNS', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'NN', '.'],
#  ['VBP', 'EX', 'DT', 'JJ', 'NN', 'NNS', '.'],
#  ['UH',
#   'VB',
#   'PRP',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'VBG',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'CD',
#   'CC',
#   'CD',
#   'NNS',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'JJ',
#   'NN',
#   'IN',
#   'NNP',
#   'IN',
#   'NN',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'CD',
#   'NNS',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'CC', 'IN', 'NN', 'CC', 'IN', 'NN', '.'],
#  ['WP', 'VBP', 'PRP', 'VB', 'IN', 'NNP', 'POS', '.'],
#  ['MD',
#   'PRP',
#   'VB',
#   'PRP',
#   'DT',
#   'NN',
#   'IN',
#   'NNS',
#   'VBG',
#   'JJ',
#   'NN',
#   'IN',
#   'CD',
#   'NNS',
#   'CC',
#   'JJR',
#   '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'JJ',
#   'NN',
#   'IN',
#   'RB',
#   'JJR',
#   'IN',
#   'CD',
#   'NNS',
#   '.'],
#  ['JJR', 'IN', 'CD', 'NNS', '.'],
#  ['PRP',
#   'MD',
#   'RB',
#   'VB',
#   'TO',
#   'VB',
#   'NN',
#   'CC',
#   'NN',
#   'CC',
#   'NN',
#   'CC',
#   'NN',
#   '.'],
#  ['PRP', 'MD', 'VB', 'JJR', 'NN', 'IN', 'JJ', 'NNS', '.'],
#  ['DT', 'NN', 'MD', 'VB', 'IN', 'DT', 'JJ', 'NN', 'NN', '.'],
#  ['PRP',
#   'VBP',
#   'VBG',
#   'JJ',
#   'NNP',
#   'RB',
#   'RB',
#   'RB',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBP',
#   'VBN',
#   'DT',
#   'NN',
#   'CC',
#   'RB',
#   'PRP',
#   'VBP',
#   'JJ',
#   'TO',
#   'VB',
#   'RB',
#   'VB',
#   'PRP',
#   'RB',
#   'RB',
#   'IN',
#   'CD',
#   'NNS',
#   'RB',
#   'IN',
#   'NN',
#   '.'],
#  ['IN', 'CD', 'CC', 'CD', 'NNS', '.'],
#  ['MD', 'PRP', 'VB', 'DT', 'NN', 'IN', 'PRP', '.'],
#  ['VBP',
#   'EX',
#   'DT',
#   'UH',
#   'JJR',
#   'IN',
#   'CD',
#   'NNS',
#   'CC',
#   'JJR',
#   'IN',
#   'CD',
#   'NNS',
#   'PRP',
#   'VBD',
#   'TO',
#   'VB',
#   'RB',
#   '.'],
#  ['WP', 'IN', 'NN', '.'],
#  ['VB', 'PRP', 'DT', 'NN', 'RB', '.'],
#  ['UH', 'PRP', 'VBP', 'JJ', 'TO', 'VB', 'IN', 'DT', 'NN', 'IN', 'NN', '.'],
#  ['DT', 'NN', 'MD', 'VB', 'CD', 'NNS', '.'],
#  ['WP', 'IN', 'NNS', 'IN', 'JJ', 'NN', '.'],
#  ['MD', 'VB', 'IN', 'JJS', 'CD', 'NN', 'NN', '.'],
#  ['WP', 'NNS', 'VBP', 'IN', 'NN', '.'],
#  ['JJ',
#   'NN',
#   'IN',
#   'NNP',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'IN',
#   'NN',
#   'HYPH',
#   'NN',
#   '.'],
#  ['DT', 'NN', 'IN', 'NN', '.'],
#  ['UH',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'RP',
#   'DT',
#   'NN',
#   'IN',
#   'NNS',
#   'CC',
#   'NN',
#   'RB',
#   'IN',
#   'NN',
#   'NN',
#   '.'],
#  ['VB', 'PRP', 'RBR', 'IN', 'NN', '.'],
#  ['WRB', 'IN', 'NN', '.'],
#  ['UH',
#   'VB',
#   'PRP',
#   'VB',
#   'RB',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'CC',
#   'PRP',
#   'MD',
#   'VB',
#   'RB',
#   'CD',
#   'NNS',
#   '.'],
#  ['VB', 'PRP', 'RB', 'DT', 'NN', 'IN', 'NNS', 'VBG', 'DT', 'NN', '.'],
#  ['PRP', 'VBP', 'JJ', 'TO', 'VB', 'IN', 'UH', '.'],
#  ['UH', 'DT', 'JJR', 'IN', 'CD', 'NNS', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'NN', 'JJ', 'RB', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'UH', 'JJ', 'JJ', 'NN', '.'],
#  ['NN', '.'],
#  ['JJ', 'NN', '.'],
#  ['UH',
#   'PRP',
#   'VBP',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'RB',
#   'IN',
#   'NN',
#   'RB',
#   'RB',
#   'JJ',
#   'RB',
#   'JJ',
#   'NN',
#   'CC',
#   'RB',
#   'JJ',
#   'CC',
#   'RB',
#   'JJ',
#   'NN',
#   'RB',
#   '.'],
#  ['PRP',
#   'VBP',
#   'VBN',
#   'DT',
#   'NN',
#   'RB',
#   'PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'WRB',
#   'RB',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   '.'],
#  ['VBD', 'JJR', 'IN', 'CD', 'NNS', '.'],
#  ['PRP', 'VBP', 'JJ', 'TO', 'VB', 'IN', 'PDT', 'DT', 'NN', 'IN', 'NN', '.'],
#  ['RB', 'JJ', 'NN', 'DT', 'NN', 'IN', 'NN', '.'],
#  ['PRP', 'VBZ', 'JJ', 'RB', 'JJ', 'NN', 'WDT', 'PRP', 'VBP', '.'],
#  ['UH',
#   'PRP',
# ...
#  ['PRP', 'VBP', 'JJ', 'IN', 'NN', 'NN', 'NN', 'IN', 'NN', '.'],
#  ['VB',
#   'PRP',
#   'PRP',
#   'VBP',
#   'RB',
#   'RB',
#   'DT',
#   'NN',
#   'CC',
#   'PRP',
#   'VBP',
#   'VBG',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['PRP',
#   'VBP',
#   'VBG',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   '.'],
#  ['MD', 'PRP', 'VB', 'PRP', 'RBR', 'IN', 'NNP', 'POS', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'JJ',
#   'TO',
#   'VB',
#   'RP',
#   'NN',
#   'RP',
#   'IN',
#   'IN',
#   'UH',
#   'CD',
#   'NNS',
#   '.'],
#  ['IN', 'NN', 'CC', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'NNS', '.'],
#  ['VB',
#   'PRP',
#   'VB',
#   'IN',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'NNS',
#   'RB',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'DT', 'JJR', 'NN', 'IN', 'NN', 'NN', '.'],
#  ['VB', 'RP', '.'],
#  ['VB', 'RP', '.'],
#  ['NN', 'NN', '.'],
#  ['VB', 'PRP', 'RBR', 'IN', 'DT', 'JJ', 'NN', '.'],
#  ['NN', 'IN', 'DT', 'NNS', 'RB', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'WDT',
#   'VBZ',
#   'RB',
#   'JJ',
#   'IN',
#   'NN',
#   '.'],
#  ['VB', 'PRP', 'NN', 'IN', 'NNP', 'POS', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'NN', 'NN', '.'],
#  ['DT', 'JJR', 'IN', 'CD', 'NNS', 'RB', '.'],
#  ['PRP',
#   'VBP',
#   'RB',
#   'RB',
#   'JJ',
#   'IN',
#   'JJ',
#   'NN',
#   'RB',
#   'NN',
#   'WDT',
#   'VBZ',
#   'IN',
#   'DT',
#   'CD',
#   'NN',
#   'TO',
#   'CD',
#   'NN',
#   'NN',
#   '.'],
#  ['WRB', 'IN', 'NN', 'RB', 'RB', '.'],
#  ['WP', 'VBP', 'NNS', 'VBP', 'PRP', 'VB', '.'],
#  ['UH',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'NN',
#   'CC',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'CD',
#   'NNS',
#   'CC',
#   'JJR',
#   '.'],
#  ['UH', 'RB', 'CD', 'NNS', '.'],
#  ['VB', 'PRP', 'IN', 'NN', 'NN', 'NN', '.'],
#  ['PRP', 'VBP', 'JJ', 'TO', 'VB', 'DT', 'JJ', 'NNS', '.'],
#  ['PRP', 'VBP', 'RB', 'VB', 'WRB', 'JJ', 'PRP', 'VBZ', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'RB', 'JJ', '.'],
#  ['NN', 'NN', '.'],
#  ['JJ', 'NN', 'NN', 'UH', '.'],
#  ['PRP', 'VBP', 'VBG', 'IN', 'DT', 'NN', 'TO', 'VB', 'NN', 'JJ', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'JJR', 'IN', 'NN', 'POS', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'JJ',
#   'NN',
#   'IN',
#   'CD',
#   'NNS',
#   'IN',
#   'CD',
#   'NNS',
#   '.'],
#  ['VB', 'PRP', 'IN', 'DT', 'VBN', 'NN', '.'],
#  ['PRP', 'VBP', 'VBG', 'IN', 'DT', 'NN', 'IN', 'NN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'NNS', 'IN', 'DT', 'VBN', 'NN', '.'],
#  ['RB', 'RB', 'RB', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'RB',
#   'VBZ',
#   '.'],
#  ['VB', 'DT', 'IN', 'NN', 'UH', '.'],
#  ['VB', 'PRP', 'RBR', 'IN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'IN', 'NN', 'NN', '.'],
#  ['PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'RB',
#   'VBD',
#   'NN',
#   'VB',
#   'TO',
#   'VB',
#   'PRP',
#   'IN',
#   'NN',
#   'CC',
#   'PRP',
#   'VBD',
#   'VB',
#   'CC',
#   'PRP',
#   'VBD',
#   'RB',
#   '.'],
#  ['MD', 'PRP', 'VB', 'PRP', 'RB', 'IN', 'DT', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'DT', 'JJ', 'NN', 'NN', 'JJ', 'NN', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'IN', 'JJS', 'CD', 'NNS', '.'],
#  ['DT', 'NN', 'MD', 'RB', 'VB', 'JJR', 'IN', 'CD', 'NNS', '.'],
#  ['WP', 'IN', 'JJ', 'NN', '.'],
#  ['PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'PRP',
#   'VBP',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['UH', 'VB', 'PRP', 'RBR', 'IN', 'NNS', '.'],
#  ['VBZ', 'NNP', 'POS', 'NN', 'JJ', 'IN', 'NN', '.'],
#  ['VB',
#   'DT',
#   'UH',
#   'PRP',
#   'UH',
#   'VB',
#   'PRP',
#   'DT',
#   'NN',
#   'IN',
#   'UH',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   'NN',
#   'PRP',
#   'VBD',
#   'DT',
#   'NN',
#   'IN',
#   'PRP',
#   'RB',
#   '.'],
#  ['VB', 'RP', 'UH', 'VBZ', 'PRP', 'NN', '.'],
#  ['WRB',
#   'VB',
#   'NNP',
#   'POS',
#   'VBZ',
#   'CD',
#   'CD',
#   'NNS',
#   'IN',
#   'NN',
#   'CC',
#   'NN',
#   'POS',
#   'NN',
#   'VBZ',
#   'CD',
#   'NNS',
#   'IN',
#   'NN',
#   '.'],
#  ['UH', 'UH', 'TO', 'VB', 'NN', '.'],
#  ['VBP', 'EX', 'DT', 'NN', 'NNS', 'IN', 'NN', '.'],
#  ['UH',
#   'WP',
#   'VBP',
#   'NNS',
#   'RB',
#   'UH',
#   'PRP',
#   'VBP',
#   'PRP',
#   'MD',
#   'VB',
#   'JJ',
#   'CC',
#   'JJ',
#   'CC',
#   'RB',
#   'JJ',
#   'JJ',
#   'NN',
#   '.'],
#  ['UH',
#   'TO',
#   'VB',
#   'RP',
#   'IN',
#   'CD',
#   'NNS',
#   'CC',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN',
#   '.'],
#  ['PRP', 'VBP', 'DT', 'NN', '.'],
#  ['DT', 'NN', 'IN', 'NN', 'VBZ', 'RB', 'VB', '.'],
#  ['VB', 'PRP', 'IN', 'NNP', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'NN', '.'],
#  ['PRP', 'VBP', 'DT', 'NN', 'NN', '.'],
#  ['PRP', 'VBP', 'RB', 'VB', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'NN', 'IN', 'NNS', 'IN', 'NN', '.'],
#  ['VB', 'PRP', 'VB', 'NN', '.'],
#  ['UH', 'VB', 'RP', '.'],
#  ['WRB', 'IN', 'NN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'DT', 'JJ', 'NN', 'NN', 'NN', '.'],
#  ['WRB', 'IN', 'JJ', 'NN', '.'],
#  ['PRP', 'VBP', 'JJR', 'NN', 'IN', 'NN', 'POS', '.'],
#  ['PRP', 'MD', 'VB', 'DT', 'NN', 'IN', 'NN', 'IN', 'JJ', 'NN', 'NN', '.'],
#  ['MD', 'PRP', 'VB', 'DT', 'NN', 'IN', 'PRP', '.'],
#  ['WP',
#   'VBZ',
#   'DT',
#   'JJ',
#   'JJ',
#   'NN',
#   'CC',
#   'JJ',
#   'NNS',
#   'IN',
#   'JJ',
#   'NN',
#   '.'],
#  ['UH', 'PRP', 'MD', 'VB', 'DT', 'JJ', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'IN', 'TO', 'CD', 'NNS', 'IN', 'NN', '.'],
#  ['VB', 'RP', '.'],
#  ['PRP', 'VBP', 'RB', 'VB', 'TO', 'VB', 'JJR', 'IN', 'CD', 'NNS', '.'],
#  ['CD', 'NNS', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'JJ', 'NN', '.'],
#  ['RB', 'JJR', 'IN', 'CD', 'NNS', '.'],
#  ['WRB', 'JJ', 'VBZ', 'NN', 'HYPH', 'NN', 'JJ', '.'],
#  ['DT', 'CD', 'NNS', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'NN',
#   'NN',
#   'CC',
#   'UH',
#   'PRP',
#   'VBZ',
#   'RB',
#   'RB',
#   'VB',
#   'WRB',
#   'PRP',
#   'VBZ',
#   '.'],
#  ['WRB', 'RB', 'IN', 'NN', 'VBZ', 'NN', 'POS', 'NN', '.'],
#  ['NN', '.'],
#  ['MD',
#   'PRP',
#   'VB',
#   'PRP',
#   'NN',
#   'RB',
#   'RB',
#   'RB',
#   'IN',
#   'CD',
#   'NNS',
#   'CC',
#   'WRB',
#   'PRP',
#   'MD',
#   'VB',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['VB', 'PRP', 'PRP', 'VBD', 'RB', 'VB', '.'],
#  ['PRP',
#   'VBP',
#   'VBG',
#   'JJ',
#   'NNP',
#   'RB',
#   'RB',
#   'RB',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBP',
#   'VBN',
#   'DT',
#   'NN',
#   'CC',
#   'RB',
#   'PRP',
#   'VBP',
#   'JJ',
#   'TO',
#   'VB',
#   'RB',
#   'VB',
#   'PRP',
#   'RB',
#   'RB',
#   'IN',
#   'CD',
#   'NNS',
#   'RB',
#   'IN',
#   'NN',
#   '.'],
#  ['PRP', 'MD', 'VB', 'NN', 'NN', 'IN', 'DT', 'JJ', 'NN', 'UH', '.'],
#  ['WP', 'IN', 'NNP', '.'],
#  ['NNS', 'JJ', 'IN', 'NN', '.'],
#  ['RB', 'UH', 'UH', 'VB', 'PRP', 'DT', 'JJS', 'JJ', 'NN', 'IN', 'NN', '.'],
#  ['PRP', 'VBP', 'JJ', '.'],
#  ['VBP', 'PRP', 'VB', 'DT', 'NN', 'VBN', 'IN', 'PRP$', 'NN', '.'],
#  ['JJ', 'NN', 'MD', 'VB', 'JJ', '.'],
#  ['PRP',
#   'VBZ',
#   'TO',
#   'VB',
#   'RB',
#   'JJ',
#   'IN',
#   'NN',
#   'CC',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'UH',
#   'RB',
#   'RB',
#   'JJ',
#   '.'],
#  ['UH', 'UH', 'UH', 'VB', 'PRP', 'IN', 'UH', 'JJR', 'UH', 'JJ', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'IN', 'VBG', 'NN', '.'],
#  ['WRB', 'VBZ', 'DT', 'JJ', 'NN', 'NN', 'JJ', '.'],
#  ['VB', 'PRP', 'IN', 'NNS', '.'],
#  ['VB', 'PRP', 'VB', 'RB', '.'],
#  ['VBP', 'PRP', 'VB', 'NN', 'IN', 'NNS', '.'],
#  ['VB', 'RP', '.'],
#  ['NN',
#   'POS',
#   'NN',
#   'NN',
#   'POS',
#   'JJ',
#   'NN',
#   'NN',
#   'HYPH',
#   'NN',
#   'NN',
#   'HYPH',
#   'VBG',
#   'NN',
#   '.'],
#  ['JJ', 'NN', '.'],
#  ['UH',
#   'DT',
#   'MD',
#   'VB',
#   'JJ',
#   'NN',
#   'UH',
#   'VB',
#   'IN',
#   'CD',
#   'CC',
#   'CD',
#   'NN',
#   'IN',
#   'NN',
#   'CC',
#   'PRP',
#   'MD',
#   'VB',
#   'VBG',
#   'IN',
#   'NN',
#   'RB',
#   'PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'PRP',
#   'RB',
#   'RB',
#   'IN',
#   'NN',
#   '.'],
#  ['MD', 'VB', 'IN', 'TO', 'CD', 'NNS', 'IN', 'NN', '.'],
#  ['MD',
#   'PRP',
#   'VB',
#   'PRP',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   'HYPH',
#   'FW',
#   'NN',
#   'CC',
#   'NN',
#   '.'],
#  ['PRP',
#   'RB',
#   'VBP',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'RB',
#   'JJR',
#   'IN',
#   'CD',
#   'NNS',
#   'CC',
#   'PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'TO',
#   'VB',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'DT', 'JJ', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'NNS', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'JJ', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'DT', 'JJ', 'NN', 'NN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'RB', 'IN', 'NN', '.'],
#  ['DT', 'NN', 'DT', 'NN', 'DT', 'JJ', 'JJ', 'NN', 'VBG', 'HYPH', 'NN', '.'],
#  ['VBP', 'EX', 'DT', 'DT', 'NN', 'IN', 'CD', 'NNS', 'IN', 'NN', '.'],
#  ['UH', 'RP', 'TO', 'RB', 'UH', 'CD', 'NNS', '.'],
#  ['WRB', 'VBZ', 'UH', 'FW', 'FW', 'VBN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'DT', 'NNS', '.'],
#  ['UH', 'TO', 'VB', 'DT', 'NN', '.'],
#  ['WRB', 'VBZ', 'UH', 'FW', 'FW', 'VBN', '.'],
#  ['WDT', 'NN', 'VBZ', 'IN', 'CD', 'NNS', 'IN', 'NNS', '.'],
#  ['UH', 'WRB', 'VBZ', 'DT', 'NN', 'HYPH', 'VBG', 'NN', 'NN', 'NN', 'VBN', '.'],
#  ['NN', '.'],
#  ['IN', 'FW', 'FW', 'NN', 'VBZ', 'DT', 'NN', 'NN', '.'],
#  ['VB', 'RP', '.'],
#  ['VBP', 'NN', 'NN', 'NN', 'NN', 'POS', 'NN', 'NN', '.'],
#  ['WRB', 'MD', 'PRP', 'VB', 'TO', 'VB', 'JJ', 'NN', '.'],
#  ['VBD', 'NN', 'WDT', 'NN', 'IN', 'NN', 'VBZ', 'DT', '.'],
#  ['NN',
#   'HYPH',
#   'NN',
#   'NN',
#   'HYPH',
#   'NN',
#   'NN',
#   'HYPH',
#   'NN',
#   'NN',
#   'NN',
#   'POS',
#   'NN',
#   'NN',
#   'NN',
#   '.'],
#  ['MD', 'PRP', 'VB', 'PRP', 'DT', 'NN', 'IN', 'NNP', 'POS', 'NN', '.'],
#  ['MD', 'PRP', 'VB', 'PRP', 'RBR', 'IN', 'NN', 'NN', '.'],
#  ['WRB', 'JJ', 'NN', 'NNS', 'VBP', 'JJR', 'IN', 'CD', 'NNS', 'IN', 'NN', '.'],
#  ['VB', 'PRP', 'NN', '.'],
#  ['PRP', 'VBP', 'NN', 'IN', 'NN', 'NN', '.'],
#  ['WP', 'NN', 'IN', 'JJ', 'NNS', 'VBP', 'RB', 'IN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'NN', 'IN', 'NNS', 'IN', 'NN', '.'],
#  ['DT',
#   'NN',
#   'IN',
#   'NN',
#   'VBZ',
#   'VBN',
#   'IN',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   'CC',
#   'NN',
#   'VBP',
#   'RB',
#   'VB',
#   '.'],
#  ['VB', 'PRP', 'DT', 'NN', 'NNS', 'IN', 'NN', '.'],
#  ['JJR', 'IN', 'CD', 'CD', 'NNS', 'POS', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'JJ', 'NN', '.'],
#  ['UH', 'PRP', 'VBD', 'PRP', 'JJ', 'PRP', 'VBP', 'TO', 'VB', 'NNS', '.'],
#  ['UH', 'RB', 'RB', 'IN', 'PRP', 'VBZ', 'VBG', 'NN', 'PRP', 'VBZ', 'JJ', '.'],
#  ['WP', 'VBZ', 'JJ', 'NN', 'NN', 'POS', 'NN', 'NN', '.'],
#  ['VB', 'PRP', 'DT', 'NN', 'RBR', 'IN', 'NN', 'NN', '.'],
#  ['UH', 'PRP', 'VBP', 'RB', 'RB', 'JJ', 'RB', 'RB', 'RB', 'NN', '.'],
#  ['PRP', 'VBP', 'JJ', 'IN', 'NN', 'IN', 'NN', '.'],
#  ['RB',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'UH',
#   'NN',
#   'NN',
#   'IN',
#   'VBG',
#   'NN',
#   'RB',
#   'VBZ',
#   'IN',
#   'CD',
#   'NNS',
#   '.'],
#  ['NN', '.'],
#  ['VBZ', 'EX', 'DT', 'JJ', 'JJ', 'NN', 'IN', 'NN', '.'],
#  ['WP', 'VBP', 'PRP', 'VB', 'IN', 'NN', 'NN', 'POS', 'NN', '.'],
#  ['PRP', 'VBP', 'DT', 'NN', 'NN', 'NN', 'UH', '.'],
#  ['WRB', 'JJ', 'VBZ', 'VBN', 'NN', 'NN', '.'],
#  ['VB',
#   'PRP',
#   'VB',
#   'NNS',
#   'IN',
#   'DT',
#   'CD',
#   'NN',
#   'TO',
#   'CD',
#   'NN',
#   'NN',
#   '.'],
#  ['JJ', 'NN', '.'],
#  ['VB', 'PRP', 'VB', 'NN', '.'],
#  ['UH', 'WRB', 'IN', 'DT', 'NN', 'IN', 'NN', '.'],
#  ['MD', 'VB', 'PRP', 'RBR', 'IN', 'NNS', 'VBN', '.'],
#  ['MD', 'PRP', 'VB', 'PRP', 'DT', 'JJ', 'JJR', 'IN', 'NNS', '.'],
#  ['VB', 'PRP', 'RBR', 'IN', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'IN', 'NN', '.'],
#  ['CD', 'CD', '.'],
#  ['UH',
#   'PRP',
#   'VBD',
#   'RB',
#   'VB',
#   'JJ',
#   'CC',
#   'PRP',
#   'VBD',
#   'RB',
#   'VB',
#   'JJ',
#   'PRP',
#   'VBD',
#   'PRP',
#   'VBD',
#   'DT',
#   'NN',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'JJ', 'NN', '.'],
#  ['VBP', 'PRP', 'VB', 'NNS', 'NN', '.'],
#  ['JJ', 'NN', 'NN', 'NN', 'NN', 'FW', 'FW', 'JJ', 'NN', '.'],
#  ['NN', 'POS', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'IN', 'NN', 'HYPH', 'NN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'DT', 'NN', 'CC', 'DT', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'JJR', 'IN', 'NNS', '.'],
#  ['VBP', 'PRP', 'VB', 'NN', 'NN', 'HYPH', 'NN', '.'],
#  ['UH', 'NN', 'VBP', 'EX', 'DT', 'JJ', 'JJ', 'NNS', 'IN', 'NN', '.'],
#  ['PRP', 'VBP', 'CD', 'NNS', 'IN', 'PRP', '.'],
#  ['WRB', 'VBZ', 'DT', 'NN', 'WDT', 'NN', 'JJ', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'WDT',
#   'VBZ',
#   'IN',
#   'JJS',
#   'CD',
#   'NNS',
#   'RB',
#   'IN',
#   'VBG',
#   'IN',
#   'IN',
#   'JJS',
#   'CD',
#   'NNS',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'IN',
#   'NNP',
#   'CC',
#   'NNP',
#   'CC',
#   'NNP',
#   'CC',
#   'IN',
#   'NN',
#   'CC',
#   'PRP$',
#   'JJ',
#   'NN',
#   'VBZ',
#   'VBN',
#   '.'],
#  ['NN', 'NN', 'NN', 'POS', 'NN', 'NN', 'NN', 'HYPH', 'NN', '.'],
#  ['UH',
#   'UH',
#   'PRP',
#   'VBP',
#   'DT',
#   'JJ',
#   'CC',
#   'PRP$',
#   'NN',
#   'VBZ',
#   'UH',
#   'DT',
#   'NN',
#   'NN',
#   'RB',
#   'UH',
#   'PRP',
#   'VBZ',
#   'VBG',
#   'JJ',
#   'NN',
#   'IN',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN',
#   'WDT',
#   'VBZ',
#   'DT',
#   'IN',
#   'PRP',
#   'VBP',
#   'DT',
#   'MD',
#   'VB',
#   'VBN',
#   '.'],
#  ['PRP', 'VBP', 'DT', 'NN', 'IN', 'NN', 'NN', 'POS', '.'],
#  ['PRP', 'VBP', 'NN', 'IN', 'JJ', 'NN', 'CC', 'DT', 'NNS', '.'],
#  ['RB',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'RB',
#   'CD',
#   'NNS',
#   'IN',
#   'NN',
#   'CC',
#   'PRP',
#   'MD',
#   'RB',
#   'VB',
#   'DT',
#   'JJR',
#   'IN',
#   'CD',
#   'NNS',
#   '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'JJ',
#   'NN',
#   'CC',
#   'RB',
#   'JJ',
#   'IN',
#   'NN',
#   '.'],
#  ['VBP', 'EX', 'DT', 'JJ', 'NN', 'NNS', 'RB', 'RB', '.'],
#  ['WP',
#   'PRP',
#   'RB',
#   'VBD',
#   'VBZ',
#   'IN',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'RB',
#   'JJ',
#   '.'],
#  ['PRP', 'MD', 'VB', 'PRP', 'TO', 'VB', 'IN', 'VBG', 'NN', 'IN', 'NNS', '.'],
#  ['PRP', 'VBP', 'NN', 'IN', 'NN', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'JJR',
#   'IN',
#   'DT',
#   'HYPH',
#   'NNP',
#   'HYPH',
#   'NNP',
#   'VBZ',
#   'IN',
#   'JJ',
#   '.'],
#  ['VBP', 'PRP', 'VB', 'DT', 'CD', 'NN', 'NN', '.'],
#  ['VB', 'RP', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'JJ', 'NN', 'UH', '.'],
#  ['UH', 'RB', 'CD', 'NNS', '.'],
#  ['UH',
#   'PRP',
#   'VBP',
#   'RB',
#   'JJ',
#   'IN',
#   'UH',
#   'NN',
#   'IN',
#   'NNP',
#   'RB',
#   'RB',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['VB', 'RP', '.'],
#  ['VB', 'RP', '.'],
#  ['PRP', 'VBD', 'WRB', 'IN', 'NNS', '.'],
#  ['UH', 'VB', 'PRP', 'IN', 'NN', 'HYPH', 'NN', 'HYPH', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'JJ', 'NN', '.'],
#  ['UH', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'NN', '.'],
#  ['WRB', 'JJ', 'VBZ', 'JJ', 'NN', '.'],
#  ['EX', 'VBZ', 'DT', 'NN', 'IN', 'NN', 'NN', 'WP', 'IN', 'DT', 'NN', '.'],
#  ['UH', 'NN', 'VBP', 'EX', 'DT', 'JJ', 'JJ', 'NNS', 'IN', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'IN', 'DT', 'NN', 'HYPH', 'NN', 'NN', '.'],
#  ['PRP', 'VBP', 'JJ', 'NN', 'JJ', 'NN', '.'],
#  ['VB', 'PRP', 'VB', 'DT', 'NN', 'IN', 'NN', 'RB', 'CD', 'NNS', 'NN', '.'],
#  ['WRB', 'MD', 'PRP', 'VB', 'DT', 'JJ', 'NN', 'NN', '.'],
#  ['PRP',
#   'MD',
#   'VBD',
#   'RB',
#   'VB',
#   'TO',
#   'VB',
#   'IN',
#   'NNS',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'IN',
#   'NN',
#   'CC',
#   'NN',
#   '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'CC',
#   'MD',
#   'PRP',
#   'VB',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   '.'],
#  ['PRP', 'VBP', 'VBG', 'IN', 'NNS', 'VBG', 'JJ', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'JJR', 'IN', 'CD', 'NNS', '.'],
#  ['UH',
#   'PRP',
#   'VBP',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'RB',
#   'IN',
#   'NN',
#   'RB',
#   'RB',
#   'JJ',
#   'RB',
#   'JJ',
#   'NN',
#   'CC',
#   'RB',
#   'JJ',
#   'CC',
#   'RB',
#   'JJ',
#   'NN',
#   'RB',
#   '.'],
#  ['VB', 'PRP', 'IN', 'NN', 'NNS', '.'],
#  ['PRP', 'MD', 'VB', 'NN', 'IN', 'JJ', 'NN', 'NN', '.'],
#  ['WP', 'VBP', 'PRP', 'VB', 'RB', 'CD', 'CD', 'NNS', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'NN', 'IN', 'NNP', 'NNP', 'POS', 'NN', '.'],
#  ['UH', 'VBP', 'PRP', 'VB', 'DT', 'JJ', 'JJ', 'NN', '.'],
#  ['RB',
#   'HYPH',
#   'FW',
#   'FW',
#   'FW',
#   'NN',
#   'NN',
#   'POS',
#   'NN',
#   'NN',
#   'NN',
#   'POS',
#   'NN',
#   'JJ',
#   'NN',
#   '.'],
#  ['WRB', 'VBZ', 'DT', 'JJ', 'NN', 'NN', 'JJ', 'IN', 'NN', '.'],
#  ['VBP', 'PRP', 'JJ', 'UH', 'CC', 'VB', 'RP', '.'],
#  ['PRP',
#   'VBP',
#   'PRP$',
#   'NN',
#   'RB',
#   'UH',
#   'RB',
#   'PRP',
#   'VBP',
#   'PRP',
#   'MD',
#   'VB',
#   'JJS',
#   'UH',
#   'IN',
#   'RB',
#   'CD',
#   'NNS',
#   '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['VB', 'PRP', 'RBR', 'IN', 'NNS', '.'],
#  ['PRP', 'VBZ', 'RB', 'VB', 'PRP', 'VBP', 'RB', 'VB', 'WRB', 'RB', '.'],
#  ['WRB', 'MD', 'PRP', 'VB', 'TO', 'VB', 'DT', 'NN', '.'],
#  ['UH', 'UH', 'WRB', 'IN', 'JJ', 'CC', 'JJ', 'CC', 'UH', 'JJ', 'NN', '.'],
#  ['VBP', 'PRP', 'VB', 'IN', 'DT', 'NNS', 'VBG', 'JJ', 'NN', '.'],
#  ...]

# %%
# sequence_tokens = [['i', "'d", 'like', 'food', '.'], ['as', 'far', 'away', 'as', 'we', 'can', 'get', '.']]

### 3. 
# Use training data and the UNK counts to build transition and emission matrices
list_of_tags, list_of_words, word_count, transition_probs, emission_probs = build_lists_and_probabilities(train_set, train_tags, train_words, unk_count)

### 5. 
# Run viterbi function on test set, get list of tags 
sequence_tags = []
for seq in sentences:
    p, back, best_path_pointer, best_path_prob = viterbi_pos_tagger(list_of_tags, seq, transition_probs, emission_probs)
    output_tags = backtrace(back, best_path_pointer, seq)
    sequence_tags.append(output_tags)

sequence_tags
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-5b7320508a66> in <module>()
#       3 ### 3.
#       4 # Use training data and the UNK counts to build transition and emission matrices
# ----> 5 list_of_tags, list_of_words, word_count, transition_probs, emission_probs = build_lists_and_probabilities(train_set, train_tags, train_words, unk_count)
#       6
#       7 ### 5.
#
# <ipython-input-27-895e93011cd5> in build_lists_and_probabilities(train_data, set_of_tags, set_of_words, unk_count)
#      33
#      34     # For UNK words, count from corpus
# ---> 35     word_count["UNK"] = UNK_count
#      36
#      37     # Combine tag set and word set
#
# NameError: name 'UNK_count' is not defined

# %%
sequence_tags
# Out:
# [['VB', 'PRP', 'RB', 'NNP', 'HYPH', 'VBG', '.'],
#  ['UH', 'VB', 'PRP', 'VBZ', 'NN', 'WDT', 'DT', 'VBZ', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'NNP', '.'],
#  ['UH', 'WP', 'RB', 'CD', 'NNS', 'WDT', 'VBZ', 'VBP', '.'],
#  ['WRB', 'UH', '.'],
#  ['WRB', 'VBZ', 'VBP', 'TO', 'TO', 'VB', 'NNS', '.'],
#  ['PRP', 'VBP', 'VB', 'RB', 'VB', 'TO', 'VB', '.'],
#  ['WRB', 'VBZ', '.'],
#  ['WRB', 'VBZ', 'PRP', 'VBP', 'TO', 'WDT', 'DT', 'VBZ', 'NNS', '.'],
#  ['VBZ', 'WDT', 'NN', '.'],
#  ['VB',
#   'PRP',
#   'VBP',
#   'IN',
#   'UH',
#   'VBZ',
#   'CC',
#   'UH',
#   'PRP',
#   'VBP',
#   'TO',
#   'VBZ',
#   '.'],
#  ['WRB',
#   'VBZ',
#   'WDT',
#   'TO',
#   'VBZ',
#   'VBZ',
#   'VBZ',
#   'VBZ',
#   'VBZ',
#   'CC',
#   'UH',
#   'VBP',
#   '.'],
#  ['UH', 'VB', 'DT', 'NNS', '.'],
#  ['VB', 'PRP', 'VBP', 'TO', 'NNS', 'WDT', 'NNP', '.'],
#  ['VBP', 'VBG', 'NN', '.'],
#  ['WRB',
#   'JJR',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'VBZ',
#   'VBZ',
#   'NN',
#   'VBZ',
#   'VBZ',
#   'VBZ',
#   'NN',
#   'WDT',
#   'NN',
#   '.'],
#  ['WRB', 'IN', 'VBG', 'VB', 'UH', '.'],
#  ['PRP', 'VBP', 'VB', 'TO', 'NN', 'WDT', 'NNP', '.'],
#  ['WRB', 'WRB', 'VBP', 'RB', 'DT', 'NN', 'VBZ', 'NNS', 'WDT', 'NNP', '.'],
#  ['WRB', 'VBG', 'NN', 'WDT', 'UH', '.'],
#  ['WRB', 'VBZ', 'VBP', 'RB', '.'],
#  ['WP', 'VBP', 'TO', 'VBP', 'RB', 'UH', 'NN', '.'],
#  ['PRP', 'VBP', 'RB', 'VB', 'VBZ', 'WP', 'VBZ', 'WDT', 'NN', '.'],
#  ['UH',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'NN',
#   'NN',
#   'WDT',
#   'VBG',
#   'RB',
#   'IN',
#   'DT',
#   'NNS',
#   'WDT',
#   'VBG',
#   '.'],
#  ['WRB',
#   'VBZ',
#   'VBZ',
#   'VBG',
#   'TO',
#   'VB',
#   'RP',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'WRB',
#   'VB',
#   'NN',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'UH', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'WDT', 'IN', 'UH', 'UH', '.'],
#  ['VB', 'PDT', 'DT', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'UH', 'IN', 'DT', 'VBZ', 'NNS', '.'],
#  ['PRP', 'VBP', 'VBG', 'VBZ', 'IN', 'NN', '.'],
#  ['WRB',
#   'DT',
#   'UH',
#   'PRP',
#   'UH',
#   'VBP',
#   'PRP',
#   'VBP',
#   'NN',
#   'RB',
#   'UH',
#   'VB',
#   'NN',
#   'NN',
#   'WDT',
#   'UH',
#   'VBZ',
#   'VBZ',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN',
#   'WDT',
#   'PRP',
#   'VBZ',
#   '.'],
#  ['PRP', 'VBP', 'VBG', 'VB', 'TO', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   'NN',
#   'CC',
#   'RB',
#   'PRP',
#   'VBP',
#   'TO',
#   'NN',
#   'UH',
#   '.'],
#  ['UH', 'VB', 'VB', 'VB', 'PRP', 'VBZ', 'VBG', 'NN', 'VBZ', 'VBZ', 'UH', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'VB',
#   'NN',
#   'UH',
#   'NN',
#   'WDT',
#   'NN',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'VBZ', 'NN', 'TO', 'NN', 'CC', 'DT', 'JJR', 'UH', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'MD',
#   'NN',
#   'VBZ',
#   'TO',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'WDT',
#   'DT',
#   'NN',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'UH', 'VB', 'NN', '.'],
#  ['VBP', 'TO', 'VB', 'TO', 'WDT', 'VBZ', 'RB', 'RB', 'WDT', 'NN', '.'],
#  ['VBZ', 'RP', '.'],
#  ['VBP', 'RB', 'DT', 'NNS', 'WDT', 'VBZ', 'NNP', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'UH', 'VB', 'TO', 'NN', 'WDT', 'NN', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'UH',
#   'WP',
#   'UH',
#   'TO',
#   'VB',
#   'PRP',
#   'MD',
#   'VB',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   'VB',
#   'WP',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'UH',
#   'NN',
#   '.'],
#  ['WRB', 'PRP', 'VBP', 'PRP', 'VBP', 'NN', 'WDT', 'DT', 'VBZ', 'NN', '.'],
#  ['WRB', 'RB', 'TO', 'NN', 'WDT', 'NNP', 'VBZ', '.'],
#  ['WRB', 'VB', 'TO', 'VB', 'NN', 'NN', 'WDT', 'NNP', '.'],
#  ['PRP', 'VBP', 'VBG', 'VB', 'RP', 'TO', 'NN', 'WDT', 'NN', 'NN', '.'],
#  ['UH',
#   'WP',
#   'VBZ',
#   'VBP',
#   'WDT',
#   'VBZ',
#   'RB',
#   'VBZ',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   'VB',
#   'NN',
#   'NN',
#   'RB',
#   'VBD',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'DT', 'NN', '.'],
#  ['UH', 'VB', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'UH', '.'],
#  ['WRB', 'RB', 'UH', 'HYPH', 'NN', '.'],
#  ['WRB', 'RB', 'DT', 'NN', 'NN', 'WDT', 'NN', '.'],
#  ['VB', 'VB', '.'],
#  ['DT', 'NN', 'WDT', 'VB', 'TO', 'IN', 'DT', 'TO', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'DT',
#   'RB',
#   'VB',
#   'NN',
#   'TO',
#   'VB',
#   'TO',
#   'WDT',
#   'VB',
#   '.'],
#  ['VBP', 'TO', 'VBP', 'RB', 'DT', 'NN', 'NNS', '.'],
#  ['PRP', 'VBZ', 'RB', 'VB', 'WRB', 'VBZ', 'PRP', 'VBZ', 'RB', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'NN', '.'],
#  ['VBP', 'TO', 'VBP', 'VBG', 'WDT', 'DT', 'NN', 'WDT', '.'],
#  ['WRB', 'PRP', 'VBP', 'PRP', 'VBP', 'VBZ', '.'],
#  ['WRB', 'VBZ', 'VBZ', 'NN', 'VBZ', 'RB', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   'CC',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   'NN',
#   '.'],
#  ['WRB', 'RB', 'VBG', 'NN', '.'],
#  ['VBZ', 'RB', 'DT', 'NN', 'NN', 'RB', '.'],
#  ['WRB', 'RB', 'NNP', 'CC', 'VBZ', 'RB', 'VBZ', '.'],
#  ['VBP', 'NN', '.'],
#  ['PRP', 'VBP', 'VBZ', '.'],
#  ['VBP', 'TO', 'VBP', 'TO', 'RB', 'DT', 'VBZ', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'NNP', '.'],
#  ['VB', 'NNP', 'NNS', 'WDT', 'VB', '.'],
#  ['WP', 'VBZ', 'PRP', 'VBP', 'DT', 'NN', 'WDT', '.'],
#  ['WRB', 'NN', 'VBZ', 'CC', 'PRP', 'VBP', 'UH', 'VB', 'MD', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'WP', 'DT', 'NNS', '.'],
#  ['UH',
#   'VB',
#   'VBZ',
#   'VBP',
#   'RB',
#   'VB',
#   'DT',
#   'NN',
#   'TO',
#   'CC',
#   'PRP',
#   'VBP',
#   'VB',
#   'RB',
#   'RB',
#   'NNS',
#   '.'],
#  ['WRB', 'VBZ', 'DT', 'NN', 'WDT', 'NN', 'WDT', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'WDT',
#   'VBZ',
#   'VBG',
#   'VBG',
#   'NN',
#   'WDT',
#   'NN',
#   '.'],
#  ['PRP', 'VBP', 'VBG', 'IN', 'DT', 'VBZ', 'VB', 'TO', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'WDT', 'NNP', 'HYPH', 'NNP', '.'],
#  ['UH', 'VBZ', 'VBZ', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'WP',
#   'VB',
#   'NN',
#   'NN',
#   'WDT',
#   'NN',
#   'WDT',
#   'DT',
#   'NN',
#   'WDT',
#   'VBG',
#   '.'],
#  ['WRB', 'PRP', 'VBP', 'TO', 'NN', 'RB', 'RB', 'NN', 'VBZ', 'NN', '.'],
#  ['PRP', 'VBP', 'VBG', 'IN', 'DT', 'NN', 'WDT', 'UH', 'VBZ', '.'],
#  ['WRB', 'NN', 'PRP', 'VBP', 'TO', 'VB', 'UH', 'NN', '.'],
#  ['WRB', 'NN', '.'],
#  ['VB', 'PRP', 'RB', 'NN', 'VBZ', '.'],
#  ['VBP', 'TO', 'VBP', 'TO', 'RB', 'DT', 'NN', 'WDT', 'VBZ', 'VBZ', '.'],
#  ['PRP', 'VBP', 'RB', 'VBZ', 'WP', 'VBZ', '.'],
#  ['WP', 'VBZ', 'WDT', 'UH', 'NNS', 'WDT', 'RB', 'VBD', 'NNP', '.'],
#  ['VB', 'PRP', 'RB', 'DT', 'VBD', 'VBZ', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VBZ',
#   'CC',
#   'PRP',
#   'MD',
#   'VB',
#   'WRB',
#   'WDT',
#   'NNS',
#   '.'],
#  ['UH', 'WRB', 'PRP', 'VBP', 'PRP', 'MD', 'VB', 'TO', 'VB', 'UH', 'VB', '.'],
#  ['PRP', 'VBP', 'TO', 'NN', 'NN', 'NN', 'VBZ', 'WDT', 'UH', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'NN', '.'],
#  ['WRB', 'DT', 'NN', 'VB', 'RP', 'VB', '.'],
#  ['WRB', 'PRP', 'VBP', 'PRP', 'VBP', 'VBZ', 'IN', 'DT', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'UH', 'VB', 'NN', '.'],
#  ['VBP', 'TO', 'VBP', 'TO', 'RB', 'VBG', 'WDT', 'UH', '.'],
#  ['WRB',
#   'HYPH',
#   'NNP',
#   'VBZ',
#   'VBZ',
#   'DT',
#   'NN',
#   'WDT',
#   'UH',
#   'WDT',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBZ',
#   'RB',
#   'PRP',
#   '.'],
#  ['WRB', 'WDT', 'NNS', 'CC', 'JJR', 'NN', 'VB', 'TO', '.'],
#  ['VBZ', 'RP', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', '.'],
#  ['WRB', 'IN', 'NN', 'TO', '.'],
#  ['VB', 'PRP', 'VBP', 'IN', 'TO', 'VBZ', 'NN', '.'],
#  ['DT', 'NN', 'WDT', 'VB', 'TO', 'IN', 'NN', 'TO', 'WDT', 'VBG', '.'],
#  ['VB', 'PRP', 'RB', 'NN', 'VBZ', '.'],
#  ['UH',
#   'UH',
#   'WRB',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBP',
#   'VB',
#   'MD',
#   'NNS',
#   'RB',
#   'UH',
#   'VBZ',
#   '.'],
#  ['WRB', 'PRP', 'VBP', 'DT', 'NN', 'WDT', 'VBG', '.'],
#  ['VB', 'CD', 'NNS', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'UH',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   'NN',
#   'VBZ',
#   'RB',
#   'WDT',
#   'VBZ',
#   'VB',
#   'WRB',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   '.'],
#  ['WRB', 'RB', 'PRP$', 'NN', 'WDT', 'NN', '.'],
#  ['UH', 'PRP', 'VBP', 'TO', 'MD', 'NN', '.'],
#  ['WRB', 'VBZ', 'PRP', 'VBZ', 'DT', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'PRP', 'VB', 'NN', '.'],
#  ['WP', 'VBZ', 'WDT', 'NN', 'WDT', 'TO', 'VBP', 'TO', 'VBG', '.'],
#  ['WRB', 'RB', 'VB', 'NN', 'NN', '.'],
#  ['UH', 'WRB', 'VB', 'NN', '.'],
#  ['UH',
#   'WRB',
#   'TO',
#   'VB',
#   'NN',
#   'WDT',
#   'NN',
#   'NNS',
#   'VBP',
#   'VBP',
#   'PRP',
#   'VBP',
#   '.'],
#  ['WRB',
#   'VBZ',
#   'VBP',
#   'VBZ',
#   'WDT',
#   'DT',
#   'VBZ',
#   'TO',
#   'TO',
#   'CD',
#   'TO',
#   'VBZ',
#   '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'WP',
#   'VB',
#   'NN',
#   'NN',
#   'WDT',
#   'NN',
#   'WDT',
#   'DT',
#   'NN',
#   'WDT',
#   'VBG',
#   '.'],
#  ['VBP', 'TO', 'VBP', 'TO', 'DT', 'NN', 'VBZ', 'NNS', '.'],
#  ['WP', 'IN', 'DT', 'NN', 'WDT', 'DT', 'NN', '.'],
#  ['PRP', 'VBP', 'RB', 'VBP', 'TO', 'VB', 'TO', 'UH', 'VBZ', '.'],
#  ['WRB',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBP',
#   'IN',
#   'UH',
#   'NN',
#   'TO',
#   'VB',
#   'TO',
#   'VB',
#   'RP',
#   'UH',
#   'WRB',
#   'VBZ',
#   '.'],
#  ['WRB', 'IN', 'DT', 'NN', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', 'VB', 'TO', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'RP', 'WDT', 'UH', 'NN', '.'],
#  ['WRB', 'HYPH', 'NNP', '.'],
#  ['PRP', 'VBP', 'TO', 'VBP', 'DT', 'NN', '.'],
#  ['WRB', '.'],
#  ['WRB',
#   'NN',
#   'VBZ',
#   'NN',
#   'WDT',
#   'FW',
#   'POS',
#   'VBZ',
#   'POS',
#   'NN',
#   'FW',
#   'NN',
#   'VBZ',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'VBZ', '.'],
#  ['VB', 'DT', 'NNS', '.'],
#  ['PRP', 'VBP', 'TO', 'TO', 'VB', 'RP', 'TO', 'VB', 'TO', '.'],
#  ['DT', 'NN', 'VBZ', 'RB', 'NNS', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'WDT',
#   'NNP',
#   'UH',
#   'WDT',
#   'VBZ',
#   'DT',
#   'VBZ',
#   'VBZ',
#   'WDT',
#   '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'DT',
#   'NN',
#   'NN',
#   'NN',
#   'PRP',
#   'VBP',
#   'RB',
#   'VBP',
#   'WRB',
#   'PRP',
#   'MD',
#   'VB',
#   'WP',
#   'PRP',
#   'VBZ',
#   'PRP',
#   'VBZ',
#   '.'],
#  ['WP', 'IN', 'TO', 'VBZ', '.'],
#  ['WRB',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBP',
#   'IN',
#   'NNP',
#   'VBZ',
#   'NN',
#   'VBZ',
#   'VBZ',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'WP',
#   'VB',
#   'NN',
#   'NN',
#   'WDT',
#   'NN',
#   'WDT',
#   'DT',
#   'NN',
#   'WDT',
#   'VBG',
#   '.'],
#  ['VB', 'PRP', 'RB', 'NN', 'WDT', '.'],
#  ['WRB', 'VBZ', 'PRP', 'VBP', 'TO', 'VB', 'WRB', '.'],
#  ['VB', 'PRP', 'RB', 'NNS', 'WDT', 'NNS', 'RB', 'VB', 'VBG', '.'],
#  ['VBP', 'TO', 'VBP', 'TO', 'NN', 'NNS', 'WDT', 'VBZ', 'VBN', 'VB', 'TO', '.'],
#  ['WRB', 'PRP', 'VBP', 'PRP', 'VBP', 'IN', 'NN', 'NN', '.'],
#  ['UH',
#   'UH',
#   'PRP',
#   'VBP',
#   'TO',
#   'NN',
#   'NN',
#   'PRP$',
#   'VBD',
#   'VBZ',
#   'UH',
#   'VB',
#   'NN',
#   'VBZ',
#   'RB',
#   'UH',
#   'WRB',
#   'VBZ',
#   'VBG',
#   'VB',
#   'NN',
#   'RB',
#   'VBZ',
#   'VBP',
#   'TO',
#   'NN',
#   'WDT',
#   'VBZ',
#   'VBZ',
#   'VBZ',
#   'PRP',
#   'VBP',
#   'VBG',
#   'VBZ',
#   'VB',
#   'WP',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'TO', 'VB', 'TO', 'NNS', 'RB', '.'],
#  ['VBZ', 'RP', 'RB', '.'],
#  ['WRB', 'VBZ', 'PRP', 'VBP', 'TO', 'UH', '.'],
#  ['VB',
#   'PRP',
#   'VBP',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   'NN',
#   'WDT',
#   'PRP',
#   'NN',
#   'WDT',
#   'DT',
#   'NN',
#   'WDT',
#   'VBZ',
#   'VBP',
#   'TO',
#   'VB',
#   'VBD',
#   '.'],
#  ['UH', 'VB', 'PRP', 'VBP', 'IN', 'VBG', 'NN', 'VBZ', '.'],
#  ['VB', 'PDT', 'DT', 'NN', '.'],
#  ['UH', 'UH', 'WP', 'VBP', 'TO', 'UH', 'WDT', 'DT', 'NN', 'VBZ', '.'],
#  ['PRP', 'VBP', 'TO', 'NN', 'WDT', 'NN', 'RB', 'VB', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'DT', 'NN', 'NN', 'UH', '.'],
#  ['PRP', 'VBP', 'TO', 'RBR', 'NN', 'RB', 'UH', 'CC', 'RB', 'UH', 'NN', '.'],
#  ['WRB', 'PRP', 'VBP', 'PRP', 'VBZ', 'VB', 'NN', 'WDT', 'NNS', 'RB', '.'],
#  ['RB', 'RBR', 'IN', 'CD', 'NNS', '.'],
#  ['WRB', 'PRP', 'VBP', 'PRP', 'RB', 'NNP', 'HYPH', 'NNP', '.'],
#  ['VB', 'VB', 'PRP', 'RB', 'VB', 'VBZ', 'UH', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'NN', 'VBZ', 'TO', 'WDT', 'VBZ', 'WDT', '.'],
#  ['DT',
#   'NN',
#   'WDT',
#   'VB',
#   'RB',
#   'VB',
#   'UH',
#   'RBR',
#   'IN',
#   'DT',
#   'VBZ',
#   'NNS',
#   'WDT',
#   'VB',
#   '.'],
#  ['VBZ',
#   'VB',
#   'HYPH',
#   'VBG',
#   'TO',
#   'WDT',
#   'VBG',
#   'VB',
#   'VBG',
#   'WDT',
#   'NN',
#   'WDT',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'NNS', 'IN', 'NN', 'NN', '.'],
#  ['PRP', 'VBP', 'VBZ', 'VBP', '.'],
#  ['UH', 'VB', 'PRP', 'VBP', 'IN', 'UH', 'VBZ', '.'],
#  ['UH', 'VB', 'WDT', 'UH', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', 'DT', 'VBD', '.'],
#  ['WRB', 'VBZ', 'NNP', 'VBP', 'TO', 'RB', 'WDT', 'NN', '.'],
#  ['WRB', 'RB', 'UH', 'NNS', '.'],
#  ['WP', 'VBP', 'TO', 'VBP', 'VBG', 'VB', 'NNS', '.'],
#  ['UH',
#   'WRB',
#   'VBZ',
#   'DT',
#   'NN',
#   'HYPH',
#   'VBG',
#   'TO',
#   'VBZ',
#   'NN',
#   'WDT',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', 'DT', 'NN', 'NN', '.'],
#  ['VBP', 'TO', 'VBP', 'TO', 'HYPH', 'NNP', 'WDT', 'PRP$', 'VBD', '.'],
#  ['PRP', 'VBZ', 'RB', 'VB', 'DT', 'NN', '.'],
#  ['PRP',
#   'VBP',
#   'VB',
#   'RP',
#   'TO',
#   'VB',
#   'NNS',
#   'WDT',
#   'VBG',
#   'CC',
#   'DT',
#   'VBD',
#   'UH',
#   'WP',
#   'IN',
#   'NNP',
#   'NNS',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'UH', '.'],
#  ['VBP',
#   'TO',
#   'VBP',
#   'TO',
#   'NN',
#   'NNS',
#   'IN',
#   'PRP$',
#   'NN',
#   'UH',
#   'UH',
#   'UH',
#   'UH',
#   'UH',
#   'WP',
#   'WDT',
#   'NN',
#   'VBZ',
#   'VBZ',
#   '.'],
#  ['WRB', 'IN', 'CD', 'NNS', '.'],
#  ['UH', 'VB', 'PRP', 'VBP', 'RBR', 'NN', 'WDT', 'DT', 'NN', 'VBZ', '.'],
#  ['UH', 'RB', 'UH', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'RB', 'NN', 'WDT', '.'],
#  ['UH', 'PRP', 'VBP', 'TO', 'VB', '.'],
#  ['WRB',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBP',
#   'IN',
#   'NNP',
#   'VBZ',
#   'NN',
#   'VBZ',
#   'VBZ',
#   '.'],
#  ['WRB', 'UH', '.'],
#  ['VB',
#   'PRP',
#   'VBP',
#   'VB',
#   'UH',
#   'NN',
#   'CC',
#   'VBD',
#   'WDT',
#   'TO',
#   'VB',
#   'TO',
#   'NNS',
#   '.'],
#  ['WRB',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'RP',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'UH',
#   'RB',
#   'VB',
#   'VB',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'VBZ', 'NN', '.'],
#  ['WRB', 'VB', 'TO', 'TO', 'NN', 'TO', 'VBP', '.'],
#  ['PRP', 'VBP', 'TO', 'TO', 'VB', 'TO', 'NNP', 'NNS', '.'],
#  ['VBZ', 'RP', '.'],
#  ['VBZ', 'NN', 'WDT', 'NN', 'VBZ', 'VBP', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'TO', 'NNS', 'VBP', 'WDT', '.'],
#  ['VBZ', 'VBP', 'VBZ', 'WDT', '.'],
#  ['VBZ', 'RP', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'MD', 'TO', 'TO', '.'],
#  ['UH',
#   'PRP',
#   'VBZ',
#   'TO',
#   'VBG',
#   'NN',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'NNS',
#   'WDT',
#   'VBG',
#   '.'],
#  ['VBZ', 'RP', '.'],
#  ['PRP', 'VBZ', 'RB', 'VBZ', 'RB', 'VB', 'NN', 'WDT', 'VBZ', 'VBZ', '.'],
#  ['UH', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'RB', 'NNP', 'NNS', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', 'NN', 'NN', 'UH', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'NN',
#   'VBG',
#   'UH',
#   'NN',
#   'WDT',
#   'PRP',
#   'VBP',
#   'TO',
#   'NN',
#   'DT',
#   'NN',
#   'TO',
#   'UH',
#   'NN',
#   'NN',
#   'RB',
#   'NNP',
#   '.'],
#  ['WRB',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'DT',
#   'NN',
#   'NN',
#   'WDT',
#   'RB',
#   'CD',
#   'NNS',
#   'WDT',
#   'VBG',
#   'CC',
#   'PRP',
#   'VBP',
#   'VB',
#   'VBP',
#   'UH',
#   'RBR',
#   'IN',
#   'DT',
#   'NNS',
#   '.'],
#  ['RB', 'RBR', 'IN', 'PDT', 'DT', 'NN', '.'],
#  ['WRB', 'PRP', 'VBP', 'RBR', 'UH', 'VBZ', '.'],
#  ['WRB', 'VBZ', 'UH', 'VBZ', '.'],
#  ['VBZ', 'VBZ', 'DT', 'NN', 'WDT', 'NN', '.'],
#  ['VBZ', 'VBG', 'WDT', 'PRP$', 'VBZ', 'WDT', '.'],
#  ['WRB', 'PRP', 'VBZ', 'RB', 'UH', 'NN', 'FW', '.'],
#  ['WRB', 'VBZ', 'NN', 'VBZ', 'VBZ', 'WDT', 'NN', 'VBN', 'TO', '.'],
#  ['DT',
#   'NN',
#   'WDT',
#   'NN',
#   'VBZ',
#   'VBN',
#   'NN',
#   'UH',
#   'WDT',
#   'NN',
#   'NN',
#   'CC',
#   'VBZ',
#   'VBP',
#   'RB',
#   'VB',
#   '.'],
#  ['VB', 'PRP', 'VBP', 'JJS', 'NNS', 'NN', 'RB', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'VB',
#   'NN',
#   'WDT',
#   'VBZ',
#   'RB',
#   'IN',
#   'PDT',
#   'DT',
#   'NN',
#   'WDT',
#   'NN',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'WDT', 'IN', 'UH', 'UH', '.'],
#  ['PRP', 'VBP', 'TO', 'WDT', 'UH', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'NN',
#   'CC',
#   'PRP',
#   'VBP',
#   'VBZ',
#   'VBZ',
#   'NN',
#   'RB',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VBG',
#   'PRP',
#   'VBP',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   'CD',
#   'NNS',
#   'CC',
#   'PRP',
#   'VBP',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   'NNS',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'WP', 'VB', 'NN', 'CC', 'PRP', 'NN', '.'],
#  ['PRP', 'VBP', 'RB', 'VBZ', 'VBP', 'NN', 'NN', 'RB', 'VBZ', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'UH',
#   'VB',
#   'NN',
#   'CC',
#   'PRP',
#   'VBZ',
#   'DT',
#   'NN',
#   'VBZ',
#   '.'],
#  ['DT', 'NN', 'WDT', 'VB', 'WP', 'DT', 'NNS', 'WDT', 'NN', '.'],
#  ['VBP', 'RB', 'DT', 'NN', 'NN', 'WDT', 'DT', 'NNS', 'WDT', 'NN', '.'],
#  ['WRB',
#   'VBZ',
#   'PRP',
#   'VBP',
#   'DT',
#   'VBZ',
#   'WDT',
#   'UH',
#   'CC',
#   'VBD',
#   'WDT',
#   'DT',
#   'NN',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', '.'],
#  ['WRB', 'NNS', 'WDT', 'NN', '.'],
#  ['VBZ', 'NN', '.'],
#  ['WRB', 'PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'WDT', 'NN', '.'],
#  ['VB', 'PRP', 'RB', 'NN', 'VBZ', '.'],
#  ['VBZ', 'RP', '.'],
#  ['WRB', 'RB', 'RB', 'NN', 'VBZ', 'NN', '.'],
#  ['WP', 'VBZ', 'DT', 'NN', 'NN', 'WDT', 'UH', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'RB',
#   'DT',
#   'NNS',
#   'WDT',
#   'UH',
#   'CC',
#   'DT',
#   'NN',
#   'WDT',
#   'NN',
#   'WDT',
#   'VB',
#   'RB',
#   'RB',
#   'NNS',
#   '.'],
#  ['PRP', 'VBZ', 'RB', 'VB', '.'],
#  ['RB', 'VB', '.'],
#  ['VBP',
#   'TO',
#   'VBP',
#   'TO',
#   'NN',
#   'RB',
#   'DT',
#   'VBZ',
#   'HYPH',
#   'VBG',
#   'NN',
#   'FW',
#   'VBD',
#   '.'],
#  ['WRB', 'VBZ', 'WDT', 'VB', 'RB', 'VB', 'VBZ', 'TO', 'VB', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', 'IN', 'CD', 'NNS', '.'],
#  ['WRB',
#   'VBZ',
#   'VBG',
#   'VBP',
#   'VBZ',
#   'VBZ',
#   'UH',
#   'NN',
#   'VBZ',
#   'VBZ',
#   'VBZ',
#   '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'CC',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'VB',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   'VB',
#   'NN',
#   '.'],
#  ['WRB', 'NN', 'WDT', 'VBP', 'WRB', '.'],
#  ['PRP',
#   'VBP',
#   'VB',
#   'UH',
#   'RBR',
#   'IN',
#   'NNP',
#   'TO',
#   'NNS',
#   'RB',
#   'TO',
#   'NNS',
#   '.'],
#  ['WRB', 'VBZ', 'VBP', 'TO', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'RB', 'NN', 'NNS', '.'],
#  ['PRP', 'VBP', 'TO', 'TO', 'VB', 'WP', 'NNS', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'MD', 'TO', 'TO', '.'],
#  ['WRB', 'PRP', 'VBP', 'RBR', 'NN', 'RB', 'UH', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'NN', 'NNP', 'NN', '.'],
#  ['WRB', 'NNS', '.'],
#  ['WDT', 'VBZ', 'RB', 'VB', 'WP', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', 'NNP', '.'],
#  ['UH',
#   'PRP',
#   'MD',
#   'VBP',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'VBZ',
#   'TO',
#   'VBP',
#   'NN',
#   'CC',
#   'NN',
#   'WDT',
#   'TO',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'UH', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'NN', 'RB', 'PRP', 'NN', '.'],
#  ['UH', 'WRB', 'RB', 'TO', 'NN', '.'],
#  ['WRB', 'PRP', 'VBP', 'PRP', 'VBP', 'RB', 'NN', 'NN', '.'],
#  ['WRB', 'VBZ', 'VBZ', '.'],
#  ['WRB', 'VBZ', 'VBZ', 'VBN', '.'],
#  ['WRB', 'VBZ', 'VBZ', 'DT', 'VBZ', 'TO', 'VB', '.'],
#  ['WRB', 'NN', 'VBZ', 'VBZ', 'WDT', 'NN', 'VBN', 'TO', '.'],
#  ['VBP',
#   'RB',
#   'DT',
#   'NN',
#   'VBZ',
#   'RB',
#   'VBZ',
#   'RB',
#   'PRP',
#   'VBP',
#   'RB',
#   'PRP',
#   'UH',
#   'WDT',
#   'WDT',
#   'PRP',
#   'VBP',
#   'RB',
#   'WDT',
#   'WP',
#   'VBZ',
#   'VBZ',
#   'VBP',
#   'VBZ',
#   '.'],
#  ['UH',
#   'PRP',
#   'MD',
#   'VB',
#   'WP',
#   'VBP',
#   'TO',
#   'NNS',
#   'PRP',
#   'NNS',
#   'WDT',
#   'VBG',
#   '.'],
#  ['WRB',
#   'PRP',
#   'VBP',
#   'NN',
#   'WDT',
#   'NNS',
#   'WDT',
#   'NNP',
#   'NNS',
#   'VBP',
#   'WDT',
#   'VBG',
#   '.'],
#  ['UH',
#   'UH',
#   'PRP',
#   'VBP',
#   'TO',
#   'NN',
#   'NN',
#   'PRP$',
#   'VBD',
#   'VBZ',
#   'UH',
#   'VB',
#   'NN',
#   'VBZ',
#   'RB',
#   'UH',
#   'WRB',
#   'VBZ',
#   'VBG',
#   'VB',
#   'NN',
#   'RB',
#   'VBZ',
#   'VBP',
#   'TO',
#   'NN',
#   'WDT',
#   'VBZ',
#   'VBZ',
#   'VBZ',
#   'PRP',
#   'VBP',
#   'VBG',
#   'VBZ',
#   'VB',
#   'WP',
#   '.'],
#  ['WRB',
#   'VBZ',
#   'TO',
#   'UH',
#   'WDT',
#   'VBZ',
#   'TO',
#   'NN',
#   'VBZ',
#   'RB',
#   'VBG',
#   'WRB',
#   'PRP',
#   'VBP',
#   'WP',
#   'VB',
#   'TO',
#   'NN',
#   '.'],
#  ['VB', 'PRP', 'RB', 'RB', 'VBZ', 'WDT', 'NN', '.'],
#  ['WRB', 'RB', 'VBG', 'NN', 'WDT', '.'],
#  ['UH',
#   'PRP',
#   'VBP',
#   'WDT',
#   'VBZ',
#   'VBP',
#   'TO',
#   'WDT',
#   'VBZ',
#   'RB',
#   'VB',
#   '.'],
#  ['WRB', 'RB', 'TO', 'UH', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'DT', 'NN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'UH', 'NNS', '.'],
#  ['PRP', 'VBP', 'VB', 'WP', 'VB', 'NNS', 'WDT', 'VBG', 'CC', 'PRP', 'UH', '.'],
#  ['WRB',
#   'VBP',
#   'VBD',
#   'DT',
#   'NN',
#   'NN',
#   'WDT',
#   'DT',
#   'NN',
#   'RB',
#   'WDT',
#   'VBZ',
#   'VBP',
#   'VB',
#   'WDT',
#   'PRP',
#   'VBP',
#   'PRP',
#   'RB',
#   'DT',
#   'NN',
#   'NNS',
#   'WDT',
#   'NNP',
#   '.'],
#  ['VBZ', 'RP', '.'],
#  ['UH', 'VBP', 'PRP', 'VBP', 'NNS', 'RB', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'TO', 'VB', 'RB', 'DT', 'NNS', '.'],
#  ['WRB', 'VB', 'TO', 'WDT', 'DT', 'NN', 'WDT', 'NN', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'IN',
#   'CD',
#   'NNS',
#   'WDT',
#   'DT',
#   'VBZ',
#   'TO',
#   '.'],
#  ['VB', 'NN', 'PRP', 'MD', 'VB', 'TO', '.'],
#  ['UH', 'UH', 'PRP', 'VBP', 'TO', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'MD', 'TO', 'TO', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'UH', 'NN', 'WDT', 'NN', '.'],
#  ['WRB', 'VBZ', 'PRP', 'VBP', 'DT', 'VBZ', 'WDT', 'NN', '.'],
#  ['WP', 'IN', 'NN', 'VBZ', '.'],
#  ['VBP', 'RB', 'DT', 'MD', 'NNS', '.'],
#  ['WRB', 'DT', 'NN', 'WDT', 'IN', 'NNP', 'NNS', 'WDT', 'VBG', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'NN', 'RB', 'NN', 'VBZ', '.'],
#  ['WRB', 'NN', '.'],
#  ['UH', 'WRB', 'RB', 'NN', 'NN', '.'],
#  ['UH',
#   'PRP',
#   'VBP',
#   'VBG',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'WDT',
#   'VBG',
#   'NN',
#   'WDT',
#   'UH',
#   'WDT',
#   'RB',
#   'CD',
#   'NNS',
#   'RB',
#   'NNS',
#   'VBP',
#   'NN',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'VB',
#   'NN',
#   'WDT',
#   'NN',
#   '.'],
#  ['WRB', 'IN', 'NNP', 'NNS', '.'],
#  ['WRB', 'WP', 'VBZ', 'VBZ', 'VBG', 'RB', '.'],
#  ['PRP', 'VBP', 'VBG', 'VBZ', 'TO', 'TO', 'NN', '.'],
#  ['WRB', 'NNP', 'UH', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', 'IN', 'NN', 'TO', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'RB', 'VBG', 'NNS', '.'],
#  ['VBZ', 'RB', 'VBZ', 'UH', 'VB', 'TO', 'DT', 'RBR', 'UH', 'NNS', '.'],
#  ['UH', 'PRP', 'VBP', 'TO', 'VB', 'TO', 'NN', 'NN', 'RB', '.'],
#  ['WRB', 'TO', 'UH', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'RP', 'VB', 'VB', 'PRP', 'NN', '.'],
#  ['WRB', 'VBZ', 'VBZ', 'NN', 'VBP', 'WDT', 'VBG', '.'],
#  ['VBZ', 'RB', 'DT', 'NN', 'NN', 'WDT', 'DT', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'TO', 'VB', 'RP', 'TO', 'VB', 'NNS', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'RP',
#   'IN',
#   'NN',
#   'WDT',
#   'DT',
#   'NN',
#   'NN',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'NN', '.'],
#  ['WRB', 'VBZ', 'VBZ', 'UH', 'TO', 'VBG', '.'],
#  ['WRB',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBP',
#   'NN',
#   'WDT',
#   'NNS',
#   'WDT',
#   'VBZ',
#   'NN',
#   'WDT',
#   'CD',
#   'NNS',
#   'CC',
#   'JJR',
#   '.'],
#  ['WRB', 'RB', 'DT', 'UH', 'HYPH', 'NNP', 'VBZ', 'NN', 'UH', '.'],
#  ['WRB', 'RB', 'UH', 'VB', 'TO', 'WDT', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'NNP', '.'],
#  ['VB', 'PRP', 'RB', 'UH', 'VB', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'NNP', 'VBZ', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'NN', 'NN', '.'],
#  ['PRP', 'VBP', 'VB', 'RB', 'VB', '.'],
#  ['WP', 'VBP', 'TO', 'VBP', 'RB', 'UH', 'NN', '.'],
#  ['PRP', 'VBP', 'VB', 'TO', 'IN', 'DT', 'NNS', 'RB', 'VB', 'DT', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'WP', 'CD', 'NNS', 'WDT', 'NN', '.'],
#  ['WRB', 'PRP', 'VBP', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'NN', 'NN', '.'],
#  ['WRB', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'VBG',
#   'NN',
#   'WDT',
#   'VBZ',
#   'VBZ',
#   'VB',
#   'TO',
#   'VBP',
#   'PRP',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'TO', 'VB', 'TO', 'NNS', 'CC', 'JJR', '.'],
#  ['WRB', 'WDT', 'NNS', 'CC', 'JJR', 'NN', 'VB', 'TO', '.'],
#  ['VBP', 'NN', 'CC', 'DT', 'NN', 'WDT', 'VBP', '.'],
#  ['PRP', 'VBP', 'VB', 'TO', 'DT', 'NN', 'WDT', 'DT', 'NNS', '.'],
#  ['VBZ', 'RB', 'VBZ', 'WDT', 'IN', 'DT', '.'],
#  ['WRB', 'WP', 'UH', '.'],
#  ['UH',
#   'WP',
#   'VBP',
#   'VBG',
#   'WDT',
#   'UH',
#   'PRP',
#   'VBP',
#   'TO',
#   'VBP',
#   'VB',
#   'TO',
#   'NN',
#   'VBD',
#   'NN',
#   'RB',
#   'VBD',
#   'VBZ',
#   'TO',
#   '.'],
#  ['PRP',
#   'VBP',
#   'RB',
#   'VBP',
#   'TO',
#   'NN',
#   'VBZ',
#   'VBZ',
#   'VBP',
#   'TO',
#   'VBZ',
#   '.'],
#  ['UH', 'VB', 'PRP', 'VBP', 'IN', 'VBG', '.'],
#  ['VBZ', 'VBP', 'VBZ', 'WDT', '.'],
#  ['WRB', 'TO', 'VBP', 'VBZ', 'CC', 'VB', 'RP', '.'],
#  ['WRB', 'VBZ', 'RB', 'VBP', 'RB', 'VBZ', 'NN', 'UH', 'VBZ', 'VBZ', '.'],
#  ['PRP',
#   'VBP',
#   'VBG',
#   'VBP',
#   'VBZ',
#   'VB',
#   'VB',
#   'RB',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBP',
#   'VBN',
#   'VB',
#   'NN',
#   'CC',
#   'RB',
#   'PRP',
#   'VBP',
#   'TO',
#   'TO',
#   'VB',
#   'RB',
#   'VBP',
#   'PRP',
#   'VBP',
#   'VB',
#   'PRP',
#   'DT',
#   'NNS',
#   'RB',
#   'VB',
#   'NN',
#   '.'],
#  ['VBZ', 'NN', 'VBZ', 'WP', 'VBZ', 'VBP', '.'],
#  ['PRP', 'VBP', 'TO', 'NN', '.'],
#  ['VBZ', 'NN', 'VBZ', 'WDT', 'WP', '.'],
#  ['WRB', 'VBZ', 'VBP', 'RP', '.'],
#  ['WRB', 'VBZ', 'PRP', 'VBP', 'DT', 'NN', 'VBZ', 'WDT', 'VBZ', '.'],
#  ['WRB', 'CC', 'VBZ', '.'],
#  ['UH',
#   'VB',
#   'VBZ',
#   'VBP',
#   'TO',
#   'WDT',
#   'VBP',
#   'RB',
#   'VBZ',
#   'NNS',
#   'WDT',
#   'NNP',
#   '.'],
#  ['WP', 'VBZ', 'DT', 'NN', 'TO', 'NN', 'WDT', 'UH', '.'],
#  ['DT',
#   'NN',
#   'WDT',
#   'NN',
#   'VBZ',
#   'RB',
#   'VB',
#   'TO',
#   'DT',
#   'JJS',
#   'NN',
#   'VB',
#   'TO',
#   '.'],
#  ['DT', 'NN', 'WDT', 'VB', 'TO', 'IN', 'DT', 'TO', 'NNS', 'RB', '.'],
#  ['VBP',
#   'RB',
#   'VB',
#   'VB',
#   'UH',
#   'PRP',
#   'VBP',
#   'RB',
#   'VBP',
#   'UH',
#   'VB',
#   'VBD',
#   'NN',
#   'VBD',
#   'NN',
#   'VBD',
#   'NN',
#   'VBD',
#   'NN',
#   'WDT',
#   'NNS',
#   'RB',
#   'VB',
#   'VBZ',
#   'NN',
#   'WDT',
#   'WDT',
#   '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'PRP',
#   'VBP',
#   'RB',
#   'VBP',
#   'WP',
#   'CD',
#   'NNS',
#   'VBP',
#   'WDT',
#   'WDT',
#   '.'],
#  ['UH', 'WRB', 'NN', 'WDT', 'VB', 'UH', 'RBR', 'IN', '.'],
#  ['WRB', 'PRP', 'VBZ', 'DT', 'NN', 'WDT', 'PRP', '.'],
#  ['VB', 'VB', 'TO', 'VB', 'NN', 'RB', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'WP',
#   'VB',
#   'NN',
#   'NN',
#   'WDT',
#   'NN',
#   'WDT',
#   'DT',
#   'NN',
#   'WDT',
#   'VBG',
#   '.'],
#  ['WRB', 'PRP', 'VBP', 'TO', 'NN', 'RB', 'DT', 'RB', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'NN', 'NN', '.'],
#  ['WRB', 'VBZ', 'NNP', 'NN', 'WDT', '.'],
#  ['VBP', 'TO', 'VBP', 'TO', 'VB', '.'],
#  ['UH', 'WRB', 'PRP', 'VBP', 'PRP', 'VBP', 'IN', 'VBD', 'TO', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'UH', 'VB', 'WDT', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'RB', 'VB', '.'],
#  ['UH', 'PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'UH', 'WDT', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'UH', 'NN', 'NN', '.'],
#  ['UH',
#   'RB',
#   'RBR',
#   'IN',
#   'DT',
#   'NNS',
#   'CC',
#   'RB',
#   'UH',
#   'VB',
#   'TO',
#   'NNS',
#   '.'],
#  ['WRB',
#   'VBZ',
#   'VBZ',
#   'DT',
#   'NN',
#   'NN',
#   'NN',
#   'WDT',
#   'DT',
#   'NN',
#   'TO',
#   'WDT',
#   'WDT',
#   '.'],
#  ['VB', 'PRP', 'RB', 'DT', 'NN', 'CC', 'RB', 'VB', 'NN', 'NN', '.'],
#  ['WRB', 'RB', 'PRP$', 'NN', 'WDT', 'NN', '.'],
#  ['DT', 'NN', 'VBZ', 'RB', 'TO', '.'],
#  ['PRP', 'VBP', 'TO', 'TO', 'VB', 'TO', 'DT', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'WRB', '.'],
#  ['PRP', 'VBP', 'WDT', 'VBZ', 'VBP', 'TO', 'VB', 'TO', 'WDT', 'NN', '.'],
#  ['WRB', 'VBZ', 'PRP', 'VBP', 'DT', 'NN', 'VBZ', 'WDT', 'VBZ', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'DT', 'NN', 'WDT', 'VBG', '.'],
#  ['VBZ', 'VBZ', 'RB', 'VB', '.'],
#  ['UH',
#   'PRP',
#   'VBZ',
#   'VBP',
#   'RB',
#   'UH',
#   'NN',
#   'RB',
#   'WRB',
#   'VBP',
#   'RB',
#   'PRP',
#   'VBP',
#   'PRP',
#   'RB',
#   'UH',
#   '.'],
#  ['VB', 'PRP', 'VBP', 'IN', 'TO', 'VBZ', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'DT', 'NN', 'NN', 'NN', 'WDT', 'TO', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'RP', 'IN', 'NN', '.'],
#  ['WRB', 'RB', 'NNP', 'NNS', '.'],
#  ['WRB', 'VB', 'TO', 'WDT', 'DT', 'NN', 'WDT', 'NN', '.'],
#  ['WRB', 'VBZ', 'VBP', 'RP', '.'],
#  ['PRP', 'VBP', 'VBG', 'NN', 'VBZ', 'NN', 'NN', '.'],
#  ['WRB', 'VBZ', 'VBZ', 'NN', 'VBP', 'WDT', 'VBG', '.'],
#  ['WRB', 'RB', 'PRP', 'NN', '.'],
#  ['VBP', 'NN', 'WDT', 'NN', 'UH', '.'],
#  ['VB', 'PRP', 'RB', 'NNS', 'WDT', 'VBZ', 'WP', 'TO', 'NN', '.'],
#  ['WRB',
#   'VBZ',
#   'TO',
#   'VBZ',
#   'VBP',
#   'TO',
#   'VBP',
#   'TO',
#   'UH',
#   'HYPH',
#   'NN',
#   '.'],
#  ['VB', 'NN', 'TO', '.'],
#  ['PRP', 'VBP', 'TO', 'TO', 'VB', 'TO', 'NN', 'CC', 'DT', 'NN', 'RB', '.'],
#  ['WRB', 'VBZ', 'NN', 'UH', '.'],
#  ['WRB', 'VBZ', 'VBP', 'TO', 'TO', 'VB', 'NNS', '.'],
#  ['VBZ', 'RB', 'VB', 'VB', 'NN', 'VBZ', '.'],
#  ['PRP',
#   'VBP',
#   'RB',
#   'VBP',
#   'VBG',
#   'NN',
#   'NN',
#   'PRP',
#   'VBP',
#   'TO',
#   'UH',
#   'NN',
#   '.'],
#  ['WRB', 'PRP', 'VBP', 'WP', 'VB', 'DT', 'NN', 'VBZ', '.'],
#  ['WRB', 'NN', 'VBZ', 'CC', 'PRP', 'VBP', 'UH', 'VB', 'MD', 'NN', '.'],
#  ['VBZ', 'RP', '.'],
#  ['VBZ', 'RP', '.'],
#  ['WP', 'IN', 'TO', 'VBZ', '.'],
#  ['WRB', 'VBZ', 'PRP', 'VBP', 'TO', 'VB', 'TO', 'PRP', 'VBP', 'VB', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', 'DT', 'VBZ', 'VBZ', 'VBZ', '.'],
#  ['WRB', 'VBZ', 'NN', 'WDT', 'VBZ', 'VBZ', 'VBZ', 'WDT', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'WDT',
#   'NN',
#   'VBZ',
#   'VBZ',
#   'NN',
#   'NN',
#   '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'WP',
#   'VBZ',
#   'WDT',
#   'VBG',
#   'VBP',
#   'VBP',
#   'TO',
#   'DT',
#   'NN',
#   'NN',
#   'VBP',
#   'WDT',
#   'NN',
#   '.'],
#  ['UH', 'WRB', 'VBZ', 'RB', 'CD', 'NNS', 'WDT', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'NNP', 'CC', 'UH', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'DT', 'NN', 'NN', 'UH', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   'NN',
#   'CC',
#   'DT',
#   'NN',
#   'VBZ',
#   'RB',
#   'VB',
#   '.'],
#  ['WRB', 'VBZ', 'VBP', 'RP', '.'],
#  ['WRB', 'PRP', 'VBP', 'PRP', 'VBP', 'IN', 'UH', 'NN', '.'],
#  ['PRP', 'VBP', 'RB', 'VBP', 'TO', 'VB', 'TO', 'VB', 'DT', 'NNS', '.'],
#  ['WRB',
#   'HYPH',
#   'VBP',
#   'NN',
#   'HYPH',
#   'NNP',
#   'NN',
#   'HYPH',
#   'NNP',
#   'NN',
#   'VBZ',
#   'VBZ',
#   'NN',
#   'VBZ',
#   'VBZ',
#   '.'],
#  ['WRB', 'PRP', 'VBP', 'WP', 'VB', 'VBG', '.'],
#  ['WRB', 'VBZ', '.'],
#  ['WRB', 'VBZ', 'VBZ', 'NN', '.'],
#  ['WRB', 'VBZ', 'PRP', 'VBP', 'DT', 'NN', 'NN', 'NN', 'WDT', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'WDT', 'NN', 'NN', '.'],
#  ['VBP', 'RB', 'VB', 'DT', 'NN', '.'],
#  ['WRB', 'PRP', 'VBP', 'IN', 'UH', 'VBZ', '.'],
#  ['PRP', 'VBP', 'VBG', 'VB', 'WRB', 'RB', 'VBZ', 'RB', 'TO', 'NN', '.'],
#  ['WRB', 'RB', 'DT', 'NN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'DT', 'NN', 'CC', 'VBZ', 'VBP', 'VBZ', '.'],
#  ['UH',
#   'VB',
#   'VBZ',
#   'VBP',
#   'RP',
#   'VBP',
#   'PRP',
#   'VBP',
#   'NN',
#   'NN',
#   'WDT',
#   'RB',
#   'CD',
#   'NNS',
#   'RB',
#   'NNS',
#   'VBP',
#   'NN',
#   'VBZ',
#   'TO',
#   'VB',
#   'TO',
#   'DT',
#   'NN',
#   'NN',
#   '.'],
#  ['WDT',
#   'VBZ',
#   'UH',
#   'NN',
#   'WDT',
#   'TO',
#   'VBZ',
#   'PRP',
#   'VBP',
#   'VBP',
#   'VBG',
#   '.'],
#  ['RB', 'VB', 'VB', 'RB', 'VB', 'VBG', 'NN', 'WDT', 'TO', 'NNS', '.'],
#  ['WRB', 'VBZ', 'DT', 'NN', 'WDT', 'VBZ', '.'],
#  ['PRP', 'VBP', 'VBZ', 'VBP', '.'],
#  ['VBZ', 'DT', 'NN', 'NN', 'WDT', 'VBZ', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'UH', 'NN', '.'],
#  ['WP', 'IN', 'NNS', 'WDT', 'NN', '.'],
#  ['WRB',
#   'JJR',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'VBZ',
#   'VBZ',
#   'NN',
#   'VBZ',
#   'VBZ',
#   'VBZ',
#   'NN',
#   'WDT',
#   'NN',
#   '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   'NN',
#   'NNS',
#   'WRB',
#   'VBZ',
#   'NN',
#   'VBZ',
#   'RB',
#   'IN',
#   'DT',
#   'TO',
#   '.'],
#  ['PRP', 'VBP', 'VBG', 'VB', 'RB', 'VB', '.'],
#  ['VB', 'PRP', 'RB', 'UH', 'NN', 'FW', '.'],
#  ['WRB', 'NNS', 'WDT', 'VBZ', '.'],
#  ['WRB', 'PRP', 'MD', 'VB', 'TO', 'NN', 'WDT', 'DT', 'NN', 'NN', 'UH', '.'],
#  ['DT', 'NN', 'WDT', 'NN', 'VBZ', 'RB', 'VB', '.'],
#  ['WRB', 'VBZ', 'PRP', 'VBP', 'WP', '.'],
#  ['WRB', 'VBZ', 'VBP', 'RP', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', 'CC', 'PRP', 'VBZ', 'UH', '.'],
#  ['WRB', 'RB', 'NN', '.'],
#  ['WRB', 'VBZ', 'UH', 'HYPH', 'NNP', 'WDT', '.'],
#  ['WRB',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBP',
#   'NN',
#   'WDT',
#   'RB',
#   'NN',
#   'UH',
#   'NNS',
#   'WDT',
#   'DT',
#   'NN',
#   '.'],
#  ['WP', 'VBZ', 'RB', 'VBZ', 'NN', 'VBZ', 'VBZ', 'VBZ', 'NN', 'WDT', '.'],
#  ['UH',
#   'PRP',
#   'VBP',
#   'WDT',
#   'VBZ',
#   'VBP',
#   'TO',
#   'WDT',
#   'VBZ',
#   'RB',
#   'VB',
#   '.'],
#  ['VBZ', 'RB', 'VB', '.'],
#  ['WRB',
#   'NN',
#   'VBZ',
#   'VBZ',
#   'VBZ',
#   'NN',
#   'WDT',
#   'NN',
#   'VBZ',
#   'WDT',
#   'VBZ',
#   'VBZ',
#   'VBZ',
#   'VBZ',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', 'NNS', '.'],
#  ['WRB',
#   'DT',
#   'VBZ',
#   'UH',
#   'VBP',
#   'PRP',
#   'VBP',
#   'NN',
#   'RB',
#   'UH',
#   'VB',
#   'NN',
#   'NN',
#   'WDT',
#   'UH',
#   'VBZ',
#   'VBZ',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN',
#   'WDT',
#   'PRP',
#   'VBZ',
#   '.'],
#  ['WRB', 'VBZ', 'VBZ', 'DT', 'VBZ', 'TO', 'VB', '.'],
#  ['WRB', 'NNS', 'WDT', 'VBZ', '.'],
#  ['UH', 'VBP', 'TO', 'VBZ', 'RB', 'VBZ', 'RB', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'RB', 'WDT', '.'],
#  ['WRB', 'VBZ', 'IN', 'DT', 'NN', 'WDT', 'VBZ', '.'],
#  ['WRB', 'WDT', 'VBP', 'VBZ', 'VBZ', 'UH', 'NN', 'VBZ', 'VBZ', 'VBZ', '.'],
#  ['RB', 'RBR', 'IN', 'DT', 'NNS', '.'],
#  ['PRP', 'MD', 'VB', 'UH', 'VB', 'WDT', '.'],
#  ['VBP',
#   'TO',
#   'VBP',
#   'RB',
#   'WRB',
#   'PRP',
#   'VBP',
#   'VB',
#   'TO',
#   'NN',
#   'VBZ',
#   'WDT',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'NN', 'NN', '.'],
#  ['UH', 'VBZ', 'RB', '.'],
#  ['PRP', 'VBP', 'VB', 'TO', 'DT', 'NN', 'WDT', 'DT', 'NNS', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'WP',
#   'DT',
#   'NN',
#   'VBZ',
#   'RB',
#   'VB',
#   'NN',
#   'NNP',
#   'VBZ',
#   '.'],
#  ['WRB', 'NN', '.'],
#  ['VB', 'PRP', 'RB', 'DT', 'NN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'UH', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', '.'],
#  ['DT',
#   'NN',
#   'WDT',
#   'VB',
#   'RB',
#   'VB',
#   'UH',
#   'RBR',
#   'IN',
#   'DT',
#   'VBZ',
#   'NNS',
#   'WDT',
#   'VB',
#   '.'],
#  ['WRB', 'VBZ', 'NNS', 'VBP', 'TO', 'VBP', 'RB', 'VB', '.'],
#  ['WRB', 'VBZ', 'VBP', 'RP', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'DT',
#   'UH',
#   'UH',
#   'TO',
#   'VB',
#   'UH',
#   'WP',
#   'RB',
#   'UH',
#   'VB',
#   '.'],
#  ['PRP', 'VBP', 'VBG', 'IN', 'DT', 'NN', 'WDT', 'NN', 'WDT', 'NNP', '.'],
#  ['VB', 'PRP', 'VBP', 'IN', 'VBG', '.'],
#  ['WP', 'VBZ', 'WDT', 'NN', 'WDT', 'TO', 'VBP', 'RB', '.'],
#  ['PRP', 'VBP', 'PRP', 'VBP', 'DT', 'NN', 'WDT', 'WP', 'VBG', '.'],
#  ['WRB', 'WDT', 'NN', 'VBZ', 'VBG', 'VBZ', '.'],
#  ['VBP', 'DT', 'NNS', 'WDT', 'VBZ', 'VBZ', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'NNP',
#   'CC',
#   'DT',
#   'NN',
#   'WDT',
#   'TO',
#   'VB',
#   'RB',
#   'TO',
#   'VBG',
#   '.'],
#  ['UH',
#   'PRP',
#   'VBP',
#   'VBG',
#   'NN',
#   'WDT',
#   'NN',
#   'RB',
#   'VB',
#   'NNP',
#   'RB',
#   'VB',
#   'VB',
#   'RB',
#   'VB',
#   'NN',
#   'CC',
#   'RB',
#   'VB',
#   'NN',
#   'RB',
#   'VB',
#   'NN',
#   'WDT',
#   '.'],
#  ['VBZ', 'RB', 'VBZ', 'VBP', 'DT', 'VBZ', 'NN', '.'],
#  ['WRB', 'VBZ', 'UH', 'WRB', 'VBZ', 'NN', '.'],
#  ['UH',
#   'PRP',
#   'VBP',
#   'VBP',
#   'RB',
#   'WDT',
#   'WP',
#   'VB',
#   'NN',
#   'WDT',
#   'NN',
#   'NN',
#   'PRP',
#   'VBP',
#   'VBP',
#   'RB',
#   'VBP',
#   'TO',
#   'VB',
#   'VBP',
#   'RB',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   'VB',
#   'PRP',
#   'VBP',
#   'VBG',
#   'NN',
#   'WDT',
#   'VB',
#   'TO',
#   '.'],
#  ['UH', 'VB', 'PRP', 'VBP', 'IN', 'DT', 'NN', 'WDT', '.'],
#  ['WRB', 'VBZ', 'NN', 'WDT', 'VBZ', 'NN', 'WDT', 'VBZ', 'VBZ', 'VBZ', '.'],
#  ['PRP', 'VBP', 'TO', 'NN', 'WDT', 'VBZ', 'DT', 'NN', '.'],
#  ['VB', 'PRP', 'VBP', 'IN', 'UH', 'CC', 'RB', 'DT', 'NN', 'NN', '.'],
#  ['WRB', '.'],
#  ['PRP', 'VBZ', 'VB', 'DT', 'NN', 'NN', '.'],
#  ['VB', 'PRP', 'RB', 'DT', 'RB', 'NN', 'VBZ', 'NN', '.'],
#  ['RB', 'VB', 'VB', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'WP',
#   'VBZ',
#   'WDT',
#   'VBG',
#   'VBP',
#   'VBP',
#   'TO',
#   'DT',
#   'NN',
#   'NN',
#   'VBP',
#   'WDT',
#   'NN',
#   '.'],
#  ['WRB', 'VBZ', 'DT', 'VBZ', 'NN', 'WDT', 'NN', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'DT',
#   'NN',
#   'NN',
#   'NN',
#   'PRP',
#   'VBP',
#   'RB',
#   'VBP',
#   'WRB',
#   'PRP',
#   'MD',
#   'VB',
#   'WP',
#   'PRP',
#   'VBZ',
#   'PRP',
#   'VBZ',
#   '.'],
#  ['WRB', 'WDT', 'CC', 'VBZ', 'VBP', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'VBN',
#   'NN',
#   'NN',
#   'WDT',
#   'DT',
#   'NN',
#   'NN',
#   'WDT',
#   'DT',
#   'VBG',
#   'NN',
#   'WDT',
#   'VBG',
#   '.'],
#  ['WRB', 'RB', 'UH', 'NN', '.'],
#  ['VB', 'DT', 'NNS', '.'],
#  ['WRB', 'PRP', 'VBP', 'PRP', 'VBP', 'RB', 'NN', 'NN', '.'],
#  ['WRB', 'VB', 'TO', 'NN', 'WDT', 'NN', '.'],
#  ['WRB', 'VBZ', 'VB', 'VBZ', 'UH', '.'],
#  ['WRB', 'VBZ', 'VBP', 'VBZ', '.'],
#  ['RB', 'RBR', 'IN', 'CD', 'NNS', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'NN', 'WDT', 'VBG', '.'],
#  ['PRP', 'VBP', 'VBG', 'RB', '.'],
#  ['PRP', 'VBP', 'PRP', 'VBP', 'DT', 'NN', 'WDT', 'WP', 'VBG', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'VBG', 'VB', 'PRP', 'VBP', 'TO', 'VB', 'TO', '.'],
#  ['PRP', 'VBP', 'VBG', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', '.'],
#  ['WRB',
#   'VBZ',
#   'DT',
#   'JJS',
#   'NN',
#   'TO',
#   'VB',
#   'TO',
#   'WDT',
#   'NNP',
#   'WDT',
#   'NN',
#   'WDT',
#   'VBG',
#   'CD',
#   'NNS',
#   'UH',
#   'WP',
#   'DT',
#   'VBZ',
#   'TO',
#   'VBP',
#   '.'],
#  ['VB', 'CD', 'TO', 'VB', 'TO', 'TO', 'VB', 'NNS', '.'],
#  ['VBP', 'TO', 'VBP', 'VBG', 'WDT', 'RB', 'VBG', 'WDT', 'UH', '.'],
#  ['WRB', 'RB', 'DT', 'VBZ', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   'NN',
#   'CC',
#   'RB',
#   'PRP',
#   'VBP',
#   'TO',
#   'NN',
#   'UH',
#   '.'],
#  ['VB', 'PRP', 'RB', 'UH', 'HYPH', 'VBP', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'UH',
#   'WP',
#   'UH',
#   'TO',
#   'VB',
#   'PRP',
#   'MD',
#   'VB',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   'VB',
#   'WP',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'UH',
#   'NN',
#   '.'],
#  ['VBP', 'TO', 'VB', 'TO', 'WDT', 'NNP', '.'],
#  ['VB', 'CD', 'NNS', '.'],
#  ['WRB', 'VBZ', 'UH', '.'],
#  ['VBZ', 'RB', 'VBP', 'NN', 'VBP', 'VBG', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'IN', 'TO', 'NNS', 'WDT', 'UH', '.'],
#  ['VBP',
#   'TO',
#   'VBP',
#   'TO',
#   'NN',
#   'NNS',
#   'IN',
#   'PRP$',
#   'NN',
#   'UH',
#   'UH',
#   'UH',
#   'UH',
#   'UH',
#   'WP',
#   'WDT',
#   'NN',
#   'VBZ',
#   'VBZ',
#   '.'],
#  ['VBP', 'NN', 'WDT', 'VB', 'RP', 'TO', 'VB', 'NNS', '.'],
#  ['RB', 'VBP', 'TO', 'IN', 'DT', 'NNS', '.'],
#  ['PRP', 'VBZ', 'VB', 'VBP', 'PRP', 'VBP', 'VBG', '.'],
#  ['WRB', 'PRP', 'VBP', 'TO', 'NN', 'RB', 'NNP', 'VBZ', 'UH', '.'],
#  ['PRP',
#   'VBP',
#   'RB',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   'IN',
#   'CD',
#   'TO',
#   'WDT',
#   'PRP$',
#   'NN',
#   '.'],
#  ['WP', 'VBZ', 'RB', 'NN', 'WDT', 'VBG', '.'],
#  ['WRB', 'PRP', 'VBP', 'IN', 'UH', 'NNS', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'NN', 'WDT', 'NN', 'NNS', '.'],
#  ['WRB', 'WDT', 'VBZ', '.'],
#  ['UH',
#   'PRP',
#   'MD',
#   'VBP',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'VBZ',
#   'TO',
#   'VBP',
#   'NN',
#   'CC',
#   'NN',
#   'WDT',
#   'TO',
#   '.'],
#  ['VB', 'PRP', 'VBP', 'JJS', 'NNS', 'NN', 'RB', '.'],
#  ['VB',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'UH',
#   'VB',
#   'NN',
#   'WDT',
#   'VBG',
#   'NN',
#   'RB',
#   'VBG',
#   'RB',
#   'CD',
#   'NNS',
#   '.'],
#  ['VBZ', 'RB', 'JJR', 'NN', 'VBP', 'VBN', '.'],
#  ['PRP', 'VBP', 'TO', 'NNS', 'IN', 'PRP', '.'],
#  ['VBZ',
#   'VB',
#   'VBZ',
#   'NN',
#   'WDT',
#   'CD',
#   'NNS',
#   'WDT',
#   'VBG',
#   'WDT',
#   'UH',
#   'CC',
#   'VBZ',
#   '.'],
#  ['VB',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'UH',
#   'VB',
#   'NN',
#   'WDT',
#   'VBG',
#   'NN',
#   'RB',
#   'VBG',
#   'RB',
#   'CD',
#   'NNS',
#   '.'],
#  ['WRB', 'IN', 'DT', 'TO', 'NNS', 'WDT', 'VB', '.'],
#  ['RB', 'RBR', 'IN', 'CD', 'NNS', 'WDT', 'UH', '.'],
#  ['VBZ', 'RP', '.'],
#  ['DT', 'NN', 'WDT', 'WDT', 'VBZ', 'VBP', '.'],
#  ['WRB',
#   'WDT',
#   'PRP',
#   'VBP',
#   'VBG',
#   'VBZ',
#   'VB',
#   'VBZ',
#   'VBP',
#   'PRP',
#   'MD',
#   'VB',
#   'RB',
#   'DT',
#   'NNS',
#   'IN',
#   'DT',
#   'VBZ',
#   'NN',
#   '.'],
#  ['PRP', 'VBP', 'RB', 'VBZ', 'RB', 'DT', 'NN', 'WDT', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'RB', 'TO', 'VBZ', 'IN', 'VBG', '.'],
#  ['WRB', 'NN', '.'],
#  ['PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'VBZ',
#   'NN',
#   'VBG',
#   'NN',
#   'RB',
#   'NN',
#   'WDT',
#   'VBZ',
#   'RB',
#   'DT',
#   'VBZ',
#   'TO',
#   'TO',
#   'CD',
#   'TO',
#   'VBZ',
#   '.'],
#  ['UH', 'VB', 'RP', '.'],
#  ['UH', 'PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'UH', 'WDT', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'WRB', 'NN', 'NN', 'PRP', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'VBN',
#   'NN',
#   'NN',
#   'WDT',
#   'VBG',
#   'NN',
#   'WDT',
#   'DT',
#   'VBG',
#   'NN',
#   'WDT',
#   'VBG',
#   '.'],
#  ['VBZ', 'VB', 'VBZ', 'VBZ', 'VBZ', '.'],
#  ['UH',
#   'VB',
#   'PRP',
#   'VBP',
#   'RB',
#   'WDT',
#   'UH',
#   'WP',
#   'UH',
#   'WP',
#   'UH',
#   'WRB',
#   '.'],
#  ['VBZ', 'RP', '.'],
#  ['PRP', 'VBP', 'VB', 'PRP', 'WP', 'VBZ', 'WDT', 'VBG', '.'],
#  ['VBZ', 'UH', 'VBZ', 'WDT', 'TO', 'VB', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'NN',
#   'WDT',
#   'VBG',
#   'WDT',
#   'NNS',
#   'WDT',
#   'NNS',
#   '.'],
#  ['UH',
#   'VB',
#   'VBZ',
#   'VBP',
#   'RB',
#   'VB',
#   'DT',
#   'NN',
#   'TO',
#   'CC',
#   'PRP',
#   'VBP',
#   'VB',
#   'RB',
#   'RB',
#   'NNS',
#   '.'],
#  ['WRB',
#   'VBZ',
#   'VBP',
#   'NN',
#   'VBZ',
#   'NN',
#   'WDT',
#   'FW',
#   'POS',
#   'VBZ',
#   'POS',
#   'NN',
#   'FW',
#   '.'],
#  ['VB', 'DT', 'TO', 'NNS', '.'],
#  ['VBZ', 'RP', '.'],
#  ['VBZ', 'VB', 'VBZ', 'VBP', 'TO', 'WDT', 'UH', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'VB', 'TO', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'TO', 'UH', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'RB', 'VB', '.'],
#  ['VBP', 'TO', 'VBP', 'TO', 'NN', 'WDT', 'VBZ', 'VBN', 'NN', '.'],
#  ['UH', 'VB', 'PRP', 'VBZ', 'NN', 'WDT', 'VBG', 'NN', '.'],
#  ['PRP',
#   'VBP',
#   'VBG',
#   'VBP',
#   'RB',
#   'UH',
#   'VB',
#   'PRP',
#   'VBP',
#   'TO',
#   'MD',
#   'VB',
#   'WP',
#   'UH',
#   'WP',
#   'RB',
#   'DT',
#   'NNS',
#   '.'],
#  ['UH',
#   'UH',
#   'PRP',
#   'VBP',
#   'VBG',
#   'VB',
#   'PRP',
#   'VBP',
#   'VBG',
#   'IN',
#   'PRP',
#   'IN',
#   'NN',
#   '.'],
#  ['UH', 'WRB', 'PRP', 'VBP', 'PRP', 'VBP', 'IN', 'DT', 'UH', 'WRB', '.'],
#  ['WRB', 'PRP', 'VBP', 'PRP', 'VBP', 'NN', 'NNS', 'VBP', 'VBP', '.'],
#  ['WRB',
#   'PRP',
#   'VBZ',
#   'VB',
#   'NNS',
#   'WDT',
#   'DT',
#   'NNS',
#   'WDT',
#   'DT',
#   'NN',
#   '.'],
#  ['WRB', 'VBZ', 'VB', 'WDT', 'VBG', 'VB', 'DT', 'VBZ', 'VBZ', '.'],
#  ['WRB', 'VBZ', 'PRP', 'VBP', 'DT', 'VBZ', 'VBZ', 'VBZ', '.'],
#  ['PRP', 'VBP', 'VBG', 'IN', 'DT', 'NN', 'WDT', 'NN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'IN', 'UH', 'NN', '.'],
#  ['WRB', 'WDT', 'DT', 'VBZ', 'UH', 'WDT', '.'],
#  ['UH', 'PRP', 'VBP', 'VB', 'WP', 'IN', 'NN', '.'],
#  ['UH', 'WDT', '.'],
#  ['WRB',
#   'VBZ',
#   'VBZ',
#   'VBZ',
#   'VBZ',
#   'HYPH',
#   'NNP',
#   'NN',
#   'NN',
#   'WDT',
#   'NN',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'NN', 'WDT', 'RBR', 'IN', 'NNP', 'NNS', 'UH', '.'],
#  ['WRB', 'VB', 'TO', 'VB', 'TO', 'NNP', 'WDT', 'NN', '.'],
#  ['PRP',
#   'VBP',
#   'VBG',
#   'VB',
#   'WP',
#   'VBG',
#   'VBZ',
#   'UH',
#   'VB',
#   'VBZ',
#   'VBP',
#   'WP',
#   'VBP',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'WP',
#   'PRP',
#   'VBP',
#   'VBG',
#   'WRB',
#   'TO',
#   'VBZ',
#   'HYPH',
#   'VBG',
#   '.'],
#  ['UH', 'VB', 'PRP', 'VBP', 'NN', 'WDT', 'VBG', 'WDT', 'NN', 'DT', 'NN', '.'],
#  ['VBP', 'TO', 'VBP', 'RB', 'TO', 'TO', '.'],
#  ['WRB', 'NNS', 'IN', 'NN', 'RB', 'VB', '.'],
#  ['WRB', 'WDT', 'NN', 'WDT', 'NN', 'NN', 'RB', '.'],
#  ['VBP', 'TO', 'VBP', 'TO', 'VBZ', 'WDT', 'UH', 'NN', '.'],
#  ['VB', 'PRP', 'VBP', 'IN', 'PRP', 'VBZ', 'UH', '.'],
#  ['RB', 'VB', 'VB', '.'],
#  ['VBZ', 'VBG', 'VB', 'NN', 'VBG', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'NNS', 'WDT', 'DT', 'NN', 'NN', '.'],
#  ['VB', 'PRP', 'RB', 'VBG', '.'],
#  ['WP', 'IN', 'NNP', 'HYPH', 'NNP', '.'],
#  ['WRB',
#   'VBZ',
#   'VBZ',
#   'DT',
#   'VBZ',
#   'VBZ',
#   'WDT',
#   'DT',
#   'VBZ',
#   'WDT',
#   'DT',
#   'TO',
#   'UH',
#   'NN',
#   'WDT',
#   'UH',
#   'NN',
#   '.'],
#  ['WRB', 'NN', 'UH', '.'],
#  ['PRP', 'MD', 'VB', 'DT', 'NN', 'WDT', 'NN', 'NNS', '.'],
#  ['UH', 'UH', 'WP', 'VBP', 'TO', 'UH', 'WDT', 'DT', 'NN', 'VBZ', '.'],
#  ['VB', 'PRP', 'RB', 'NN', 'NNS', '.'],
#  ['WRB', 'NN', 'PRP', '.'],
#  ['UH',
#   'PRP',
#   'VBP',
#   'VBG',
#   'NN',
#   'WDT',
#   'NN',
#   'RB',
#   'VB',
#   'NNP',
#   'RB',
#   'VB',
#   'VB',
#   'RB',
#   'VB',
#   'NN',
#   'CC',
#   'RB',
#   'VB',
#   'NN',
#   'RB',
#   'VB',
#   'NN',
#   'WDT',
#   '.'],
#  ['VBZ', 'DT', 'NN', 'VBZ', 'WDT', 'VB', 'VBG', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'NN',
#   'WDT',
#   'VBZ',
#   'UH',
#   'WP',
#   'NN',
#   'VBG',
#   'DT',
#   'VBZ',
#   'TO',
#   'TO',
#   'VB',
#   'TO',
#   'VBZ',
#   '.'],
#  ['WRB',
#   'VBZ',
#   'PRP',
#   'VBP',
#   'TO',
#   'VBG',
#   'VBZ',
#   'RB',
#   'VBZ',
#   'VB',
#   'VB',
#   'WDT',
#   '.'],
#  ['PRP',
#   'VBP',
#   'VB',
#   'RB',
#   'CD',
#   'NNS',
#   'WDT',
#   'VBG',
#   'CC',
#   'UH',
#   'VB',
#   'VBP',
#   'TO',
#   'IN',
#   'DT',
#   'NNS',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'NN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'DT', 'NN', 'RB', 'VB', 'VB', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', '.'],
#  ['WRB', 'NNS', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', 'NNS', '.'],
#  ['PRP', 'VBP', 'TO', 'NN', 'RB', '.'],
#  ['WRB', 'PRP', 'VBP', 'PRP', 'VBP', 'IN', 'UH', 'NN', '.'],
#  ['RB', 'RBR', 'IN', 'NNP', 'NNS', 'WDT', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'RB', 'PRP', 'NNP', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'UH', 'WP', 'NN', '.'],
#  ['WRB', 'PRP', 'VBP', 'PRP', 'UH', 'VB', 'NN', 'RB', 'UH', 'VB', 'NN', '.'],
#  ['WRB', 'VBZ', 'DT', 'NNS', 'CC', 'VBD', 'WDT', 'VBZ', '.'],
#  ['WRB',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBP',
#   'NN',
#   'RB',
#   'VB',
#   'WDT',
#   'VBG',
#   'NN',
#   '.'],
#  ['UH',
#   'UH',
#   'UH',
#   'VB',
#   'TO',
#   'NN',
#   'DT',
#   'NN',
#   'WDT',
#   'DT',
#   'MD',
#   'NN',
#   '.'],
#  ['DT', 'NN', 'WDT', 'VB', 'TO', 'DT', 'NN', 'WDT', 'NN', '.'],
#  ['WRB', 'VB', 'RB', 'VB', '.'],
#  ['VB', 'PRP', 'VBP', 'IN', 'UH', 'WRB', 'VBZ', '.'],
#  ['WRB', 'CD', 'NNS', 'WDT', 'NN', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   'NN',
#   'UH',
#   'WP',
#   'VBP',
#   'WDT',
#   'UH',
#   'VBZ',
#   '.'],
#  ['WRB', 'RB', 'TO', 'NNS', 'VBP', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'TO', 'VB', 'RP', 'TO', 'VB', 'NNS', 'WDT', 'VBG', '.'],
#  ['VBP', 'RB', 'VBZ', 'TO', 'NNS', '.'],
#  ['VBZ', 'RB', 'NNS', 'NNP', 'NNS', 'WDT', 'TO', 'NNS', 'WDT', 'NN', '.'],
#  ['VB', 'PRP', 'VBP', 'IN', 'NNP', 'HYPH', 'VBG', 'TO', 'VBZ', 'UH', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'WDT', 'NN', '.'],
#  ['VB', 'PRP', 'RB', 'VBG', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'RB', 'VB', 'VB', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'RB', 'DT', 'NNS', '.'],
#  ['VBP',
#   'RB',
#   'DT',
#   'UH',
#   'WP',
#   'IN',
#   'CD',
#   'NNS',
#   'CC',
#   'JJR',
#   'IN',
#   'CD',
#   'NNS',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'RB',
#   '.'],
#  ['VBZ', 'RP', '.'],
#  ['WP', 'VBZ', 'UH', 'NN', 'WDT', '.'],
#  ['VBZ', '.'],
#  ['WRB', 'NNP', '.'],
#  ['VBP', 'RB', 'DT', 'VBZ', 'VBP', 'TO', 'VB', 'NN', 'VBZ', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'RP', 'IN', 'NN', 'NN', '.'],
#  ['WRB',
#   'VBZ',
#   'VBP',
#   'VBZ',
#   'WDT',
#   'DT',
#   'VBZ',
#   'TO',
#   'TO',
#   'CD',
#   'TO',
#   'VBZ',
#   '.'],
#  ['WRB', 'RBR', '.'],
#  ['VBP', 'RB', 'PRP', 'VBP', 'VBZ', 'NN', '.'],
#  ['WRB', 'VBZ', 'VB', 'PRP', 'VBZ', '.'],
#  ['VBZ', 'RB', 'VBZ', 'NN', 'WDT', 'NN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'DT', 'NN', 'NN', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'WP',
#   'VB',
#   'NN',
#   'NN',
#   'WDT',
#   'NN',
#   'WDT',
#   'DT',
#   'NN',
#   'WDT',
#   'VBG',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', 'NN', 'RB', 'DT', 'NN', 'TO', 'NN', '.'],
#  ['WRB', 'VBZ', 'DT', 'NN', 'WDT', '.'],
#  ['PRP', 'VBP', 'VBG', 'UH', 'RB', 'PRP', 'VBZ', 'VB', 'RB', '.'],
#  ['VB', 'VBZ', 'DT', 'NN', 'NN', 'UH', 'VBZ', 'WP', 'IN', 'DT', 'NN', '.'],
#  ['VB',
#   'VB',
#   'NN',
#   'WDT',
#   'NN',
#   'WDT',
#   'VB',
#   'UH',
#   'NN',
#   'CC',
#   'PRP',
#   'VBP',
#   'VB',
#   'RB',
#   'NNP',
#   'TO',
#   'VB',
#   'NNS',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'NN', '.'],
#  ['UH', 'VB', 'PRP', 'VBP', 'IN', 'TO', '.'],
#  ['DT', 'NN', 'CC', 'DT', 'NN', 'WDT', 'RB', 'VB', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'NN', 'RB', 'UH', 'VBZ', '.'],
#  ['PRP',
#   'VBP',
#   'VB',
#   'RB',
#   'CD',
#   'NNS',
#   'WDT',
#   'VBG',
#   'CC',
#   'UH',
#   'VB',
#   'VBP',
#   'TO',
#   'IN',
#   'DT',
#   'NNS',
#   '.'],
#  ['WRB', 'VBZ', 'NN', 'VBZ', 'NN', '.'],
#  ['WRB', 'VB', 'RB', 'DT', 'TO', 'NNS', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', '.'],
#  ['VBP', 'RB', 'DT', 'RB', 'NN', 'VBZ', '.'],
#  ['UH',
#   'WRB',
#   'PRP',
#   'VBP',
#   'NN',
#   'NN',
#   'WDT',
#   'VBG',
#   'NN',
#   'WDT',
#   'UH',
#   'WDT',
#   'CD',
#   'NNS',
#   'RB',
#   'NNS',
#   'VBP',
#   'NN',
#   'WDT',
#   'DT',
#   'UH',
#   'NN',
#   'WDT',
#   'NN',
#   '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'UH',
#   'NN',
#   'WDT',
#   'NNP',
#   'POS',
#   'NN',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'NNS',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'WP', 'VB', 'NN', 'CC', 'PRP', 'NN', '.'],
#  ['WP', 'VBP', 'TO', 'VBP', 'RB', 'VBG', 'VBZ', '.'],
#  ['WRB',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBP',
#   'NN',
#   'WDT',
#   'NNS',
#   'WDT',
#   'VBZ',
#   'NN',
#   'WDT',
#   'CD',
#   'NNS',
#   'CC',
#   'JJR',
#   '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'UH',
#   'NN',
#   'WDT',
#   'RB',
#   'RBR',
#   'IN',
#   'DT',
#   'NNS',
#   '.'],
#  ['WRB', 'IN', 'NNP', 'NNS', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'VBP',
#   'TO',
#   'VB',
#   'WRB',
#   'VB',
#   'VBD',
#   'NNS',
#   'VBZ',
#   'NNS',
#   'VBD',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'NN', 'WDT', 'NN', 'NNS', '.'],
#  ['DT', 'NN', 'WDT', 'VB', 'TO', 'DT', 'NN', 'NN', 'VBZ', '.'],
#  ['PRP',
#   'VBP',
#   'VBG',
#   'VBP',
#   'VBZ',
#   'VB',
#   'VB',
#   'RB',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBP',
#   'VBN',
#   'VB',
#   'NN',
#   'CC',
#   'RB',
#   'PRP',
#   'VBP',
#   'TO',
#   'TO',
#   'VB',
#   'RB',
#   'VBP',
#   'PRP',
#   'VBP',
#   'VB',
#   'PRP',
#   'DT',
#   'NNS',
#   'RB',
#   'VB',
#   'NN',
#   '.'],
#  ['WRB', 'NNP', 'NNS', 'PRP', 'NNS', '.'],
#  ['WRB', 'PRP', 'VBZ', 'DT', 'NN', 'WDT', 'PRP', '.'],
#  ['VBP',
#   'RB',
#   'DT',
#   'UH',
#   'WP',
#   'IN',
#   'CD',
#   'NNS',
#   'CC',
#   'JJR',
#   'IN',
#   'CD',
#   'NNS',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'RB',
#   '.'],
#  ['WP', 'IN', 'UH', '.'],
#  ['WRB', 'PRP', 'VBP', 'NN', 'RB', '.'],
#  ['UH', 'PRP', 'VBP', 'TO', 'TO', 'VB', 'RB', 'DT', 'NN', 'WDT', 'VBG', '.'],
#  ['DT', 'VBD', 'WDT', 'VB', 'TO', 'NNS', '.'],
#  ['WP', 'IN', 'NNS', 'WDT', 'VBG', 'NN', '.'],
#  ['WRB', 'VB', 'TO', 'TO', 'NN', 'TO', 'VBP', '.'],
#  ['WP', 'VBZ', 'WDT', 'VBG', 'UH', '.'],
#  ['WRB',
#   'NN',
#   'WDT',
#   'NNP',
#   'VBZ',
#   'MD',
#   'VB',
#   'TO',
# ...
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'TO',
#   'VB',
#   'RP',
#   'VBD',
#   'WDT',
#   'TO',
#   'VB',
#   'UH',
#   'TO',
#   'TO',
#   '.'],
#  ['WRB', 'NN', 'CC', 'VBD', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'UH', '.'],
#  ['WRB',
#   'VBZ',
#   'VBP',
#   'RP',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'RB',
#   'NN',
#   'NNS',
#   'RB',
#   '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'RBR', 'NN', 'RB', 'UH', 'NN', '.'],
#  ['VBZ', 'RP', '.'],
#  ['VBZ', 'RP', '.'],
#  ['WRB', 'VBZ', '.'],
#  ['VB', 'PRP', 'VBP', 'IN', 'DT', 'NN', 'NN', '.'],
#  ['VBP', 'WDT', 'DT', 'NNS', 'RB', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   'NN',
#   'WDT',
#   'VBZ',
#   'RB',
#   'VB',
#   'TO',
#   'VBG',
#   '.'],
#  ['WRB', 'PRP', 'VBZ', 'RB', 'TO', 'VBZ', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'NN', '.'],
#  ['UH', 'TO', 'IN', 'DT', 'NNS', 'RB', '.'],
#  ['PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'VBZ',
#   'NN',
#   'VBG',
#   'NN',
#   'RB',
#   'NN',
#   'WDT',
#   'VBZ',
#   'RB',
#   'DT',
#   'VBZ',
#   'TO',
#   'TO',
#   'CD',
#   'TO',
#   'VBZ',
#   '.'],
#  ['WRB', 'RB', 'NN', 'WDT', 'VB', '.'],
#  ['WP', 'VBZ', 'TO', 'VBP', 'TO', 'VBP', '.'],
#  ['UH',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'CC',
#   'NN',
#   'WDT',
#   'DT',
#   'NNP',
#   'WDT',
#   'DT',
#   'NNS',
#   'CC',
#   'JJR',
#   '.'],
#  ['UH', 'VB', 'VB', 'NNS', '.'],
#  ['VB', 'PRP', 'RB', 'UH', 'VBZ', 'VBZ', '.'],
#  ['PRP', 'VBP', 'TO', 'TO', 'VB', 'DT', 'VBZ', 'NNS', '.'],
#  ['PRP', 'VBP', 'RB', 'VBZ', 'WRB', 'VBZ', 'VBZ', 'VBZ', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'RB', 'WDT', '.'],
#  ['UH', 'VBZ', '.'],
#  ['WRB', 'VBZ', 'NN', 'UH', '.'],
#  ['PRP', 'VBP', 'VBG', 'IN', 'DT', 'NN', 'TO', 'VB', 'WRB', 'WDT', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'IN', 'UH', 'VBZ', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'NN',
#   'WDT',
#   'DT',
#   'NNS',
#   'WDT',
#   'DT',
#   'NNS',
#   '.'],
#  ['VB', 'PRP', 'RB', 'DT', 'VBZ', 'TO', '.'],
#  ['PRP', 'VBP', 'VBG', 'IN', 'DT', 'NN', 'WDT', 'UH', 'VBZ', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'VBZ', 'WDT', 'DT', 'VBZ', 'TO', '.'],
#  ['RB', 'VB', 'VB', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'TO',
#   'VB',
#   'NN',
#   'NN',
#   'WDT',
#   'VBZ',
#   '.'],
#  ['WRB', 'WDT', 'TO', 'VB', 'UH', '.'],
#  ['VB', 'PRP', 'VBP', 'IN', 'UH', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'UH', 'NN', '.'],
#  ['PRP',
#   'VBP',
#   'RB',
#   'VBZ',
#   'RB',
#   'DT',
#   'VBD',
#   'WDT',
#   'VBZ',
#   'VBZ',
#   'VBP',
#   'TO',
#   'VB',
#   'PRP',
#   'VB',
#   'UH',
#   'NNS',
#   'PRP',
#   'VBP',
#   'VBZ',
#   'RP',
#   'PRP',
#   'VBP',
#   'RB',
#   '.'],
#  ['WRB', 'PRP', 'VBP', 'PRP', 'VBP', 'RB', 'NN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'DT', 'NN', 'VBZ', 'NN', 'WDT', 'VB', 'VBZ', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', 'TO', 'MD', 'NNS', '.'],
#  ['DT', 'NN', 'WDT', 'VB', 'VBP', 'TO', 'IN', 'NNP', 'NNS', '.'],
#  ['WP', 'IN', 'VBG', 'TO', '.'],
#  ['PRP',
#   'VBP',
#   'RB',
#   'VBP',
#   'VBG',
#   'NN',
#   'NN',
#   'PRP',
#   'VBP',
#   'TO',
#   'UH',
#   'NN',
#   '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'NN',
#   'NN',
#   'WDT',
#   'NN',
#   'WDT',
#   'DT',
#   'NN',
#   'WDT',
#   'VBG',
#   '.'],
#  ['UH', 'VB', 'PRP', 'VBP', 'IN', 'VBG', '.'],
#  ['VBZ', 'RB', 'VBZ', 'NN', 'WDT', 'NN', 'NN', '.'],
#  ['WRB',
#   'DT',
#   'UH',
#   'PRP',
#   'UH',
#   'VBP',
#   'PRP',
#   'VBP',
#   'NN',
#   'RB',
#   'UH',
#   'VB',
#   'NN',
#   'NN',
#   'WDT',
#   'UH',
#   'VBZ',
#   'VBZ',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN',
#   'WDT',
#   'PRP',
#   'VBZ',
#   '.'],
#  ['VBZ', 'RP', 'UH', 'VBZ', 'RB', 'VBZ', '.'],
#  ['WRB',
#   'VBZ',
#   'VBP',
#   'VBZ',
#   'VBZ',
#   'UH',
#   'TO',
#   'NNS',
#   'WDT',
#   'NN',
#   'CC',
#   'VBZ',
#   'VBZ',
#   'NN',
#   'VBZ',
#   'RB',
#   'NNS',
#   'WDT',
#   'NN',
#   '.'],
#  ['UH', 'VBP', 'TO', 'VB', 'TO', '.'],
#  ['VBP', 'RB', 'DT', 'NN', 'NNS', 'WDT', 'NNP', '.'],
#  ['UH',
#   'WP',
#   'VBP',
#   'VBG',
#   'WDT',
#   'UH',
#   'PRP',
#   'VBP',
#   'TO',
#   'VBP',
#   'VB',
#   'TO',
#   'NN',
#   'VBD',
#   'NN',
#   'RB',
#   'VBD',
#   'VBZ',
#   'TO',
#   '.'],
#  ['VBP',
#   'TO',
#   'VB',
#   'RP',
#   'TO',
#   'VB',
#   'NNS',
#   'CC',
#   'PRP',
#   'VBP',
#   'TO',
#   'NN',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'VBZ', '.'],
#  ['DT', 'NN', 'WDT', 'NN', 'VBZ', 'RB', 'VB', '.'],
#  ['VB', 'PRP', 'RB', 'VBG', '.'],
#  ['PRP', 'VBP', 'VBG', 'VB', 'TO', '.'],
#  ['PRP', 'VBP', 'TO', 'NN', 'NN', '.'],
#  ['PRP', 'VBP', 'RB', 'VBZ', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'RB', 'NNS', 'RB', 'VBG', '.'],
#  ['WRB', 'VBZ', 'VBP', 'TO', '.'],
#  ['UH', 'VB', 'RP', '.'],
#  ['WRB', 'RB', 'UH', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'DT', 'MD', 'VBZ', 'WDT', 'NN', '.'],
#  ['WRB', 'RB', 'NN', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'NN', 'RB', 'NNP', 'VBZ', '.'],
#  ['PRP', 'VBP', 'VB', 'TO', 'VBZ', 'WDT', 'NN', 'WDT', 'TO', 'VBZ', 'NN', '.'],
#  ['WRB', 'PRP', 'VBZ', 'DT', 'NN', 'WDT', 'PRP', '.'],
#  ['WP',
#   'VBZ',
#   'DT',
#   'VBZ',
#   'VBZ',
#   'WDT',
#   'NNS',
#   'VBZ',
#   'VBP',
#   'WDT',
#   'UH',
#   'WDT',
#   '.'],
#  ['WRB', 'PRP', 'MD', 'VB', 'TO', 'NN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'RP', 'TO', 'VB', 'NNS', 'WDT', 'UH', '.'],
#  ['VBZ', 'RP', '.'],
#  ['PRP', 'VBP', 'RB', 'VBP', 'TO', 'VB', 'TO', 'IN', 'CD', 'NNS', '.'],
#  ['WRB', 'NNS', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'WRB', 'NN', '.'],
#  ['RB', 'RBR', 'IN', 'CD', 'NNS', '.'],
#  ['WRB', 'VBZ', 'VBZ', 'VBZ', 'HYPH', 'VBP', 'WDT', '.'],
#  ['VBP', 'VBZ', 'NNS', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'VBN',
#   'NN',
#   'CC',
#   'UH',
#   'PRP',
#   'VBZ',
#   'RB',
#   'VB',
#   'VB',
#   'WRB',
#   'VBZ',
#   'VBZ',
#   '.'],
#  ['WRB', 'VBZ', 'VB', 'NN', 'VBZ', 'RB', 'VBZ', 'NN', '.'],
#  ['UH', '.'],
#  ['WRB',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBZ',
#   'VB',
#   'VB',
#   'VB',
#   'PRP',
#   'DT',
#   'NNS',
#   'CC',
#   'WRB',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'WDT',
#   'DT',
#   'NN',
#   '.'],
#  ['WRB', 'VBZ', 'VBP', 'VBP', 'RB', 'WDT', '.'],
#  ['PRP',
#   'VBP',
#   'VBG',
#   'VBP',
#   'VBZ',
#   'VB',
#   'VB',
#   'RB',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBP',
#   'VBN',
#   'VB',
#   'NN',
#   'CC',
#   'RB',
#   'PRP',
#   'VBP',
#   'TO',
#   'TO',
#   'VB',
#   'RB',
#   'VBP',
#   'PRP',
#   'VBP',
#   'VB',
#   'PRP',
#   'DT',
#   'NNS',
#   'RB',
#   'VB',
#   'NN',
#   '.'],
#  ['PRP', 'MD', 'VB', 'NN', 'NN', 'WDT', 'DT', 'NN', 'NN', 'UH', '.'],
#  ['WP', 'IN', 'TO', '.'],
#  ['VBZ', 'WDT', 'VBZ', 'NNP', '.'],
#  ['VB', 'UH', 'UH', 'VB', 'PRP', 'VBP', 'JJS', 'NN', 'NN', 'WDT', 'NNP', '.'],
#  ['PRP', 'VBP', 'VBZ', '.'],
#  ['VBP', 'TO', 'VBP', 'TO', 'VBZ', 'WDT', 'WDT', 'PRP$', 'NN', '.'],
#  ['WRB', 'NN', 'WDT', 'VB', 'TO', '.'],
#  ['PRP',
#   'VBZ',
#   'TO',
#   'VB',
#   'RB',
#   'VB',
#   'TO',
#   'VBG',
#   'NNS',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'UH',
#   'VB',
#   'VB',
#   'VB',
#   '.'],
#  ['UH', 'UH', 'UH', 'VB', 'PRP', 'RB', 'UH', 'WP', 'UH', 'WRB', 'NN', '.'],
#  ['PRP', 'VBP', 'VB', 'TO', 'VBG', 'NN', '.'],
#  ['WRB', 'VBZ', 'DT', 'NN', 'NN', 'NN', 'WDT', '.'],
#  ['VB', 'PRP', 'RB', 'VBG', '.'],
#  ['WRB', 'VBZ', 'VBP', 'RB', '.'],
#  ['VBP', 'TO', 'VBP', 'TO', 'RB', 'VBG', '.'],
#  ['VBZ', 'RP', '.'],
#  ['WRB',
#   'VBZ',
#   'VBP',
#   'VBZ',
#   'VBZ',
#   'VBZ',
#   'NN',
#   'VBZ',
#   'HYPH',
#   'VBG',
#   'VBZ',
#   'HYPH',
#   'VBG',
#   'TO',
#   '.'],
#  ['WRB', 'VBZ', '.'],
#  ['UH',
#   'VB',
#   'NN',
#   'VB',
#   'RB',
#   'NNP',
#   'UH',
#   'WP',
#   'WP',
#   'TO',
#   'NNS',
#   'RB',
#   'TO',
#   'WDT',
#   'NN',
#   'CC',
#   'PRP',
#   'VBP',
#   'VB',
#   'WP',
#   'IN',
#   'UH',
#   'RB',
#   'PRP',
#   'VBP',
#   'RB',
#   'VBP',
#   'TO',
#   'VBP',
#   'VB',
#   'VB',
#   'NN',
#   '.'],
#  ['WRB', 'VB', 'RP', 'TO', 'VB', 'NNS', 'WDT', 'VBG', '.'],
#  ['WRB',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBZ',
#   'VB',
#   'DT',
#   'NN',
#   'WDT',
#   'TO',
#   'NNS',
#   'VBG',
#   'NN',
#   'FW',
#   'VBD',
#   '.'],
#  ['PRP',
#   'VBP',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   'VB',
#   'NNS',
#   'NN',
#   'PRP',
#   'VBP',
#   'VBG',
#   'VB',
#   'RB',
#   'RBR',
#   'IN',
#   'CD',
#   'NNS',
#   'CC',
#   'PRP',
#   'VBP',
#   'RB',
#   'VBP',
#   'TO',
#   'VB',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', 'NN', 'NN', '.'],
#  ['PRP', 'VBP', 'VBG', 'VB', 'WRB', '.'],
#  ['PRP', 'VBP', 'VBG', 'VB', 'TO', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'DT', 'MD', 'VBZ', 'WDT', 'NN', '.'],
#  ['PRP', 'VBP', 'VB', 'RB', 'VB', 'NNP', '.'],
#  ['VBZ',
#   'NN',
#   'VBP',
#   'NN',
#   'VBP',
#   'NN',
#   'VBZ',
#   'TO',
#   'WDT',
#   'JJR',
#   'VBG',
#   '.'],
#  ['VBP', 'RB', 'DT', 'NN', 'NN', 'WDT', 'DT', 'NNS', 'WDT', 'NN', '.'],
#  ['UH', 'WP', 'TO', 'VB', 'UH', 'VB', 'NNS', '.'],
#  ['WRB', 'VBZ', 'UH', 'WRB', 'NNS', 'VBP', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', 'VBZ', '.'],
#  ['VBP', 'TO', 'VB', 'UH', 'NN', '.'],
#  ['WRB', 'VBZ', 'UH', 'WRB', 'NNS', 'VBP', '.'],
#  ['WRB', 'VBZ', 'VBZ', 'VBG', 'TO', 'NNS', 'WDT', 'VBG', '.'],
#  ['UH',
#   'WRB',
#   'VBZ',
#   'DT',
#   'NN',
#   'HYPH',
#   'VBG',
#   'TO',
#   'VBZ',
#   'NN',
#   'WDT',
#   '.'],
#  ['WRB', '.'],
#  ['WRB', 'UH', 'FW', 'NN', 'VBZ', 'DT', 'NN', 'WDT', '.'],
#  ['VBZ', 'RP', '.'],
#  ['WRB', 'VBZ', 'VBP', 'VBZ', 'VBZ', 'VBZ', 'VBZ', 'VBZ', '.'],
#  ['WRB', 'VBZ', 'PRP', 'VBP', 'TO', 'VB', 'WRB', 'VBP', '.'],
#  ['WRB', 'VBZ', 'WP', 'VBZ', 'WDT', 'NN', 'VBZ', 'RB', '.'],
#  ['WRB',
#   'HYPH',
#   'VBP',
#   'NN',
#   'HYPH',
#   'NNP',
#   'NN',
#   'HYPH',
#   'NNP',
#   'NN',
#   'VBZ',
#   'VBZ',
#   'NN',
#   'VBZ',
#   'VBZ',
#   '.'],
#  ['WRB', 'PRP', 'VBP', 'PRP', 'VBP', 'NN', 'WDT', 'NNP', 'VBZ', 'NN', '.'],
#  ['WRB', 'PRP', 'VBP', 'PRP', 'VBP', 'IN', 'UH', 'VBZ', '.'],
#  ['WRB',
#   'VBZ',
#   'NN',
#   'NNS',
#   'WDT',
#   'TO',
#   'IN',
#   'CD',
#   'NNS',
#   'WDT',
#   'VBG',
#   '.'],
#  ['WRB', 'PRP', 'VBZ', '.'],
#  ['PRP', 'VBP', 'VBG', 'RB', 'VBD', 'VBZ', '.'],
#  ['WP', 'VBZ', 'WDT', 'UH', 'NNS', 'WDT', 'RB', 'VBD', 'NNP', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'RB', 'NNS', 'RB', 'NN', '.'],
#  ['DT',
#   'NN',
#   'WDT',
#   'NN',
#   'VBZ',
#   'VBN',
#   'NN',
#   'UH',
#   'WDT',
#   'NN',
#   'NN',
#   'CC',
#   'VBD',
#   'VBP',
#   'RB',
#   'VB',
#   '.'],
#  ['VB', 'PRP', 'VBP', 'TO', 'NNS', 'WDT', 'NNP', '.'],
#  ['WRB', 'IN', 'DT', 'TO', 'NNS', 'WDT', 'VB', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', 'NN', '.'],
#  ['UH', 'PRP', 'VBP', 'PRP', 'VBZ', 'PRP', 'VBP', 'TO', 'VB', 'WP', '.'],
#  ['UH', 'VB', 'VB', 'VB', 'PRP', 'VBZ', 'VBG', 'NN', 'VBZ', 'VBZ', 'UH', '.'],
#  ['WP', 'VBZ', 'UH', 'NN', 'VBZ', 'VBZ', 'VBZ', 'WDT', '.'],
#  ['VB', 'PRP', 'VBP', 'NN', 'WDT', 'IN', 'NN', 'VBZ', '.'],
#  ['UH', 'PRP', 'VBP', 'VBG', 'RB', 'VBG', 'RB', 'RB', 'VB', 'VBD', '.'],
#  ['PRP', 'VBP', 'TO', 'NN', 'NN', 'WDT', 'UH', '.'],
#  ['VB',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'UH',
#   'VB',
#   'NN',
#   'WDT',
#   'VBG',
#   'NN',
#   'RB',
#   'VBG',
#   'RB',
#   'CD',
#   'NNS',
#   '.'],
#  ['WRB', '.'],
#  ['VBZ', 'RB', 'DT', 'NN', 'TO', 'NN', 'WDT', 'UH', '.'],
#  ['WP', 'VBP', 'TO', 'VBP', 'RB', 'UH', 'WDT', 'VBZ', 'VBZ', '.'],
#  ['PRP', 'VBP', 'TO', 'NN', 'NN', 'NN', 'UH', '.'],
#  ['WRB', 'VBZ', 'VBZ', 'UH', 'NN', 'VBZ', '.'],
#  ['WRB',
#   'VBZ',
#   'VBP',
#   'VBZ',
#   'WDT',
#   'DT',
#   'VBZ',
#   'TO',
#   'TO',
#   'CD',
#   'TO',
#   'VBZ',
#   '.'],
#  ['WRB', 'NN', '.'],
#  ['WRB', 'VBZ', 'VBP', 'TO', '.'],
#  ['UH', 'WRB', 'RB', 'DT', 'NN', 'WDT', 'VBG', '.'],
#  ['WRB', 'VB', 'PRP', 'VBP', 'IN', 'NNS', 'VBP', '.'],
#  ['WRB', 'PRP', 'VBP', 'PRP', 'VBP', 'NN', 'TO', 'IN', 'VBG', '.'],
#  ['VB', 'PRP', 'VBP', 'IN', 'UH', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', 'UH', '.'],
#  ['WRB', 'TO', '.'],
#  ['UH',
#   'PRP',
#   'VBP',
#   'RB',
#   'VBP',
#   'RB',
#   'NN',
#   'PRP',
#   'VBP',
#   'RB',
#   'VBP',
#   'UH',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBP',
#   'VBZ',
#   'NN',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', 'NN', '.'],
#  ['VBP', 'TO', 'VBP', 'VBG', 'NN', '.'],
#  ['WRB', 'VBZ', 'NN', 'VBZ', 'VBZ', 'WDT', 'NN', 'VBN', 'TO', '.'],
#  ['WRB', 'VBZ', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'RB', 'NNP', 'HYPH', 'NNP', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'DT', 'NN', 'CC', 'DT', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'IN', 'RB', '.'],
#  ['VBP', 'TO', 'VBP', 'TO', 'VBZ', 'HYPH', 'VBG', '.'],
#  ['WRB', 'WRB', 'VBP', 'RB', 'DT', 'NN', 'VBZ', 'NNS', 'WDT', 'NNP', '.'],
#  ['PRP', 'VBP', 'TO', 'NNS', 'IN', 'PRP', '.'],
#  ['WRB', 'VBZ', 'DT', 'NN', 'WDT', 'NN', 'WDT', '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'VB',
#   'NN',
#   'NN',
#   'WDT',
#   'VBZ',
#   'RB',
#   'TO',
#   'CD',
#   'NNS',
#   'RB',
#   'VB',
#   'VBG',
#   'WDT',
#   'VBG',
#   'TO',
#   'CD',
#   'NNS',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'NNP',
#   'POS',
#   'RB',
#   'POS',
#   'RB',
#   'POS',
#   'PRP',
#   'NN',
#   'CC',
#   'PRP$',
#   'VBD',
#   'NN',
#   'VBZ',
#   'VBN',
#   '.'],
#  ['WRB', 'VBZ', 'VBZ', 'VBZ', 'VBZ', 'VBZ', 'VBZ', 'HYPH', 'VBP', '.'],
#  ['UH',
#   'UH',
#   'PRP',
#   'VBP',
#   'TO',
#   'NN',
#   'NN',
#   'PRP$',
#   'VBD',
#   'VBZ',
#   'UH',
#   'VB',
#   'NN',
#   'VBZ',
#   'RB',
#   'UH',
#   'WRB',
#   'VBZ',
#   'VBG',
#   'VB',
#   'NN',
#   'RB',
#   'VBZ',
#   'VBP',
#   'TO',
#   'NN',
#   'WDT',
#   'VBZ',
#   'VBZ',
#   'VBZ',
#   'PRP',
#   'VBP',
#   'VBG',
#   'VBZ',
#   'VB',
#   'WP',
#   '.'],
#  ['PRP', 'VBP', 'TO', 'NN', 'WDT', 'NN', 'VBZ', 'VBZ', '.'],
#  ['PRP', 'VBP', 'VBG', 'WDT', 'UH', 'NN', 'CC', 'UH', 'WP', '.'],
#  ['WRB',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'DT',
#   'NN',
#   'NN',
#   'WDT',
#   'RB',
#   'CD',
#   'NNS',
#   'WDT',
#   'VBG',
#   'CC',
#   'PRP',
#   'VBP',
#   'VB',
#   'VBP',
#   'UH',
#   'RBR',
#   'IN',
#   'DT',
#   'NNS',
#   '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'UH',
#   'NN',
#   'CC',
#   'RB',
#   'VB',
#   'TO',
#   'VBG',
#   '.'],
#  ['VBP', 'RB', 'DT', 'NN', 'VBZ', 'NNS', 'RB', 'VB', '.'],
#  ['WP',
#   'VBZ',
#   'VBP',
#   'WDT',
#   'VBZ',
#   'RB',
#   'VBZ',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   'VB',
#   'NN',
#   'NN',
#   'RB',
#   'VBD',
#   '.'],
#  ['PRP', 'MD', 'VB', 'PRP', 'TO', 'VB', 'WP', 'VBG', 'NN', 'WDT', 'VBG', '.'],
#  ['PRP', 'VBP', 'TO', 'WDT', 'UH', '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   'IN',
#   'DT',
#   'NN',
#   'NNP',
#   'HYPH',
#   'NNP',
#   'VBZ',
#   'RB',
#   'VBZ',
#   '.'],
#  ['VBP', 'TO', 'VBP', 'TO', 'VBZ', 'TO', 'NN', '.'],
#  ['VBZ', 'RP', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', 'NN', 'UH', '.'],
#  ['UH', 'VB', 'NNP', 'NNS', '.'],
#  ['UH',
#   'PRP',
#   'VBP',
#   'VBG',
#   'VBZ',
#   'RB',
#   'UH',
#   'UH',
#   'WDT',
#   'NNP',
#   'RB',
#   'RB',
#   'VB',
#   'NN',
#   'RB',
#   'NN',
#   '.'],
#  ['VBZ', 'RP', '.'],
#  ['VBZ', 'RP', '.'],
#  ['PRP', 'VBP', 'WRB', 'RB', 'VBG', '.'],
#  ['UH', 'VB', 'PRP', 'RB', 'UH', 'NNS', 'VBG', 'HYPH', 'VBG', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', 'NN', '.'],
#  ['WRB', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', '.'],
#  ['WRB', 'VBZ', 'VBZ', 'VBZ', 'VBZ', '.'],
#  ['VB', 'VBZ', 'DT', 'NN', 'NN', 'UH', 'VBZ', 'WP', 'IN', 'DT', 'NN', '.'],
#  ['WRB', 'WRB', 'VBP', 'RB', 'DT', 'NN', 'VBZ', 'NNS', 'WDT', 'NNP', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', 'VB', 'VBZ', 'HYPH', 'VBG', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'NN', 'WDT', 'NN', '.'],
#  ['WRB', 'VBZ', 'VBP', 'DT', 'NN', 'WDT', 'NN', 'RB', 'VB', 'NNS', 'WDT', '.'],
#  ['WRB', 'VBZ', 'PRP', 'VBP', 'DT', 'VBZ', 'VBZ', 'VBZ', '.'],
#  ['PRP',
#   'MD',
#   'VBD',
#   'RB',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   'VBZ',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'TO',
#   'UH',
#   'CC',
#   'VBZ',
#   '.'],
#  ['PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'WRB',
#   'NN',
#   'NN',
#   'PRP',
#   'VBZ',
#   'VBP',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   '.'],
#  ['PRP', 'VBP', 'VBG', 'IN', 'NNS', 'WDT', 'TO', 'NN', '.'],
#  ['PRP', 'VBP', 'TO', 'VB', 'TO', 'IN', 'NNP', 'NNS', '.'],
#  ['UH',
#   'PRP',
#   'VBP',
#   'VBG',
#   'NN',
#   'WDT',
#   'NN',
#   'RB',
#   'VB',
#   'NNP',
#   'RB',
#   'VB',
#   'VB',
#   'RB',
#   'VB',
#   'NN',
#   'CC',
#   'RB',
#   'VB',
#   'NN',
#   'RB',
#   'VB',
#   'NN',
#   'WDT',
#   '.'],
#  ['VB', 'PRP', 'RB', 'NN', 'VBZ', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'WDT', 'UH', 'VBZ', 'VBZ', '.'],
#  ['WP', 'VBP', 'TO', 'VBP', 'RB', 'VB', 'TO', 'NNS', '.'],
#  ['PRP', 'MD', 'VB', 'TO', 'VB', 'TO', 'WDT', 'UH', 'VBZ', 'VBZ', 'NN', '.'],
#  ['UH', 'VBP', 'TO', 'VBP', 'TO', 'NN', 'TO', 'NN', '.'],
#  ['WRB',
#   'JJR',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'VBZ',
#   'VBZ',
#   'NN',
#   'VBZ',
#   'VBZ',
#   'VBZ',
#   'NN',
#   'WDT',
#   'NN',
#   '.'],
#  ['WRB', 'VBZ', 'DT', 'VBZ', 'VBZ', 'WDT', 'VBZ', 'NN', 'NN', '.'],
#  ['WRB', 'TO', 'VBP', 'VBZ', 'CC', 'VB', 'RP', '.'],
#  ['PRP',
#   'VBP',
#   'VBG',
#   'VBP',
#   'RB',
#   'UH',
#   'VB',
#   'PRP',
#   'VBP',
#   'TO',
#   'MD',
#   'VB',
#   'WP',
#   'UH',
#   'WP',
#   'RB',
#   'DT',
#   'NNS',
#   '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'TO',
#   'VB',
#   'NNS',
#   'NN',
#   'WDT',
#   'NN',
#   'WDT',
#   'NN',
#   '.'],
#  ['VB', 'PRP', 'VBP', 'IN', 'VBG', '.'],
#  ['PRP', 'VBZ', 'RB', 'VB', 'PRP', 'VBP', 'RB', 'VBZ', 'WRB', 'VBZ', '.'],
#  ['WRB', 'VBZ', 'PRP', 'VBP', 'TO', 'VB', 'DT', 'VBZ', '.'],
#  ['UH', 'UH', 'WRB', 'RB', 'UH', 'NN', 'UH', 'NN', 'UH', 'VB', 'NN', '.'],
#  ['VBP', 'TO', 'VBP', 'TO', 'DT', 'NNS', 'WDT', 'VBZ', 'NN', '.'],
#  ...]

# %%
flat_list = [tag for tag_list in sequence_tags for tag in tag_list]
flat_list
# Out:
# ['VB',
#  'PRP',
#  'RB',
#  'NNP',
#  'HYPH',
#  'VBG',
#  '.',
#  'UH',
#  'VB',
#  'PRP',
#  'VBZ',
#  'NN',
#  'WDT',
#  'DT',
#  'VBZ',
#  'NN',
#  '.',
#  'PRP',
#  'MD',
#  'VB',
#  'TO',
#  'VB',
#  'TO',
#  'NNP',
#  '.',
#  'UH',
#  'WP',
#  'RB',
#  'CD',
#  'NNS',
#  'WDT',
#  'VBZ',
#  'VBP',
#  '.',
#  'WRB',
#  'UH',
#  '.',
#  'WRB',
#  'VBZ',
#  'VBP',
#  'TO',
#  'TO',
#  'VB',
#  'NNS',
#  '.',
#  'PRP',
#  'VBP',
#  'VB',
#  'RB',
#  'VB',
#  'TO',
#  'VB',
#  '.',
#  'WRB',
#  'VBZ',
#  '.',
#  'WRB',
#  'VBZ',
#  'PRP',
#  'VBP',
#  'TO',
#  'WDT',
#  'DT',
#  'VBZ',
#  'NNS',
#  '.',
#  'VBZ',
#  'WDT',
#  'NN',
#  '.',
#  'VB',
#  'PRP',
#  'VBP',
#  'IN',
#  'UH',
#  'VBZ',
#  'CC',
#  'UH',
#  'PRP',
#  'VBP',
#  'TO',
#  'VBZ',
#  '.',
#  'WRB',
#  'VBZ',
#  'WDT',
#  'TO',
#  'VBZ',
#  'VBZ',
#  'VBZ',
#  'VBZ',
#  'VBZ',
#  'CC',
#  'UH',
#  'VBP',
#  '.',
#  'UH',
#  'VB',
#  'DT',
#  'NNS',
#  '.',
#  'VB',
#  'PRP',
#  'VBP',
#  'TO',
#  'NNS',
#  'WDT',
#  'NNP',
#  '.',
#  'VBP',
#  'VBG',
#  'NN',
#  '.',
#  'WRB',
#  'JJR',
#  'NN',
#  'NN',
#  'NN',
#  'NN',
#  'VBZ',
#  'VBZ',
#  'NN',
#  'VBZ',
#  'VBZ',
#  'VBZ',
#  'NN',
#  'WDT',
#  'NN',
#  '.',
#  'WRB',
#  'IN',
#  'VBG',
#  'VB',
#  'UH',
#  '.',
#  'PRP',
#  'VBP',
#  'VB',
#  'TO',
#  'NN',
#  'WDT',
#  'NNP',
#  '.',
#  'WRB',
#  'WRB',
#  'VBP',
#  'RB',
#  'DT',
#  'NN',
#  'VBZ',
#  'NNS',
#  'WDT',
#  'NNP',
#  '.',
#  'WRB',
#  'VBG',
#  'NN',
#  'WDT',
#  'UH',
#  '.',
#  'WRB',
#  'VBZ',
#  'VBP',
#  'RB',
#  '.',
#  'WP',
#  'VBP',
#  'TO',
#  'VBP',
#  'RB',
#  'UH',
#  'NN',
#  '.',
#  'PRP',
#  'VBP',
#  'RB',
#  'VB',
#  'VBZ',
#  'WP',
#  'VBZ',
#  'WDT',
#  'NN',
#  '.',
#  'UH',
#  'PRP',
#  'MD',
#  'VB',
#  'TO',
#  'VB',
#  'TO',
#  'NN',
#  'NN',
#  'WDT',
#  'VBG',
#  'RB',
#  'IN',
#  'DT',
#  'NNS',
#  'WDT',
#  'VBG',
#  '.',
#  'WRB',
#  'VBZ',
#  'VBZ',
#  'VBG',
#  'TO',
#  'VB',
#  'RP',
#  'PRP',
#  'MD',
#  'VB',
#  'TO',
#  'VB',
#  'WRB',
#  'VB',
#  'NN',
#  '.',
#  'PRP',
#  'MD',
#  'VB',
#  'TO',
#  'VB',
#  'UH',
#  'NN',
#  '.',
#  'PRP',
#  'MD',
#  'VB',
#  'TO',
#  'VB',
#  'TO',
#  'WDT',
#  'IN',
#  'UH',
#  'UH',
#  '.',
#  'VB',
#  'PDT',
#  'DT',
#  'NN',
#  '.',
#  'PRP',
#  'MD',
#  'VB',
#  'TO',
#  'VB',
#  'TO',
#  'UH',
#  'IN',
#  'DT',
#  'VBZ',
#  'NNS',
#  '.',
#  'PRP',
#  'VBP',
#  'VBG',
#  'VBZ',
#  'IN',
#  'NN',
#  '.',
#  'WRB',
#  'DT',
#  'UH',
#  'PRP',
#  'UH',
#  'VBP',
#  'PRP',
#  'VBP',
#  'NN',
#  'RB',
#  'UH',
#  'VB',
#  'NN',
#  'NN',
#  'WDT',
#  'UH',
#  'VBZ',
#  'VBZ',
#  'PRP',
#  'VBP',
#  'DT',
#  'NN',
#  'WDT',
#  'PRP',
#  'VBZ',
#  '.',
#  'PRP',
#  'VBP',
#  'VBG',
#  'VB',
#  'TO',
#  '.',
#  'PRP',
#  'VBP',
#  'TO',
#  'VB',
#  'TO',
#  'NN',
#  'CC',
#  'RB',
#  'PRP',
#  'VBP',
#  'TO',
#  'NN',
#  'UH',
#  '.',
#  'UH',
#  'VB',
#  'VB',
#  'VB',
#  'PRP',
#  'VBZ',
#  'VBG',
#  'NN',
#  'VBZ',
#  'VBZ',
#  'UH',
#  '.',
#  'PRP',
#  'MD',
#  'VB',
#  'TO',
#  'VB',
#  'TO',
#  'VB',
#  'NN',
#  'UH',
#  'NN',
#  'WDT',
#  'NN',
#  '.',
#  'PRP',
#  'VBP',
#  'TO',
#  'VBZ',
#  'NN',
#  'TO',
#  'NN',
#  'CC',
#  'DT',
#  'JJR',
#  'UH',
#  '.',
#  'PRP',
#  'VBP',
#  'TO',
#  'MD',
#  'NN',
#  'VBZ',
#  'TO',
#  'VB',
#  'TO',
#  'VB',
#  'TO',
#  'WDT',
#  'DT',
#  'NN',
#  '.',
#  'PRP',
#  'MD',
#  'VB',
#  'TO',
#  'VB',
#  'UH',
#  'VB',
#  'NN',
#  '.',
#  'VBP',
#  'TO',
#  'VB',
#  'TO',
#  'WDT',
#  'VBZ',
#  'RB',
#  'RB',
#  'WDT',
#  'NN',
#  '.',
#  'VBZ',
#  'RP',
#  '.',
#  'VBP',
#  'RB',
#  'DT',
#  'NNS',
#  'WDT',
#  'VBZ',
#  'NNP',
#  '.',
#  'PRP',
#  'MD',
#  'VB',
#  'TO',
#  'VB',
#  'UH',
#  'VB',
#  'TO',
#  'NN',
#  'WDT',
#  'NN',
#  '.',
#  'PRP',
#  'MD',
#  'VB',
#  'UH',
#  'WP',
#  'UH',
#  'TO',
#  'VB',
#  'PRP',
#  'MD',
#  'VB',
#  'VBP',
#  'TO',
#  'VB',
#  'TO',
#  'VB',
#  'WP',
#  'PRP',
#  'MD',
#  'VB',
#  'TO',
#  'UH',
#  'NN',
#  '.',
#  'WRB',
#  'PRP',
#  'VBP',
#  'PRP',
#  'VBP',
#  'NN',
#  'WDT',
#  'DT',
#  'VBZ',
#  'NN',
#  '.',
#  'WRB',
#  'RB',
#  'TO',
#  'NN',
#  'WDT',
#  'NNP',
#  'VBZ',
#  '.',
#  'WRB',
#  'VB',
#  'TO',
#  'VB',
#  'NN',
#  'NN',
#  'WDT',
#  'NNP',
#  '.',
#  'PRP',
#  'VBP',
#  'VBG',
#  'VB',
#  'RP',
#  'TO',
#  'NN',
#  'WDT',
#  'NN',
#  'NN',
#  '.',
#  'UH',
#  'WP',
#  'VBZ',
#  'VBP',
#  'WDT',
#  'VBZ',
#  'RB',
#  'VBZ',
#  'VBP',
#  'TO',
#  'VB',
#  'TO',
#  'VB',
#  'NN',
#  'NN',
#  'RB',
#  'VBD',
#  '.',
#  'PRP',
#  'MD',
#  'VB',
#  'TO',
#  'VB',
#  'DT',
#  'NN',
#  '.',
#  'UH',
#  'VB',
#  'NN',
#  '.',
#  'PRP',
#  'MD',
#  'VB',
#  'TO',
#  'VB',
#  'TO',
#  'UH',
#  '.',
#  'WRB',
#  'RB',
#  'UH',
#  'HYPH',
#  'NN',
#  '.',
#  'WRB',
#  'RB',
#  'DT',
#  'NN',
#  'NN',
#  'WDT',
#  'NN',
#  '.',
#  'VB',
#  'VB',
#  '.',
#  'DT',
#  'NN',
#  'WDT',
#  'VB',
#  'TO',
#  'IN',
#  'DT',
#  'TO',
#  '.',
#  'PRP',
#  'VBP',
#  'TO',
#  'VB',
#  'DT',
#  'RB',
#  'VB',
#  'NN',
#  'TO',
#  'VB',
#  'TO',
#  'WDT',
#  'VB',
#  '.',
#  'VBP',
#  'TO',
#  'VBP',
#  'RB',
#  'DT',
#  'NN',
#  'NNS',
#  '.',
#  'PRP',
#  'VBZ',
#  'RB',
#  'VB',
#  'WRB',
#  'VBZ',
#  'PRP',
#  'VBZ',
#  'RB',
#  '.',
#  'PRP',
#  'MD',
#  'VB',
#  'TO',
#  'VB',
#  'TO',
#  'NN',
#  '.',
#  'VBP',
#  'TO',
#  'VBP',
#  'VBG',
#  'WDT',
#  'DT',
#  'NN',
#  'WDT',
#  '.',
#  'WRB',
#  'PRP',
#  'VBP',
#  'PRP',
#  'VBP',
#  'VBZ',
#  '.',
#  'WRB',
#  'VBZ',
#  'VBZ',
#  'NN',
#  'VBZ',
#  'RB',
#  '.',
#  'PRP',
#  'VBP',
#  'TO',
#  'VB',
#  'TO',
#  'CC',
#  'PRP',
#  'VBP',
#  'TO',
#  'VB',
#  'TO',
#  'NN',
#  '.',
#  'WRB',
#  'RB',
#  'VBG',
#  'NN',
#  '.',
#  'VBZ',
#  'RB',
#  'DT',
#  'NN',
#  'NN',
#  'RB',
#  '.',
#  'WRB',
#  'RB',
#  'NNP',
#  'CC',
#  'VBZ',
#  'RB',
#  'VBZ',
#  '.',
#  'VBP',
#  'NN',
#  '.',
#  'PRP',
#  'VBP',
#  'VBZ',
#  '.',
#  'VBP',
#  'TO',
#  'VBP',
#  'TO',
#  'RB',
#  'DT',
#  'VBZ',
#  '.',
#  'PRP',
#  'MD',
#  'VB',
#  'TO',
#  'VB',
#  'TO',
#  'NNP',
#  '.',
#  'VB',
#  'NNP',
#  'NNS',
#  'WDT',
#  'VB',
#  '.',
#  'WP',
#  'VBZ',
#  'PRP',
#  'VBP',
#  'DT',
#  'NN',
#  'WDT',
#  '.',
#  'WRB',
#  'NN',
#  'VBZ',
#  'CC',
#  'PRP',
#  'VBP',
#  'UH',
#  'VB',
#  'MD',
#  'NN',
#  '.',
#  'PRP',
#  'VBP',
#  'TO',
#  'VB',
#  'WP',
#  'DT',
#  'NNS',
#  '.',
#  'UH',
#  'VB',
#  'VBZ',
#  'VBP',
#  'RB',
#  'VB',
#  'DT',
#  'NN',
#  'TO',
#  'CC',
#  'PRP',
#  'VBP',
#  'VB',
#  'RB',
#  'RB',
#  'NNS',
#  '.',
#  'WRB',
#  'VBZ',
#  'DT',
#  'NN',
#  'WDT',
#  'NN',
#  'WDT',
#  '.',
#  'PRP',
#  'MD',
#  'VB',
#  'TO',
#  'VB',
#  'DT',
#  'NN',
#  'WDT',
#  'VBZ',
#  'VBG',
#  'VBG',
#  'NN',
#  'WDT',
#  'NN',
#  '.',
#  'PRP',
#  'VBP',
#  'VBG',
#  'IN',
#  'DT',
#  'VBZ',
#  'VB',
#  'TO',
#  'NN',
#  '.',
#  'PRP',
#  'MD',
#  'VB',
#  'TO',
#  'WDT',
#  'NNP',
#  'HYPH',
#  'NNP',
#  '.',
#  'UH',
#  'VBZ',
#  'VBZ',
#  '.',
#  'PRP',
#  'MD',
#  'VB',
#  'WP',
#  'VB',
#  'NN',
#  'NN',
#  'WDT',
#  'NN',
#  'WDT',
#  'DT',
#  'NN',
#  'WDT',
#  'VBG',
#  '.',
#  'WRB',
#  'PRP',
#  'VBP',
#  'TO',
#  'NN',
#  'RB',
#  'RB',
#  'NN',
#  'VBZ',
#  'NN',
#  '.',
#  'PRP',
#  'VBP',
#  'VBG',
#  'IN',
#  'DT',
#  'NN',
#  'WDT',
#  'UH',
#  'VBZ',
#  '.',
#  'WRB',
#  'NN',
#  'PRP',
#  'VBP',
#  'TO',
#  'VB',
#  'UH',
#  'NN',
#  '.',
#  'WRB',
#  'NN',
#  '.',
#  'VB',
#  'PRP',
#  'RB',
#  'NN',
#  'VBZ',
#  '.',
#  'VBP',
#  'TO',
#  'VBP',
#  'TO',
#  'RB',
#  'DT',
#  'NN',
#  'WDT',
#  'VBZ',
#  'VBZ',
#  '.',
#  'PRP',
#  'VBP',
#  'RB',
#  'VBZ',
#  'WP',
#  'VBZ',
#  '.',
#  'WP',
#  'VBZ',
#  'WDT',
#  'UH',
#  'NNS',
#  'WDT',
#  'RB',
#  'VBD',
#  'NNP',
#  '.',
#  'VB',
#  'PRP',
#  'RB',
#  'DT',
#  'VBD',
#  'VBZ',
#  '.',
#  'PRP',
#  'VBP',
#  'TO',
#  'VBZ',
#  'CC',
#  'PRP',
#  'MD',
#  'VB',
#  'WRB',
#  'WDT',
#  'NNS',
#  '.',
#  'UH',
#  'WRB',
#  'PRP',
#  'VBP',
#  'PRP',
#  'MD',
#  'VB',
#  'TO',
#  'VB',
#  'UH',
#  'VB',
#  '.',
#  'PRP',
#  'VBP',
#  'TO',
#  'NN',
#  'NN',
#  'NN',
#  'VBZ',
#  'WDT',
#  'UH',
#  '.',
#  'PRP',
#  'MD',
#  'VB',
#  'TO',
#  'VB',
#  'TO',
#  'NN',
#  '.',
#  'WRB',
#  'DT',
#  'NN',
#  'VB',
#  'RP',
#  'VB',
#  '.',
#  'WRB',
#  'PRP',
#  'VBP',
#  'PRP',
#  'VBP',
#  'VBZ',
#  'IN',
#  'DT',
#  'NN',
#  '.',
#  'PRP',
#  'MD',
#  'VB',
#  'TO',
#  'VB',
#  'TO',
#  'UH',
#  'VB',
#  'NN',
#  '.',
#  'VBP',
#  'TO',
#  'VBP',
#  'TO',
#  'RB',
#  'VBG',
#  'WDT',
#  'UH',
#  '.',
#  'WRB',
#  'HYPH',
#  'NNP',
#  'VBZ',
#  'VBZ',
#  'DT',
#  'NN',
#  'WDT',
#  'UH',
#  'WDT',
#  'PRP',
#  'VBP',
#  'PRP',
#  'VBZ',
#  'RB',
#  'PRP',
#  '.',
#  'WRB',
#  'WDT',
#  'NNS',
#  'CC',
#  'JJR',
#  'NN',
#  'VB',
#  'TO',
#  '.',
#  'VBZ',
#  'RP',
#  '.',
#  'PRP',
#  'VBP',
#  'TO',
#  'VB',
#  'TO',
#  '.',
#  'WRB',
#  'IN',
#  'NN',
#  'TO',
#  '.',
#  'VB',
#  'PRP',
#  'VBP',
#  'IN',
#  'TO',
#  'VBZ',
#  'NN',
#  '.',
#  'DT',
#  'NN',
#  'WDT',
#  'VB',
#  'TO',
#  'IN',
#  'NN',
#  'TO',
#  'WDT',
#  'VBG',
#  '.',
#  'VB',
#  'PRP',
#  'RB',
#  'NN',
#  'VBZ',
#  '.',
#  'UH',
#  'UH',
#  'WRB',
#  'PRP',
#  'VBP',
#  'PRP',
#  'VBP',
#  'VB',
#  'MD',
#  'NNS',
#  'RB',
#  'UH',
#  'VBZ',
#  '.',
#  'WRB',
#  'PRP',
#  'VBP',
#  'DT',
#  'NN',
#  'WDT',
#  'VBG',
#  '.',
#  'VB',
#  'CD',
#  'NNS',
#  ...]

# %%
flat_list = [tag_list for tag_list in sequence_tags]

# %%
flatten_list = lambda target_list : [tag for tag_list in target_list for tag in tag_list]

# %%
flat_list = flatten_list(sequence_tags)

# %%
flat_list = []
for tag_list in sequence_tags:
    for tag in tag_list:
        flat_list.append(tag)

# %%
# Flatten lists
sentences_labels_flat = flatten_list(sentences_labels)
sequence_tags_flat = flatten_list(sequence_tags)
len(sentences_labels_flat)
# Out:
# 30783

# %%
count_correct = 0
for tag in range(0, len(sentences_labels_flat)):
    if sentences_labels_flat[tag] == sequence_tags_flat[tag]:
        count_correct += 1
        
count_correct / len(sentences_labels_flat)
# Out:
# 0.596725465354254

# %%
# Test on single sentence
input_sentence = ['i', "'d", 'like', 'to', 'go', 'to', 'UNK', '.', '/n'] 

# Training data
with open('berp-POS-training.txt', 'r') as train_file:
    train_data = train_file.readlines()
    
# Get tags and words from fixed lexicon from this train_data
set_of_tags, set_of_words = build_words_tags_sets(train_data)        

# Divide up data into train and test set
# Then get list of words from train_set
# Words not in train_set but in total set: process unseen & get counts

# Process unseen words & get cumulative counts
new_sentence = []
UNK_count = 0
for word in input_sentence:
    if (word != '/n'):
        if (word not in set_of_words):
            new_sentence.append('UNK')
            UNK_count += 1
        else:
            new_sentence.append(word)
        
# Get probability matrices, run viterbi & get output       
list_of_tags, list_of_words, word_count, transition_probs, emission_probs = build_lists_and_probabilities(train_data, set_of_tags, set_of_words, UNK_count)
p, back, best_path_pointer, best_path_prob = viterbi_pos_tagger(list_of_tags, new_sentence, transition_probs, emission_probs)
output_tags = backtrace(back, best_path_pointer, new_sentence)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-534-80088bb38738> in <module>()
#       7
#       8 # Get tags and words from fixed lexicon from this train_data
# ----> 9 set_of_tags, set_of_words = build_words_tags_sets(train_data)
#      10
#      11 # Divide up data into train and test set
#
# ValueError: too many values to unpack (expected 2)

# %%
# # Create a test set and try. 
# test_data = ""
# for line in train_data[:104]:
#     if len(line) == 1:
#         test_data += '\n'
#     elif len(line) > 1:
#         num_word = line.strip().split('\t')
#         num = num_word[0]
#         word = num_word[1]
#         new_line = num + '\t' + word
#         test_data += new_line + '\n'    
        
# # Write to file        
# with open('viterbi_testfile.txt', 'w') as testfile:
#     pass # Empty content before writing
#     testfile.write(test_data)

# %%
list2d = [[1,'AB',3],[4,5,6], [10], [8,9]]
merged = list(itertools.chain(*list2d))
merged
# Out:
# [1, 'AB', 3, 4, 5, 6, 10, 8, 9]
